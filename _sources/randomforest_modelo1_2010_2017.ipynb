# %% [markdown]
# # Floresta Aleatória
# **Variáveis Agregadas (2010-2017)** \\
#  \\
# Bootcamp Machine Learning ENAP 2024 \\
# Maurício Marques Soares Filho \\
# 25/10/2024 \\

# %%
###
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import dtreeviz

###
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.inspection import permutation_importance

###
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from collections import Counter

###
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, GridSearchCV

###
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier


###
from sklearn.pipeline import Pipeline
from skopt import BayesSearchCV

###
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Pré-processamento dos dados

# %%
#Estilizar conteúdo
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},  # Bordas cinza escuro
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'
        ).format(
            precision=casas_decimais
        )
    )

# %%
# Importar a base de dados
df_eventos_2010_2017_modelo1 = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2010_2017_modelo1.csv",
    sep=';',
    decimal=',',
)

estilo_tabelas(df_eventos_2010_2017_modelo1.head(5))
# Out:
# <style type="text/css">
# #T_617d0 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_617d0 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_617d0 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_617d0 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_617d0 td {
#   border: 1px solid #666;
# }
# #T_617d0  th {
#   border: 1px solid #666;
# }
# #T_617d0_row0_col0, #T_617d0_row0_col1, #T_617d0_row0_col2, #T_617d0_row0_col3, #T_617d0_row0_col4, #T_617d0_row0_col5, #T_617d0_row0_col6, #T_617d0_row0_col7, #T_617d0_row0_col8, #T_617d0_row0_col9, #T_617d0_row0_col10, #T_617d0_row0_col11, #T_617d0_row0_col12, #T_617d0_row0_col13, #T_617d0_row0_col14, #T_617d0_row0_col15, #T_617d0_row0_col16, #T_617d0_row0_col17, #T_617d0_row0_col18, #T_617d0_row0_col19, #T_617d0_row0_col20, #T_617d0_row0_col21, #T_617d0_row0_col22, #T_617d0_row0_col23, #T_617d0_row0_col24, #T_617d0_row0_col25, #T_617d0_row0_col26, #T_617d0_row0_col27, #T_617d0_row0_col28, #T_617d0_row0_col29, #T_617d0_row0_col30, #T_617d0_row0_col31, #T_617d0_row0_col32, #T_617d0_row0_col33, #T_617d0_row0_col34, #T_617d0_row0_col35, #T_617d0_row0_col36, #T_617d0_row0_col37, #T_617d0_row0_col38, #T_617d0_row0_col39, #T_617d0_row0_col40, #T_617d0_row0_col41, #T_617d0_row0_col42, #T_617d0_row0_col43, #T_617d0_row0_col44, #T_617d0_row0_col45, #T_617d0_row0_col46, #T_617d0_row0_col47, #T_617d0_row0_col48, #T_617d0_row0_col49, #T_617d0_row0_col50, #T_617d0_row0_col51, #T_617d0_row0_col52, #T_617d0_row0_col53, #T_617d0_row0_col54, #T_617d0_row0_col55, #T_617d0_row1_col0, #T_617d0_row1_col1, #T_617d0_row1_col2, #T_617d0_row1_col3, #T_617d0_row1_col4, #T_617d0_row1_col5, #T_617d0_row1_col6, #T_617d0_row1_col7, #T_617d0_row1_col8, #T_617d0_row1_col9, #T_617d0_row1_col10, #T_617d0_row1_col11, #T_617d0_row1_col12, #T_617d0_row1_col13, #T_617d0_row1_col14, #T_617d0_row1_col15, #T_617d0_row1_col16, #T_617d0_row1_col17, #T_617d0_row1_col18, #T_617d0_row1_col19, #T_617d0_row1_col20, #T_617d0_row1_col21, #T_617d0_row1_col22, #T_617d0_row1_col23, #T_617d0_row1_col24, #T_617d0_row1_col25, #T_617d0_row1_col26, #T_617d0_row1_col27, #T_617d0_row1_col28, #T_617d0_row1_col29, #T_617d0_row1_col30, #T_617d0_row1_col31, #T_617d0_row1_col32, #T_617d0_row1_col33, #T_617d0_row1_col34, #T_617d0_row1_col35, #T_617d0_row1_col36, #T_617d0_row1_col37, #T_617d0_row1_col38, #T_617d0_row1_col39, #T_617d0_row1_col40, #T_617d0_row1_col41, #T_617d0_row1_col42, #T_617d0_row1_col43, #T_617d0_row1_col44, #T_617d0_row1_col45, #T_617d0_row1_col46, #T_617d0_row1_col47, #T_617d0_row1_col48, #T_617d0_row1_col49, #T_617d0_row1_col50, #T_617d0_row1_col51, #T_617d0_row1_col52, #T_617d0_row1_col53, #T_617d0_row1_col54, #T_617d0_row1_col55, #T_617d0_row2_col0, #T_617d0_row2_col1, #T_617d0_row2_col2, #T_617d0_row2_col3, #T_617d0_row2_col4, #T_617d0_row2_col5, #T_617d0_row2_col6, #T_617d0_row2_col7, #T_617d0_row2_col8, #T_617d0_row2_col9, #T_617d0_row2_col10, #T_617d0_row2_col11, #T_617d0_row2_col12, #T_617d0_row2_col13, #T_617d0_row2_col14, #T_617d0_row2_col15, #T_617d0_row2_col16, #T_617d0_row2_col17, #T_617d0_row2_col18, #T_617d0_row2_col19, #T_617d0_row2_col20, #T_617d0_row2_col21, #T_617d0_row2_col22, #T_617d0_row2_col23, #T_617d0_row2_col24, #T_617d0_row2_col25, #T_617d0_row2_col26, #T_617d0_row2_col27, #T_617d0_row2_col28, #T_617d0_row2_col29, #T_617d0_row2_col30, #T_617d0_row2_col31, #T_617d0_row2_col32, #T_617d0_row2_col33, #T_617d0_row2_col34, #T_617d0_row2_col35, #T_617d0_row2_col36, #T_617d0_row2_col37, #T_617d0_row2_col38, #T_617d0_row2_col39, #T_617d0_row2_col40, #T_617d0_row2_col41, #T_617d0_row2_col42, #T_617d0_row2_col43, #T_617d0_row2_col44, #T_617d0_row2_col45, #T_617d0_row2_col46, #T_617d0_row2_col47, #T_617d0_row2_col48, #T_617d0_row2_col49, #T_617d0_row2_col50, #T_617d0_row2_col51, #T_617d0_row2_col52, #T_617d0_row2_col53, #T_617d0_row2_col54, #T_617d0_row2_col55, #T_617d0_row3_col0, #T_617d0_row3_col1, #T_617d0_row3_col2, #T_617d0_row3_col3, #T_617d0_row3_col4, #T_617d0_row3_col5, #T_617d0_row3_col6, #T_617d0_row3_col7, #T_617d0_row3_col8, #T_617d0_row3_col9, #T_617d0_row3_col10, #T_617d0_row3_col11, #T_617d0_row3_col12, #T_617d0_row3_col13, #T_617d0_row3_col14, #T_617d0_row3_col15, #T_617d0_row3_col16, #T_617d0_row3_col17, #T_617d0_row3_col18, #T_617d0_row3_col19, #T_617d0_row3_col20, #T_617d0_row3_col21, #T_617d0_row3_col22, #T_617d0_row3_col23, #T_617d0 ...
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_617d0" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_617d0_level0_col0" class="col_heading level0 col0" >Status</th>
#       <th id="T_617d0_level0_col1" class="col_heading level0 col1" >DH_total_danos_humanos</th>
#       <th id="T_617d0_level0_col2" class="col_heading level0 col2" >DM_total_danos_materiais</th>
#       <th id="T_617d0_level0_col3" class="col_heading level0 col3" >PEPL_total_publico</th>
#       <th id="T_617d0_level0_col4" class="col_heading level0 col4" >PEPR_total_privado</th>
#       <th id="T_617d0_level0_col5" class="col_heading level0 col5" >regiao_Centro-oeste</th>
#       <th id="T_617d0_level0_col6" class="col_heading level0 col6" >regiao_Nordeste</th>
#       <th id="T_617d0_level0_col7" class="col_heading level0 col7" >regiao_Norte</th>
#       <th id="T_617d0_level0_col8" class="col_heading level0 col8" >regiao_Sudeste</th>
#       <th id="T_617d0_level0_col9" class="col_heading level0 col9" >regiao_Sul</th>
#       <th id="T_617d0_level0_col10" class="col_heading level0 col10" >COBRADE_11110</th>
#       <th id="T_617d0_level0_col11" class="col_heading level0 col11" >COBRADE_11120</th>
#       <th id="T_617d0_level0_col12" class="col_heading level0 col12" >COBRADE_11311</th>
#       <th id="T_617d0_level0_col13" class="col_heading level0 col13" >COBRADE_11312</th>
#       <th id="T_617d0_level0_col14" class="col_heading level0 col14" >COBRADE_11313</th>
#       <th id="T_617d0_level0_col15" class="col_headi

# %%
# Remover linhas com dados ausentes
df_eventos_2010_2017_modelo1 = df_eventos_2010_2017_modelo1.dropna()
estilo_tabelas(df_eventos_2010_2017_modelo1.head(5))

# Remover registros em que todos os dados informados são nulos
df_eventos_2010_2017_modelo1 = df_eventos_2010_2017_modelo1[
    ~((df_eventos_2010_2017_modelo1['DH_total_danos_humanos'] == 0) &
      (df_eventos_2010_2017_modelo1['DM_total_danos_materiais'] == 0) &
      (df_eventos_2010_2017_modelo1['PEPL_total_publico'] == 0) &
      (df_eventos_2010_2017_modelo1['PEPR_total_privado'] == 0))
]

# %%
# Dimensões do dataset
status_counts = df_eventos_2010_2017_modelo1['Status'].value_counts()
print("\nContagem da variável 'Status':")
status_counts.index=['Reconhecido', 'Não Reconhecido']
display(status_counts)

# %% [markdown]
# ## Modelo Sem Balanceamento

# %%
# Divisão em Dados de Treino e Teste
df_eventos_2010_2017_modelo1 = df_eventos_2010_2017_modelo1.sample(frac=1, random_state=42).reset_index(drop=True, inplace=False)
X_2010_2017_modelo1 = df_eventos_2010_2017_modelo1.drop('Status', axis=1)
y_2010_2017_modelo1 = df_eventos_2010_2017_modelo1['Status']
X_train_2010_2017_modelo1, X_test_2010_2017_modelo1, y_train_2010_2017_modelo1, y_test_2010_2017_modelo1 = train_test_split(X_2010_2017_modelo1, y_2010_2017_modelo1, test_size = 0.2, random_state = 42, stratify = y_2010_2017_modelo1)

# Dimensões do dataset de treino
status_counts = y_train_2010_2017_modelo1.value_counts()
print("\nDimensões do dataset de treino:")
status_counts.index=['Reconhecido', 'Não Reconhecido']
display(status_counts)

# Dimensões do dataset de teste
status_counts = y_test_2010_2017_modelo1.value_counts()
print("\nDimensões do dataset de teste:")
status_counts.index=['Reconhecido', 'Não Reconhecido']
display(status_counts)
# Out:
# Dimensões do dataset de treino:
# Reconhecido        7324
# Não Reconhecido     876
# Name: count, dtype: int64
# Dimensões do dataset de teste:
# Reconhecido        1832
# Não Reconhecido     219
# Name: count, dtype: int64

# %%
# Treinamento

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'rf_class_0__criterion': ['gini', 'entropy'],
    'rf_class_0__n_estimators': [150, 175, 200, 225, 250, 300],
    'rf_class_0__max_depth': [2, 4, 6, 8],
    'rf_class_0__min_samples_split': [2, 5, 10, 15, 100],
    'rf_class_0__min_samples_leaf': [1, 2, 5, 10],
    'rf_class_0__max_features': ['sqrt', 'log2', None]
}

# Criar pipeline com RobustScaler e RandomForestClassifier
pipeline_rf_class_0 = Pipeline([
    ('scaler', RobustScaler()),
    ('rf_class_0', RandomForestClassifier(random_state = 42))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_rf_class_0 = BayesSearchCV(
    pipeline_rf_class_0,
    search_spaces = param_grid_bayes,
    n_iter = 30,
    cv = 5,
    scoring = 'f1_weighted',
    n_jobs = 1,
    random_state = 42
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_rf_class_0.fit(X_train_2010_2017_modelo1, y_train_2010_2017_modelo1)

# Melhor modelo encontrado
best_rf_class_0_model = bayes_search_rf_class_0.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_rf_class_0.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_rf_class_0 = best_rf_class_0_model.predict(X_test_2010_2017_modelo1)

# Relatório de classificação
classification_report_rf_class_0 = metrics.classification_report(y_test_2010_2017_modelo1, y_pred_rf_class_0, digits=6, target_names=['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest: \n')
print(classification_report_rf_class_0)
# Out:
# Melhores hiperparâmetros: OrderedDict([('rf_class_0__criterion', 'gini'), ('rf_class_0__max_depth', 8), ('rf_class_0__max_features', None), ('rf_class_0__min_samples_leaf', 2), ('rf_class_0__min_samples_split', 2), ('rf_class_0__n_estimators', 175)])
#
#  Classification report para Random Forest:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.800000  0.054795  0.102564       219
#     Reconhecido   0.898330  0.998362  0.945708      1832
#
#        accuracy                       0.897611      2051
#       macro avg   0.849165  0.526578  0.524136      2051
#    weighted avg   0.887831  0.897611  0.855680      2051

# %%
# Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(best_rf_class_0_model, X_test_2010_2017_modelo1, y_test_2010_2017_modelo1, values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido'])

# %% [markdown]
# ## Balanceamento de Dados com SMOTE

# %%
# Divisão em Dados de Treino e Teste
X_smote = df_eventos_2010_2017_modelo1.drop('Status', axis=1)
y_smote = df_eventos_2010_2017_modelo1['Status']
X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, y_smote, test_size = 0.2, random_state = 42, stratify = y_smote)

# %%
# Aplicar SMOTE apenas no conjunto de treino
smote = SMOTE(random_state = 42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_smote, y_train_smote)

# %%
# Treinamento

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'rf_class_1__criterion': ['gini', 'entropy'],
    'rf_class_1__n_estimators': [150, 175, 200, 225, 250, 300],
    'rf_class_1__max_depth': [2, 4, 6, 8],
    'rf_class_1__min_samples_split': [2, 5, 10, 15, 100],
    'rf_class_1__min_samples_leaf': [1, 2, 5, 10],
    'rf_class_1__max_features': ['sqrt', 'log2', None]
}

# Criar pipeline com RobustScaler e RandomForestClassifier
pipeline_rf_class_1 = Pipeline([
    ('scaler', RobustScaler()),
    ('rf_class_1', RandomForestClassifier(random_state = 42))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_rf_class_1 = BayesSearchCV(
    pipeline_rf_class_1,
    search_spaces = param_grid_bayes,
    n_iter = 30,
    cv = 5,
    scoring = 'f1_weighted',
    n_jobs = 1,
    random_state = 42
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_rf_class_1.fit(X_train_smote, y_train_smote)

# Melhor modelo encontrado
best_rf_class_1_model = bayes_search_rf_class_1.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_rf_class_1.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_rf_class_1 = best_rf_class_1_model.predict(X_test_smote)

# Relatório de classificação
classification_report_rf_class_1 = metrics.classification_report(y_test_smote, y_pred_rf_class_1, digits=6, target_names=['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest com SMOTE: \n')
print(classification_report_rf_class_1)
# Out:
# Melhores hiperparâmetros: OrderedDict([('rf_class_1__criterion', 'gini'), ('rf_class_1__max_depth', 8), ('rf_class_1__max_features', 'sqrt'), ('rf_class_1__min_samples_leaf', 1), ('rf_class_1__min_samples_split', 5), ('rf_class_1__n_estimators', 225)])
#
#  Classification report para Random Forest com SMOTE:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.389937  0.283105  0.328042       219
#     Reconhecido   0.917019  0.947052  0.931794      1832
#
#        accuracy                       0.876158      2051
#       macro avg   0.653478  0.615079  0.629918      2051
#    weighted avg   0.860739  0.876158  0.867327      2051

# %%
# Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(best_rf_class_1_model, X_test_smote, y_test_smote, values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido'])

# %% [markdown]
# ## Avaliação das Variáveis de Importância
# Avaliação das variáveis de importância de acordo com o modelo desbalanceado,  que apresentou o maior f1-score.

# %%
# Passo intermediário
X_train     = X_train_2010_2017_modelo1
y_train     = y_train_2010_2017_modelo1
X_test      = X_test_2010_2017_modelo1
y_test      = y_test_2010_2017_modelo1
model_type  = 'rf_class_0'
best_model  = best_rf_class_0_model

# Ajustar o melhor modelo encontrado (depois da busca bayesiana)
best_model.named_steps[model_type].fit(X_train, y_train)

# Obter a importância das features
importance_dict = {}
for feature, importance in zip(X_train.columns, best_model.named_steps[model_type].feature_importances_):
    importance_dict[feature] = importance
#importance_dict

# Transformar em DataFrame para organizar como tabela
importance_df = pd.DataFrame({
    'Feature': list(importance_dict.keys()),
    'Importance': list(importance_dict.values())
})

# Ordenar pela importância em ordem decrescente
importance_df = importance_df.sort_values(by='Importance', ascending=False)
estilo_tabelas(importance_df.head(10))
# Out:
# <style type="text/css">
# #T_1b7ac thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_1b7ac td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_1b7ac tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_1b7ac table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_1b7ac td {
#   border: 1px solid #666;
# }
# #T_1b7ac  th {
#   border: 1px solid #666;
# }
# #T_1b7ac_row0_col0, #T_1b7ac_row0_col1, #T_1b7ac_row1_col0, #T_1b7ac_row1_col1, #T_1b7ac_row2_col0, #T_1b7ac_row2_col1, #T_1b7ac_row3_col0, #T_1b7ac_row3_col1, #T_1b7ac_row4_col0, #T_1b7ac_row4_col1, #T_1b7ac_row5_col0, #T_1b7ac_row5_col1, #T_1b7ac_row6_col0, #T_1b7ac_row6_col1, #T_1b7ac_row7_col0, #T_1b7ac_row7_col1, #T_1b7ac_row8_col0, #T_1b7ac_row8_col1, #T_1b7ac_row9_col0, #T_1b7ac_row9_col1 {
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_1b7ac" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b7ac_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_1b7ac_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b7ac_level0_row0" class="row_heading level0 row0" >54</th>
#       <td id="T_1b7ac_row0_col0" class="data row0 col0" >Rendapercapita</td>
#       <td id="T_1b7ac_row0_col1" class="data row0 col1" >0.193</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_1b7ac_row1_col0" class="data row1 col0" >DH_total_danos_humanos</td>
#       <td id="T_1b7ac_row1_col1" class="data row1 col1" >0.169</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1b7ac_row2_col0" class="data row2 col0" >PEPR_total_privado</td>
#       <td id="T_1b7ac_row2_col1" class="data row2 col1" >0.161</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_1b7ac_row3_col0" class="data row3 col0" >PEPL_total_publico</td>
#       <td id="T_1b7ac_row3_col1" class="data row3 col1" >0.104</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_1b7ac_row4_col0" class="data row4 col0" >DM_total_danos_materiais</td>
#       <td id="T_1b7ac_row4_col1" class="data row4 col1" >0.094</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_1b7ac_row5_col0" class="data row5 col0" >regiao_Sul</td>
#       <td id="T_1b7ac_row5_col1" class="data row5 col1" >0.041</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row6" class="row_heading level0 row6" >40</th>
#       <td id="T_1b7ac_row6_col0" class="data row6 col0" >COBRADE_14132</td>
#       <td id="T_1b7ac_row6_col1" class="data row6 col1" >0.034</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row7" class="row_heading level0 row7" >5</th>
#       <td id="T_1b7ac_row7_col0" class="data row7 col0" >regiao_Nordeste</td>
#       <td id="T_1b7ac_row7_col1" class="data row7 col1" >0.030</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row8" class="row_heading level0 row8" >32</th>
#       <td id="T_1b7ac_row8_col0" class="data row8 col0" >COBRADE_13214</td>
#       <td id="T_1b7ac_row8_col1" class="data row8 col1" >0.030</td>
#     </tr>
#     <tr>
#       <th id="T_1b7ac_level0_row9" class="row_heading level0 row9" >6</th>
#       <td id="T_1b7ac_row9_col0" class="data row9 col0" >regiao_Norte</td>
#       <td id="T_1b7ac_row9_col1" class="data row9 col1" >0.025</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calcular os resultados (permutation_importance) da queda no desempenho do modelo ao embaralhar cada uma das variáveis.
result = permutation_importance(best_model, X_test, y_test, n_repeats=100, random_state = 42, n_jobs = -1)

# Ordenar os resultados
sorted_idx = result.importances_mean.argsort()

# Gráfico boxplot pra mostrar a importância das variáveis
fig, ax = plt.subplots()
ax.boxplot(result.importances[sorted_idx].T, vert=False, labels=X_test.columns[sorted_idx])
ax.set_title("Permutation Importances (test set)")
fig.set_size_inches(15, 20)
fig.tight_layout()
plt.show()
# Out:
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /var/folders/cj/_95ntbkj60b_pjvf32tvsh2h0000gn/T/ipykernel_1224/3097555738.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
