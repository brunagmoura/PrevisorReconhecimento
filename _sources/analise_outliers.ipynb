# %% [markdown]
# ## Análise outliers

# %% [markdown]
# ### Bibliotecas e base de dados

# %%
#Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
from scipy import stats

#Estilizar conteúdo
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def estilo_tabelas(df_eventos, max_altura='300px', casas_decimais=2):
    return (
        df_eventos.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        ).format(
            precision=casas_decimais  
        )
    )

object_columns = ['Protocolo_S2iD', 'Nome_Municipio', 'Sigla_UF', 'regiao',
                  'Setores Censitários', 'Status', 'DH_Descricao', 'DM_Descricao',
                  'DA_Descricao', 'DA_Polui/cont da água', 'DA_Polui/cont do ar',
                  'DA_Polui/cont do solo', 'DA_Dimi/exauri hídrico',
                  "DA_Incêndi parques/APA's/APP's", 'PEPL_Descricao', 'PEPR_Descricao',
                  'Categoria', 'Grupo', 'Subgrupo', 'Tipo', 'Subtipo']

dtype = {col: 'object' for col in object_columns}

df_eventos = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_desastres_rec_nrec.csv",
    sep=';',
    dtype = dtype,
    decimal=',',
)

estilo_tabelas(df_eventos.head(5))
# Out:
# <style type="text/css">
# #T_b60b2 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_b60b2 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_b60b2 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_b60b2 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_b60b2 td {
#   border: 1px solid #666;
# }
# #T_b60b2  th {
#   border: 1px solid #666;
# }
# #T_b60b2_row0_col0, #T_b60b2_row0_col1, #T_b60b2_row0_col2, #T_b60b2_row0_col3, #T_b60b2_row0_col4, #T_b60b2_row0_col5, #T_b60b2_row0_col6, #T_b60b2_row0_col7, #T_b60b2_row0_col8, #T_b60b2_row0_col9, #T_b60b2_row0_col10, #T_b60b2_row0_col11, #T_b60b2_row0_col12, #T_b60b2_row0_col13, #T_b60b2_row0_col14, #T_b60b2_row0_col15, #T_b60b2_row0_col16, #T_b60b2_row0_col17, #T_b60b2_row0_col18, #T_b60b2_row0_col19, #T_b60b2_row0_col20, #T_b60b2_row0_col21, #T_b60b2_row0_col22, #T_b60b2_row0_col23, #T_b60b2_row0_col24, #T_b60b2_row0_col25, #T_b60b2_row0_col26, #T_b60b2_row0_col27, #T_b60b2_row0_col28, #T_b60b2_row0_col29, #T_b60b2_row0_col30, #T_b60b2_row0_col31, #T_b60b2_row0_col32, #T_b60b2_row0_col33, #T_b60b2_row0_col34, #T_b60b2_row0_col35, #T_b60b2_row0_col36, #T_b60b2_row0_col37, #T_b60b2_row0_col38, #T_b60b2_row0_col39, #T_b60b2_row0_col40, #T_b60b2_row0_col41, #T_b60b2_row0_col42, #T_b60b2_row0_col43, #T_b60b2_row0_col44, #T_b60b2_row0_col45, #T_b60b2_row0_col46, #T_b60b2_row0_col47, #T_b60b2_row0_col48, #T_b60b2_row0_col49, #T_b60b2_row0_col50, #T_b60b2_row0_col51, #T_b60b2_row0_col52, #T_b60b2_row0_col53, #T_b60b2_row0_col54, #T_b60b2_row0_col55, #T_b60b2_row0_col56, #T_b60b2_row0_col57, #T_b60b2_row0_col58, #T_b60b2_row0_col59, #T_b60b2_row0_col60, #T_b60b2_row0_col61, #T_b60b2_row0_col62, #T_b60b2_row0_col63, #T_b60b2_row0_col64, #T_b60b2_row0_col65, #T_b60b2_row0_col66, #T_b60b2_row0_col67, #T_b60b2_row0_col68, #T_b60b2_row0_col69, #T_b60b2_row0_col70, #T_b60b2_row0_col71, #T_b60b2_row0_col72, #T_b60b2_row0_col73, #T_b60b2_row0_col74, #T_b60b2_row0_col75, #T_b60b2_row0_col76, #T_b60b2_row0_col77, #T_b60b2_row0_col78, #T_b60b2_row0_col79, #T_b60b2_row0_col80, #T_b60b2_row0_col81, #T_b60b2_row0_col82, #T_b60b2_row0_col83, #T_b60b2_row1_col0, #T_b60b2_row1_col1, #T_b60b2_row1_col2, #T_b60b2_row1_col3, #T_b60b2_row1_col4, #T_b60b2_row1_col5, #T_b60b2_row1_col6, #T_b60b2_row1_col7, #T_b60b2_row1_col8, #T_b60b2_row1_col9, #T_b60b2_row1_col10, #T_b60b2_row1_col11, #T_b60b2_row1_col12, #T_b60b2_row1_col13, #T_b60b2_row1_col14, #T_b60b2_row1_col15, #T_b60b2_row1_col16, #T_b60b2_row1_col17, #T_b60b2_row1_col18, #T_b60b2_row1_col19, #T_b60b2_row1_col20, #T_b60b2_row1_col21, #T_b60b2_row1_col22, #T_b60b2_row1_col23, #T_b60b2_row1_col24, #T_b60b2_row1_col25, #T_b60b2_row1_col26, #T_b60b2_row1_col27, #T_b60b2_row1_col28, #T_b60b2_row1_col29, #T_b60b2_row1_col30, #T_b60b2_row1_col31, #T_b60b2_row1_col32, #T_b60b2_row1_col33, #T_b60b2_row1_col34, #T_b60b2_row1_col35, #T_b60b2_row1_col36, #T_b60b2_row1_col37, #T_b60b2_row1_col38, #T_b60b2_row1_col39, #T_b60b2_row1_col40, #T_b60b2_row1_col41, #T_b60b2_row1_col42, #T_b60b2_row1_col43, #T_b60b2_row1_col44, #T_b60b2_row1_col45, #T_b60b2_row1_col46, #T_b60b2_row1_col47, #T_b60b2_row1_col48, #T_b60b2_row1_col49, #T_b60b2_row1_col50, #T_b60b2_row1_col51, #T_b60b2_row1_col52, #T_b60b2_row1_col53, #T_b60b2_row1_col54, #T_b60b2_row1_col55, #T_b60b2_row1_col56, #T_b60b2_row1_col57, #T_b60b2_row1_col58, #T_b60b2_row1_col59, #T_b60b2_row1_col60, #T_b60b2_row1_col61, #T_b60b2_row1_col62, #T_b60b2_row1_col63, #T_b60b2_row1_col64, #T_b60b2_row1_col65, #T_b60b2_row1_col66, #T_b60b2_row1_col67, #T_b60b2_row1_col68, #T_b60b2_row1_col69, #T_b60b2_row1_col70, #T_b60b2_row1_col71, #T_b60b2_row1_col72, #T_b60b2_row1_col73, #T_b60b2_row1_col74, #T_b60b2_row1_col75, #T_b60b2_row1_col76, #T_b60b2_row1_col77, #T_b60b2_row1_col78, #T_b60b2_row1_col79, #T_b60b2_row1_col80, #T_b60b2_row1_col81, #T_b60b2_row1_col82, #T_b60b2_row1_col83, #T_b60b2_row2_col0, #T_b60b2_row2_col1, #T_b60b2_row2_col2, #T_b60b2_row2_col3, #T_b60b2_row2_col4, #T_b60b2_row2_col5, #T_b60b2_row2_col6, #T_b60b2_row2_col7, #T_b60b2_row2_col8, #T_b60b2_row2_col9, #T_b60b2_row2_col10, #T_b60b2_row2_col11, #T_b60b2_row2_col12, #T_b60b2_row2_col13, #T_b60b2_row2_col14, #T_b60b2_row2_col15, #T_b60b2_row2_col16, #T_b60b2_row2_col17, #T_b60b2_row2_col18, #T_b60b2_row2_col19, #T_b60b2_row2_col20, #T_b60b2_row2_col21, #T_b60b2_row2_col22, #T_b60b2_row2_col23 ...

# %% [markdown]
# ### Box-plot

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Ajustando o estilo
sns.set_style("whitegrid")

# Criando os boxplots com Seaborn
sns.boxplot(data=df_eventos[['DH_total_danos_humanos']], ax=axes[0, 0], color='#1f77b4')
axes[0, 0].set_title('Danos Humanos')
axes[0, 0].set_ylabel('Valores (Qtde.)')

sns.boxplot(data=df_eventos[['DM_total_danos_materiais']], ax=axes[0, 1], color='#1f78b4')
axes[0, 1].set_title('Danos Materiais')

sns.boxplot(data=df_eventos[['PEPL_total_publico']], ax=axes[1, 0], color='#4a85b6')
axes[1, 0].set_title('Prejuízo público')
axes[1, 0].set_ylabel('Valores (R$)')

sns.boxplot(data=df_eventos[['PEPR_total_privado']], ax=axes[1, 1], color='#87c1ea')
axes[1, 1].set_title('Prejuízo privado')

# Removendo notação científica em todos os subplots
for ax in axes.flat:
    ax.ticklabel_format(style='plain', axis='y')

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Z-Score

# %%
colunas = ['DH_total_danos_humanos', 'DM_total_danos_materiais', 'PEPL_total_publico', 'PEPR_total_privado',
           'DH_MORTOS', 'DH_FERIDOS', 'DH_ENFERMOS',
       'DH_DESABRIGADOS', 'DH_DESALOJADOS', 'DH_DESAPARECIDOS',
       'DH_OUTROS AFETADOS', 'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas',
       'DM_Uni Habita Valor', 'DM_Inst Saúde Danificadas',
       'DM_Inst Saúde Destruidas', 'DM_Inst Saúde Valor',
       'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas',
       'DM_Inst Ensino Valor', 'DM_Inst Serviços Danificadas',
       'DM_Inst Serviços Destruidas', 'DM_Inst Serviços Valor',
       'DM_Inst Comuni Danificadas', 'DM_Inst Comuni Destruidas',
       'DM_Inst Comuni Valor', 'DM_Obras de Infra Danificadas',
       'DM_Obras de Infra Destruidas', 'DM_Obras de Infra Valor','PEPL_Assis_méd e emergên(R$)',
       'PEPL_Abast de água pot(R$)', 'PEPL_sist de esgotos sanit(R$)',
       'PEPL_Sis limp e rec lixo (R$)', 'PEPL_Sis cont pragas (R$)',
       'PEPL_distrib energia (R$)', 'PEPL_Telecomunicações (R$)',
       'PEPL_Tran loc/reg/l_curso (R$)', 'PEPL_Distrib combustíveis(R$)',
       'PEPL_Segurança pública (R$)', 'PEPL_Ensino (R$)']

# Calculando o z-score para cada coluna
df_zscores = df_eventos[colunas].apply(lambda col: stats.zscore(col))

# Identificando outliers (z-score > 3 ou z-score < -3)
outliers = (df_zscores > 3) | (df_zscores < -3)

# Contando o número de outliers em cada coluna
contagem_outliers = outliers.sum()

# Exibindo o resultado
contagem_outliers_df = pd.DataFrame(contagem_outliers, columns=['Número de Outliers'])

estilo_tabelas(contagem_outliers_df.sort_values(by = 'Número de Outliers', ascending = False))
# Out:
# <style type="text/css">
# #T_1ed66 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_1ed66 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_1ed66 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_1ed66 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_1ed66 td {
#   border: 1px solid #666;
# }
# #T_1ed66  th {
#   border: 1px solid #666;
# }
# #T_1ed66_row0_col0, #T_1ed66_row1_col0, #T_1ed66_row2_col0, #T_1ed66_row3_col0, #T_1ed66_row4_col0, #T_1ed66_row5_col0, #T_1ed66_row6_col0, #T_1ed66_row7_col0, #T_1ed66_row8_col0, #T_1ed66_row9_col0, #T_1ed66_row10_col0, #T_1ed66_row11_col0, #T_1ed66_row12_col0, #T_1ed66_row13_col0, #T_1ed66_row14_col0, #T_1ed66_row15_col0, #T_1ed66_row16_col0, #T_1ed66_row17_col0, #T_1ed66_row18_col0, #T_1ed66_row19_col0, #T_1ed66_row20_col0, #T_1ed66_row21_col0, #T_1ed66_row22_col0, #T_1ed66_row23_col0, #T_1ed66_row24_col0, #T_1ed66_row25_col0, #T_1ed66_row26_col0, #T_1ed66_row27_col0, #T_1ed66_row28_col0, #T_1ed66_row29_col0, #T_1ed66_row30_col0, #T_1ed66_row31_col0, #T_1ed66_row32_col0, #T_1ed66_row33_col0, #T_1ed66_row34_col0, #T_1ed66_row35_col0, #T_1ed66_row36_col0, #T_1ed66_row37_col0, #T_1ed66_row38_col0, #T_1ed66_row39_col0 {
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_1ed66" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ed66_level0_col0" class="col_heading level0 col0" >Número de Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ed66_level0_row0" class="row_heading level0 row0" >DM_Inst Ensino Danificadas</th>
#       <td id="T_1ed66_row0_col0" class="data row0 col0" >350</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row1" class="row_heading level0 row1" >DH_DESALOJADOS</th>
#       <td id="T_1ed66_row1_col0" class="data row1 col0" >231</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row2" class="row_heading level0 row2" >DM_Inst Serviços Destruidas</th>
#       <td id="T_1ed66_row2_col0" class="data row2 col0" >183</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row3" class="row_heading level0 row3" >DM_Inst Ensino Destruidas</th>
#       <td id="T_1ed66_row3_col0" class="data row3 col0" >172</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row4" class="row_heading level0 row4" >DH_ENFERMOS</th>
#       <td id="T_1ed66_row4_col0" class="data row4 col0" >157</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row5" class="row_heading level0 row5" >DM_Uni Habita Danificadas</th>
#       <td id="T_1ed66_row5_col0" class="data row5 col0" >155</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row6" class="row_heading level0 row6" >PEPL_distrib energia (R$)</th>
#       <td id="T_1ed66_row6_col0" class="data row6 col0" >150</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row7" class="row_heading level0 row7" >DH_OUTROS AFETADOS</th>
#       <td id="T_1ed66_row7_col0" class="data row7 col0" >143</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row8" class="row_heading level0 row8" >DH_total_danos_humanos</th>
#       <td id="T_1ed66_row8_col0" class="data row8 col0" >140</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row9" class="row_heading level0 row9" >PEPL_Ensino (R$)</th>
#       <td id="T_1ed66_row9_col0" class="data row9 col0" >138</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row10" class="row_heading level0 row10" >DM_Inst Serviços Danificadas</th>
#       <td id="T_1ed66_row10_col0" class="data row10 col0" >135</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row11" class="row_heading level0 row11" >DH_DESABRIGADOS</th>
#       <td id="T_1ed66_row11_col0" class="data row11 col0" >134</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row12" class="row_heading level0 row12" >PEPL_total_publico</th>
#       <td id="T_1ed66_row12_col0" class="data row12 col0" >127</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row13" class="row_heading level0 row13" >PEPL_Sis limp e rec lixo (R$)</th>
#       <td id="T_1ed66_row13_col0" class="data row13 col0" >119</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row14" class="row_heading level0 row14" >PEPL_Tran loc/reg/l_curso (R$)</th>
#       <td id="T_1ed66_row14_col0" class="data row14 col0" >104</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row15" class="row_heading level0 row15" >PEPR_total_privado</th>
#       <td id="T_1ed66_row15_col0" class="data row15 col0" >97</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row16" class="row_heading level0 row16" >DM_Obras de Infra Valor</th>
#       <td id="T_1ed66_row16_col0" class="data row16 col0" >97</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row17" class="row_heading level0 row17" >PEPL_Abast de água pot(R$)</th>
#       <td id="T_1ed66_row17_col0" class="data row17 col0" >96</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row18" class="row_heading level0 row18" >DM_Inst Saúde Destruidas</th>
#       <td id="T_1ed66_row18_col0" class="data row18 col0" >91</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row19" class="row_heading level0 row19" >DM_Inst Saúde Valor</th>
#       <td id="T_1ed66_row19_col0" class="data row19 col0" >91</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row20" class="row_heading level0 row20" >DM_Inst Ensino Valor</th>
#       <td id="T_1ed66_row20_col0" class="data row20 col0" >85</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row21" class="row_heading level0 row21" >DM_Inst Comuni Valor</th>
#       <td id="T_1ed66_row21_col0" class="data row21 col0" >81</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row22" class="row_heading level0 row22" >PEPL_Assis_méd e emergên(R$)</th>
#       <td id="T_1ed66_row22_col0" class="data row22 col0" >65</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row23" class="row_heading level0 row23" >DM_Inst Saúde Danificadas</th>
#       <td id="T_1ed66_row23_col0" class="data row23 col0" >60</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row24" class="row_heading level0 row24" >PEPL_Sis cont pragas (R$)</th>
#       <td id="T_1ed66_row24_col0" class="data row24 col0" >51</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row25" class="row_heading level0 row25" >PEPL_sist de esgotos sanit(R$)</th>
#       <td id="T_1ed66_row25_col0" class="data row25 col0" >47</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row26" class="row_heading level0 row26" >DH_FERIDOS</th>
#       <td id="T_1ed66_row26_col0" class="data row26 col0" >46</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row27" class="row_heading level0 row27" >DM_Uni Habita Destruidas</th>
#       <td id="T_1ed66_row27_col0" class="data row27 col0" >42</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row28" class="row_heading level0 row28" >PEPL_Telecomunicações (R$)</th>
#       <td id="T_1ed66_row28_col0" class="data row28 col0" >40</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row29" class="row_heading level0 row29" >DM_total_danos_materiais</th>
#       <td id="T_1ed66_row29_col0" class="data row29 col0" >35</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row30" class="row_heading level0 row30" >PEPL_Distrib combustíveis(R$)</th>
#       <td id="T_1ed66_row30_col0" class="data row30 col0" >34</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row31" class="row_heading level0 row31" >DM_Inst Serviços Valor</th>
#       <td id="T_1ed66_row31_col0" class="data row31 col0" >25</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row32" class="row_heading level0 row32" >DM_Inst Comuni Danificadas</th>
#       <td id="T_1ed66_row32_col0" class="data row32 col0" >25</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_level0_row33" class="row_heading level0 row33" >DH_MORTOS</th>
#       <td id="T_1ed66_row33_col0" class="data row33 col0" >25</td>
#     </tr>
#     <tr>
#       <th id="T_1ed66_l

# %% [markdown]
# Dado que uma grande quantidade de outliers foi identificada, o uso de técnicas de padronização tradicionais, como o z-score (que assume uma distribuição normal dos dados), pode não ser o método ideal para bases de dados com muitos outliers. Nesses casos, é recomendável utilizar métodos de robustez que sejam menos sensíveis a valores extremos.
