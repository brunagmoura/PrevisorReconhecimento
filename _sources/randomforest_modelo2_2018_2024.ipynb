# %% [markdown]
# # Floresta Aleatória
# **Variáveis Desagregadas (2018-2024)** \\
#  \\
# Bootcamp Machine Learning ENAP 2024 \\
# Maurício Marques Soares Filho \\
# 25/10/2024 \\

# %% [markdown]
# ## Imports...

# %%
###
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import dtreeviz

###
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.inspection import permutation_importance

###
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from collections import Counter

###
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, GridSearchCV

###
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier


###
from sklearn.pipeline import Pipeline
from skopt import BayesSearchCV

###
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Pré-processamento dos dados

# %%
#Estilizar conteúdo
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

def estilo_tabelas(df, max_altura = '300px', casas_decimais = 3):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},  # Bordas cinza escuro
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style = "height:auto; overflow:auto; max-height:{max_altura}; display:block;"'
        ).format(
            precision=casas_decimais
        )
    )

# %%
# Importar a base de dados
df_eventos_2018_2024_modelo2 = pd.read_csv(
     "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2018_2024_modelo2.csv",
    sep = ';',
    decimal = ',',
)

estilo_tabelas(df_eventos_2018_2024_modelo2.head(5))
# Out:
# <style type="text/css">
# #T_b5523 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_b5523 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_b5523 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_b5523 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_b5523 td {
#   border: 1px solid #666;
# }
# #T_b5523  th {
#   border: 1px solid #666;
# }
# #T_b5523_row0_col0, #T_b5523_row0_col1, #T_b5523_row0_col2, #T_b5523_row0_col3, #T_b5523_row0_col4, #T_b5523_row0_col5, #T_b5523_row0_col6, #T_b5523_row0_col7, #T_b5523_row0_col8, #T_b5523_row0_col9, #T_b5523_row0_col10, #T_b5523_row0_col11, #T_b5523_row0_col12, #T_b5523_row0_col13, #T_b5523_row0_col14, #T_b5523_row0_col15, #T_b5523_row0_col16, #T_b5523_row0_col17, #T_b5523_row0_col18, #T_b5523_row0_col19, #T_b5523_row0_col20, #T_b5523_row0_col21, #T_b5523_row0_col22, #T_b5523_row0_col23, #T_b5523_row0_col24, #T_b5523_row0_col25, #T_b5523_row0_col26, #T_b5523_row0_col27, #T_b5523_row0_col28, #T_b5523_row0_col29, #T_b5523_row0_col30, #T_b5523_row0_col31, #T_b5523_row0_col32, #T_b5523_row0_col33, #T_b5523_row0_col34, #T_b5523_row0_col35, #T_b5523_row0_col36, #T_b5523_row0_col37, #T_b5523_row0_col38, #T_b5523_row0_col39, #T_b5523_row0_col40, #T_b5523_row0_col41, #T_b5523_row0_col42, #T_b5523_row0_col43, #T_b5523_row0_col44, #T_b5523_row0_col45, #T_b5523_row0_col46, #T_b5523_row0_col47, #T_b5523_row0_col48, #T_b5523_row0_col49, #T_b5523_row0_col50, #T_b5523_row0_col51, #T_b5523_row0_col52, #T_b5523_row0_col53, #T_b5523_row0_col54, #T_b5523_row0_col55, #T_b5523_row0_col56, #T_b5523_row0_col57, #T_b5523_row0_col58, #T_b5523_row0_col59, #T_b5523_row0_col60, #T_b5523_row0_col61, #T_b5523_row0_col62, #T_b5523_row0_col63, #T_b5523_row0_col64, #T_b5523_row0_col65, #T_b5523_row0_col66, #T_b5523_row0_col67, #T_b5523_row0_col68, #T_b5523_row0_col69, #T_b5523_row0_col70, #T_b5523_row0_col71, #T_b5523_row0_col72, #T_b5523_row0_col73, #T_b5523_row0_col74, #T_b5523_row0_col75, #T_b5523_row0_col76, #T_b5523_row0_col77, #T_b5523_row0_col78, #T_b5523_row0_col79, #T_b5523_row0_col80, #T_b5523_row0_col81, #T_b5523_row0_col82, #T_b5523_row0_col83, #T_b5523_row0_col84, #T_b5523_row0_col85, #T_b5523_row0_col86, #T_b5523_row0_col87, #T_b5523_row0_col88, #T_b5523_row0_col89, #T_b5523_row0_col90, #T_b5523_row0_col91, #T_b5523_row0_col92, #T_b5523_row0_col93, #T_b5523_row0_col94, #T_b5523_row0_col95, #T_b5523_row0_col96, #T_b5523_row0_col97, #T_b5523_row0_col98, #T_b5523_row0_col99, #T_b5523_row0_col100, #T_b5523_row0_col101, #T_b5523_row0_col102, #T_b5523_row0_col103, #T_b5523_row0_col104, #T_b5523_row0_col105, #T_b5523_row0_col106, #T_b5523_row0_col107, #T_b5523_row0_col108, #T_b5523_row0_col109, #T_b5523_row0_col110, #T_b5523_row0_col111, #T_b5523_row0_col112, #T_b5523_row0_col113, #T_b5523_row0_col114, #T_b5523_row0_col115, #T_b5523_row0_col116, #T_b5523_row0_col117, #T_b5523_row0_col118, #T_b5523_row0_col119, #T_b5523_row0_col120, #T_b5523_row0_col121, #T_b5523_row1_col0, #T_b5523_row1_col1, #T_b5523_row1_col2, #T_b5523_row1_col3, #T_b5523_row1_col4, #T_b5523_row1_col5, #T_b5523_row1_col6, #T_b5523_row1_col7, #T_b5523_row1_col8, #T_b5523_row1_col9, #T_b5523_row1_col10, #T_b5523_row1_col11, #T_b5523_row1_col12, #T_b5523_row1_col13, #T_b5523_row1_col14, #T_b5523_row1_col15, #T_b5523_row1_col16, #T_b5523_row1_col17, #T_b5523_row1_col18, #T_b5523_row1_col19, #T_b5523_row1_col20, #T_b5523_row1_col21, #T_b5523_row1_col22, #T_b5523_row1_col23, #T_b5523_row1_col24, #T_b5523_row1_col25, #T_b5523_row1_col26, #T_b5523_row1_col27, #T_b5523_row1_col28, #T_b5523_row1_col29, #T_b5523_row1_col30, #T_b5523_row1_col31, #T_b5523_row1_col32, #T_b5523_row1_col33, #T_b5523_row1_col34, #T_b5523_row1_col35, #T_b5523_row1_col36, #T_b5523_row1_col37, #T_b5523_row1_col38, #T_b5523_row1_col39, #T_b5523_row1_col40, #T_b5523_row1_col41, #T_b5523_row1_col42, #T_b5523_row1_col43, #T_b5523_row1_col44, #T_b5523_row1_col45, #T_b5523_row1_col46, #T_b5523_row1_col47, #T_b5523_row1_col48, #T_b5523_row1_col49, #T_b5523_row1_col50, #T_b5523_row1_col51, #T_b5523_row1_col52, #T_b5523_row1_col53, #T_b5523_row1_col54, #T_b5523_row1_col55, #T_b5523_row1_col56, #T_b5523_row1_col57, #T_b5523_row1_col58, #T_b5523_row1_col59, #T_b5523_row1_col60, #T_b5523_row1_col61, #T_b5523_row1_col62, #T_b5523_row1_col63, #T_b5523_row1_col64, #T_b5523_row1_col65, #T_b5523_row1_col66, #T_b5523_row1_col67, #T_b5523 ...

# %%
# Remover linhas com dados ausentes
df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.dropna()
estilo_tabelas(df_eventos_2018_2024_modelo2.head(5))

# Remover linhas com todos os dados informados = 0.
colunas_informados = [
    'DH_MORTOS', 'DH_FERIDOS', 'DH_ENFERMOS', 'DH_DESABRIGADOS', 'DH_DESALOJADOS',
    'DH_DESAPARECIDOS', 'DH_OUTROS AFETADOS',
    'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas', 'DM_Uni Habita Valor',
    'DM_Inst Saúde Danificadas', 'DM_Inst Saúde Destruidas', 'DM_Inst Saúde Valor',
    'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas', 'DM_Inst Ensino Valor',
    'DM_Inst Serviços Danificadas', 'DM_Inst Serviços Destruidas', 'DM_Inst Serviços Valor',
    'DM_Inst Comuni Danificadas', 'DM_Inst Comuni Destruidas', 'DM_Inst Comuni Valor',
    'DM_Obras de Infra Danificadas', 'DM_Obras de Infra Destruidas', 'DM_Obras de Infra Valor',
    'PEPL_Assis_méd e emergên(R$)', 'PEPL_Abast de água pot(R$)',
    'PEPL_sist de esgotos sanit(R$)', 'PEPL_Sis limp e rec lixo (R$)', 'PEPL_Sis cont pragas (R$)',
    'PEPL_distrib energia (R$)', 'PEPL_Telecomunicações (R$)', 'PEPL_Tran loc/reg/l_curso (R$)',
    'PEPL_Distrib combustíveis(R$)', 'PEPL_Segurança pública (R$)', 'PEPL_Ensino (R$)',
    'PEPR_Agricultura (R$)', 'PEPR_Pecuária (R$)', 'PEPR_Indústria (R$)', 'PEPR_Comércio (R$)',
    'PEPR_Serviços (R$)'
]

df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2[
    ~(df_eventos_2018_2024_modelo2[colunas_informados] == 0).all(axis=1)
]

# %%
# Dimensões do dataset
status_counts = df_eventos_2018_2024_modelo2['Status'].value_counts()
print("\nContagem da variável 'Status':")
status_counts.index=['Reconhecido', 'Não Reconhecido']
display(status_counts)
# Out:
# Contagem da variável 'Status':
# Reconhecido        7380
# Não Reconhecido     590
# Name: count, dtype: int64

# %% [markdown]
# ## Modelo Sem Balanceamento

# %%
# Divisão em Dados de Treino e Teste
df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.sample(frac = 1, random_state = 42).reset_index(drop = True, inplace = False)
X_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.drop('Status', axis = 1)
y_2018_2024_modelo2 = df_eventos_2018_2024_modelo2['Status']
X_train_2018_2024_modelo2, X_test_2018_2024_modelo2, y_train_2018_2024_modelo2, y_test_2018_2024_modelo2 = train_test_split(X_2018_2024_modelo2, y_2018_2024_modelo2, test_size = 0.2, random_state = 42, stratify = y_2018_2024_modelo2)

# Dimensões do dataset de treino
status_counts = y_train_2018_2024_modelo2.value_counts()
print("\nDimensões do dataset de treino:")
status_counts.index=['Reconhecido', 'Não Reconhecido']
display(status_counts)

# Dimensões do dataset de teste
status_counts = y_test_2018_2024_modelo2.value_counts()
print("\nDimensões do dataset de teste:")
status_counts.index=['Reconhecido', 'Não Reconhecido']
display(status_counts)
# Out:
# Dimensões do dataset de treino:
# Reconhecido        5904
# Não Reconhecido     472
# Name: count, dtype: int64
# Dimensões do dataset de teste:
# Reconhecido        1476
# Não Reconhecido     118
# Name: count, dtype: int64

# %%
# Treinamento

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'rf_class_0__criterion': ['gini', 'entropy'],
    'rf_class_0__n_estimators': [150, 175, 200, 225, 250, 300],
    'rf_class_0__max_depth': [2, 4, 6, 8],
    'rf_class_0__min_samples_split': [2, 5, 10, 15, 100],
    'rf_class_0__min_samples_leaf': [1, 2, 5, 10],
    'rf_class_0__max_features': ['sqrt', 'log2', None]
}

# Criar pipeline com RobustScaler e RandomForestClassifier
pipeline_rf_class_0 = Pipeline([
    ('scaler', RobustScaler()),
    ('rf_class_0', RandomForestClassifier(random_state = 42))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_rf_class_0 = BayesSearchCV(
    pipeline_rf_class_0,
    search_spaces = param_grid_bayes,
    n_iter = 30,
    cv = 5,
    scoring = 'f1_weighted',
    n_jobs = -1,
    random_state = 42
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_rf_class_0.fit(X_train_2018_2024_modelo2, y_train_2018_2024_modelo2)

# Melhor modelo encontrado
best_rf_class_0_model = bayes_search_rf_class_0.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_rf_class_0.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_rf_class_0 = best_rf_class_0_model.predict(X_test_2018_2024_modelo2)

# Relatório de classificação TREINO
classification_report_rf_class_0 = metrics.classification_report(y_train_2018_2024_modelo2, best_rf_class_0_model.predict(X_train_2018_2024_modelo2), digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest [TREINO]: \n')
print(classification_report_rf_class_0)

# Relatório de classificação TESTE
classification_report_rf_class_0 = metrics.classification_report(y_test_2018_2024_modelo2, y_pred_rf_class_0, digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest [TESTE]: \n')
print(classification_report_rf_class_0)
# Out:
# Melhores hiperparâmetros: OrderedDict([('rf_class_0__criterion', 'gini'), ('rf_class_0__max_depth', 8), ('rf_class_0__max_features', None), ('rf_class_0__min_samples_leaf', 1), ('rf_class_0__min_samples_split', 2), ('rf_class_0__n_estimators', 200)])
#
#  Classification report para Random Forest [TREINO]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   1.000000  0.264831  0.418760       472
#     Reconhecido   0.944489  1.000000  0.971452      5904
#
#        accuracy                       0.945577      6376
#       macro avg   0.972244  0.632415  0.695106      6376
#    weighted avg   0.948598  0.945577  0.930538      6376
#
#
#  Classification report para Random Forest [TESTE]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.952381  0.169492  0.287770       118
#     Reconhecido   0.937699  0.999322  0.967530      1476
#
#        accuracy                       0.937892      1594
#       macro avg   0.945040  0.584407  0.627650      1594
#    weighted avg   0.938786  0.937892  0.917209      1594

# %%
# Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(best_rf_class_0_model, X_test_2018_2024_modelo2, y_test_2018_2024_modelo2, values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido'])

# %% [markdown]
# ## Balanceamento de Dados com SMOTE

# %%
# Divisão em Dados de Treino e Teste
X_smote = df_eventos_2018_2024_modelo2.drop('Status', axis=1)
y_smote = df_eventos_2018_2024_modelo2['Status']
X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, y_smote, test_size = 0.2, random_state = 42, stratify = y_smote)

# %%
# Aplicar SMOTE apenas no conjunto de treino
smote = SMOTE(random_state = 42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_smote, y_train_smote)

# %%
# Treinamento

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'rf_class_1__criterion': ['gini', 'entropy'],
    'rf_class_1__n_estimators': [150, 175, 200, 225, 250, 300],
    'rf_class_1__max_depth': [2, 4, 6, 8],
    'rf_class_1__min_samples_split': [2, 5, 10, 15, 100],
    'rf_class_1__min_samples_leaf': [1, 2, 5, 10],
    'rf_class_1__max_features': ['sqrt', 'log2', None]
}

# Criar pipeline com RobustScaler e RandomForestClassifier
pipeline_rf_class_1 = Pipeline([
    ('scaler', RobustScaler()),
    ('rf_class_1', RandomForestClassifier(random_state = 42))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_rf_class_1 = BayesSearchCV(
    pipeline_rf_class_1,
    search_spaces = param_grid_bayes,
    n_iter = 30,
    cv = 5,
    scoring = 'f1_weighted',
    n_jobs = -1,
    random_state = 42
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_rf_class_1.fit(X_train_smote, y_train_smote)

# Melhor modelo encontrado
best_rf_class_1_model = bayes_search_rf_class_1.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_rf_class_1.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_rf_class_1 = best_rf_class_1_model.predict(X_test_smote)

# Relatório de classificação TREINO
classification_report_rf_class_1 = metrics.classification_report(y_train_smote, best_rf_class_1_model.predict(X_train_smote), digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest com SMOTE [TREINO]: \n')
print(classification_report_rf_class_1)


# Relatório de classificação TESTE
classification_report_rf_class_1 = metrics.classification_report(y_test_smote, y_pred_rf_class_1, digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest com SMOTE [TESTE]: \n')
print(classification_report_rf_class_1)
# Out:
# Melhores hiperparâmetros: OrderedDict([('rf_class_1__criterion', 'entropy'), ('rf_class_1__max_depth', 8), ('rf_class_1__max_features', None), ('rf_class_1__min_samples_leaf', 1), ('rf_class_1__min_samples_split', 2), ('rf_class_1__n_estimators', 175)])
#
#  Classification report para Random Forest com SMOTE [TREINO]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.931674  0.919207  0.925399      5904
#     Reconhecido   0.920274  0.932588  0.926390      5904
#
#        accuracy                       0.925898     11808
#       macro avg   0.925974  0.925898  0.925894     11808
#    weighted avg   0.925974  0.925898  0.925894     11808
#
#
#  Classification report para Random Forest com SMOTE [TESTE]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.329193  0.449153  0.379928       118
#     Reconhecido   0.954641  0.926829  0.940529      1476
#
#        accuracy                       0.891468      1594
#       macro avg   0.641917  0.687991  0.660229      1594
#    weighted avg   0.908340  0.891468  0.899029      1594

# %%
# Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(best_rf_class_1_model, X_test_smote, y_test_smote, values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido'])

# %% [markdown]
# ## Avaliação das Variáveis de Importância
# Avaliação das variáveis de importância de acordo com o modelo desbalanceado,  que apresentou o maior f1-score.

# %%
# Passo intermediário
X_train     = X_train_2018_2024_modelo2
y_train     = y_train_2018_2024_modelo2
X_test      = X_test_2018_2024_modelo2
y_test      = y_test_2018_2024_modelo2
model_type  = 'rf_class_0'
best_model  = best_rf_class_0_model

# Ajustar o melhor modelo encontrado (depois da busca bayesiana)
best_model.named_steps[model_type].fit(X_train, y_train)

# Obter a importância das features
importance_dict = {}
for feature, importance in zip(X_train.columns, best_model.named_steps[model_type].feature_importances_):
    importance_dict[feature] = importance
#importance_dict

# Transformar em DataFrame para organizar como tabela
importance_df = pd.DataFrame({
    'Feature': list(importance_dict.keys()),
    'Importance': list(importance_dict.values())
})

# Ordenar pela importância em ordem decrescente
importance_df = importance_df.sort_values(by = 'Importance', ascending = False)
estilo_tabelas(importance_df.head(10))
# Out:
# <style type="text/css">
# #T_93e6f thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_93e6f td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_93e6f tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_93e6f table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_93e6f td {
#   border: 1px solid #666;
# }
# #T_93e6f  th {
#   border: 1px solid #666;
# }
# #T_93e6f_row0_col0, #T_93e6f_row0_col1, #T_93e6f_row1_col0, #T_93e6f_row1_col1, #T_93e6f_row2_col0, #T_93e6f_row2_col1, #T_93e6f_row3_col0, #T_93e6f_row3_col1, #T_93e6f_row4_col0, #T_93e6f_row4_col1, #T_93e6f_row5_col0, #T_93e6f_row5_col1, #T_93e6f_row6_col0, #T_93e6f_row6_col1, #T_93e6f_row7_col0, #T_93e6f_row7_col1, #T_93e6f_row8_col0, #T_93e6f_row8_col1, #T_93e6f_row9_col0, #T_93e6f_row9_col1 {
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_93e6f" style = "height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93e6f_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_93e6f_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93e6f_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_93e6f_row0_col0" class="data row0 col0" >DM_Inst Saúde Destruidas</td>
#       <td id="T_93e6f_row0_col1" class="data row0 col1" >0.290</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_93e6f_row1_col0" class="data row1 col0" >DH_OUTROS AFETADOS</td>
#       <td id="T_93e6f_row1_col1" class="data row1 col1" >0.105</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_93e6f_row2_col0" class="data row2 col0" >DM_Uni Habita Danificadas</td>
#       <td id="T_93e6f_row2_col1" class="data row2 col1" >0.078</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_93e6f_row3_col0" class="data row3 col0" >DM_Uni Habita Destruidas</td>
#       <td id="T_93e6f_row3_col1" class="data row3 col1" >0.036</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row4" class="row_heading level0 row4" >36</th>
#       <td id="T_93e6f_row4_col0" class="data row4 col0" >PEPR_Agricultura (R$)</td>
#       <td id="T_93e6f_row4_col1" class="data row4 col1" >0.034</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row5" class="row_heading level0 row5" >47</th>
#       <td id="T_93e6f_row5_col0" class="data row5 col0" >QTDE_FAMILIAS_ATUALIZADAS</td>
#       <td id="T_93e6f_row5_col1" class="data row5 col1" >0.029</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row6" class="row_heading level0 row6" >41</th>
#       <td id="T_93e6f_row6_col0" class="data row6 col0" >DensidadePop</td>
#       <td id="T_93e6f_row6_col1" class="data row6 col1" >0.019</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row7" class="row_heading level0 row7" >23</th>
#       <td id="T_93e6f_row7_col0" class="data row7 col0" >DM_Obras de Infra Destruidas</td>
#       <td id="T_93e6f_row7_col1" class="data row7 col1" >0.019</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row8" class="row_heading level0 row8" >4</th>
#       <td id="T_93e6f_row8_col0" class="data row8 col0" >DH_DESALOJADOS</td>
#       <td id="T_93e6f_row8_col1" class="data row8 col1" >0.017</td>
#     </tr>
#     <tr>
#       <th id="T_93e6f_level0_row9" class="row_heading level0 row9" >117</th>
#       <td id="T_93e6f_row9_col0" class="data row9 col0" >COBRADE_24100</td>
#       <td id="T_93e6f_row9_col1" class="data row9 col1" >0.016</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calcular os resultados (permutation_importance) da queda no desempenho do modelo ao embaralhar cada uma das variáveis.
result = permutation_importance(best_model, X_test, y_test, n_repeats = 100, random_state = 42, n_jobs = -1)

# Ordenar os resultados
sorted_idx = result.importances_mean.argsort()

# Gráfico boxplot pra mostrar a importância das variáveis
fig, ax = plt.subplots()
ax.boxplot(result.importances[sorted_idx].T, vert = False, labels = X_test.columns[sorted_idx])
ax.set_title('Permutation Importances (test set)')
fig.set_size_inches(15, 20)
fig.tight_layout()
plt.show()
# Out:
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /var/folders/cj/_95ntbkj60b_pjvf32tvsh2h0000gn/T/ipykernel_1271/582988329.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.

# %% [markdown]
# ## Seleção de Variáveis

# %% [markdown]
# ### Importância Média > 0.00

# %%
# Filtrar as variáveis com importância média > 0
positive_idx = result.importances_mean > 0.0

# Selecionar apenas as colunas das features com importância positiva
selected_features = X_test.columns[positive_idx]

# Criar novos datasets apenas com essas features
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

# Exibir as features selecionadas
print('Número de Features:', len(selected_features))
print('Features selecionadas:', selected_features.tolist())
# Out:
# Número de Features: 38
# Features selecionadas: ['DH_FERIDOS', 'DH_DESABRIGADOS', 'DH_DESALOJADOS', 'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas', 'DM_Inst Saúde Danificadas', 'DM_Inst Saúde Destruidas', 'DM_Inst Saúde Valor', 'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas', 'DM_Inst Ensino Valor', 'DM_Inst Serviços Danificadas', 'DM_Inst Serviços Destruidas', 'DM_Inst Serviços Valor', 'DM_Inst Comuni Destruidas', 'DM_Inst Comuni Valor', 'DM_Obras de Infra Danificadas', 'PEPL_Assis_méd e emergên(R$)', 'PEPL_sist de esgotos sanit(R$)', 'PEPL_Sis limp e rec lixo (R$)', 'PEPL_Distrib combustíveis(R$)', 'PEPR_Indústria (R$)', 'PEPR_Serviços (R$)', 'DOMICILIO_AREARURAL', 'PDEFAGUA', 'QTDE_FAMILIAS_ATUALIZADAS', 'Sigla_UF_AL', 'Sigla_UF_CE', 'Sigla_UF_ES', 'Sigla_UF_PE', 'Sigla_UF_PR', 'Sigla_UF_RN', 'Sigla_UF_SC', 'Sigla_UF_SP', 'COBRADE_11410', 'COBRADE_12300', 'COBRADE_13214', 'COBRADE_14132']

# %%
# Treinamento

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'rf_class_0__criterion': ['gini', 'entropy'],
    'rf_class_0__n_estimators': [150, 175, 200, 225, 250, 300],
    'rf_class_0__max_depth': [2, 4, 6, 8],
    'rf_class_0__min_samples_split': [2, 5, 10, 15, 100],
    'rf_class_0__min_samples_leaf': [1, 2, 5, 10],
    'rf_class_0__max_features': ['sqrt', 'log2', None]
}

# Criar pipeline com RobustScaler e RandomForestClassifier
pipeline_rf_class_0 = Pipeline([
    ('scaler', RobustScaler()),
    ('rf_class_0', RandomForestClassifier(random_state = 42))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_rf_class_0 = BayesSearchCV(
    pipeline_rf_class_0,
    search_spaces = param_grid_bayes,
    n_iter = 30,
    cv = 5,
    scoring = 'f1_weighted',
    n_jobs = -1,
    random_state = 42
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_rf_class_0.fit(X_train_selected, y_train)

# Melhor modelo encontrado
best_rf_class_0_model = bayes_search_rf_class_0.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_rf_class_0.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_rf_class_0 = best_rf_class_0_model.predict(X_test_selected)

# Relatório de classificação TREINO
classification_report_rf_class_0 = metrics.classification_report(y_train, best_rf_class_0_model.predict(X_train_selected), digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest [TREINO]: \n')
print(classification_report_rf_class_0)

# Relatório de classificação TESTE
classification_report_rf_class_0 = metrics.classification_report(y_test, y_pred_rf_class_0, digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest [TESTE]: \n')
print(classification_report_rf_class_0)
# Out:
# Melhores hiperparâmetros: OrderedDict([('rf_class_0__criterion', 'gini'), ('rf_class_0__max_depth', 8), ('rf_class_0__max_features', None), ('rf_class_0__min_samples_leaf', 2), ('rf_class_0__min_samples_split', 5), ('rf_class_0__n_estimators', 250)])
#
#  Classification report para Random Forest [TREINO]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   1.000000  0.239407  0.386325       472
#     Reconhecido   0.942679  1.000000  0.970494      5904
#
#        accuracy                       0.943695      6376
#       macro avg   0.971340  0.619703  0.678409      6376
#    weighted avg   0.946923  0.943695  0.927249      6376
#
#
#  Classification report para Random Forest [TESTE]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.954545  0.177966  0.300000       118
#     Reconhecido   0.938295  0.999322  0.967848      1476
#
#        accuracy                       0.938519      1594
#       macro avg   0.946420  0.588644  0.633924      1594
#    weighted avg   0.939498  0.938519  0.918409      1594

# %%
# Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(best_rf_class_0_model, X_test_selected, y_test, values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido'])

# %% [markdown]
# ### Impotância > -0.00001

# %%
# Filtrar as variáveis com importância média > -0.00001
positive_idx = result.importances_mean > -0.00001

# Selecionar apenas as colunas das features com importância positiva
selected_features = X_test.columns[positive_idx]

# Criar novos datasets apenas com essas features
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

# Exibir as features selecionadas
print('Número de Features:', len(selected_features))
print('Features selecionadas:', selected_features.tolist())
# Out:
# Número de Features: 100
# Features selecionadas: ['DH_MORTOS', 'DH_FERIDOS', 'DH_DESABRIGADOS', 'DH_DESALOJADOS', 'DH_DESAPARECIDOS', 'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas', 'DM_Inst Saúde Danificadas', 'DM_Inst Saúde Destruidas', 'DM_Inst Saúde Valor', 'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas', 'DM_Inst Ensino Valor', 'DM_Inst Serviços Danificadas', 'DM_Inst Serviços Destruidas', 'DM_Inst Serviços Valor', 'DM_Inst Comuni Danificadas', 'DM_Inst Comuni Destruidas', 'DM_Inst Comuni Valor', 'DM_Obras de Infra Danificadas', 'DM_Obras de Infra Valor', 'PEPL_Assis_méd e emergên(R$)', 'PEPL_Abast de água pot(R$)', 'PEPL_sist de esgotos sanit(R$)', 'PEPL_Sis limp e rec lixo (R$)', 'PEPL_Sis cont pragas (R$)', 'PEPL_Telecomunicações (R$)', 'PEPL_Distrib combustíveis(R$)', 'PEPR_Agricultura (R$)', 'PEPR_Pecuária (R$)', 'PEPR_Indústria (R$)', 'PEPR_Serviços (R$)', 'DOMICILIO_AREARURAL', 'PDEFAGUA', 'QTDE_FAMILIAS_ATUALIZADAS', 'Sigla_UF_AC', 'Sigla_UF_AL', 'Sigla_UF_AP', 'Sigla_UF_BA', 'Sigla_UF_CE', 'Sigla_UF_DF', 'Sigla_UF_ES', 'Sigla_UF_GO', 'Sigla_UF_MG', 'Sigla_UF_MS', 'Sigla_UF_MT', 'Sigla_UF_PB', 'Sigla_UF_PE', 'Sigla_UF_PI', 'Sigla_UF_PR', 'Sigla_UF_RJ', 'Sigla_UF_RN', 'Sigla_UF_RO', 'Sigla_UF_RR', 'Sigla_UF_RS', 'Sigla_UF_SC', 'Sigla_UF_SE', 'Sigla_UF_SP', 'Sigla_UF_TO', 'Sigla_UF_pa', 'COBRADE_11110', 'COBRADE_11120', 'COBRADE_11311', 'COBRADE_11312', 'COBRADE_11313', 'COBRADE_11321', 'COBRADE_11331', 'COBRADE_11332', 'COBRADE_11340', 'COBRADE_11410', 'COBRADE_11420', 'COBRADE_11431', 'COBRADE_11432', 'COBRADE_11433', 'COBRADE_12300', 'COBRADE_13111', 'COBRADE_13112', 'COBRADE_13120', 'COBRADE_13211', 'COBRADE_13212', 'COBRADE_13214', 'COBRADE_13310', 'COBRADE_13321', 'COBRADE_13322', 'COBRADE_14110', 'COBRADE_14120', 'COBRADE_14132', 'COBRADE_14140', 'COBRADE_15110', 'COBRADE_15120', 'COBRADE_15130', 'COBRADE_15210', 'COBRADE_15230', 'COBRADE_22210', 'COBRADE_22220', 'COBRADE_23120', 'COBRADE_24100', 'COBRADE_24200', 'COBRADE_25100', 'COBRADE_25500']

# %%
# Treinamento

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'rf_class_0__criterion': ['gini', 'entropy'],
    'rf_class_0__n_estimators': [150, 175, 200, 225, 250, 300],
    'rf_class_0__max_depth': [2, 4, 6, 8],
    'rf_class_0__min_samples_split': [2, 5, 10, 15, 100],
    'rf_class_0__min_samples_leaf': [1, 2, 5, 10],
    'rf_class_0__max_features': ['sqrt', 'log2', None]
}

# Criar pipeline com RobustScaler e RandomForestClassifier
pipeline_rf_class_0 = Pipeline([
    ('scaler', RobustScaler()),
    ('rf_class_0', RandomForestClassifier(random_state = 42))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_rf_class_0 = BayesSearchCV(
    pipeline_rf_class_0,
    search_spaces = param_grid_bayes,
    n_iter = 30,
    cv = 5,
    scoring = 'f1_weighted',
    n_jobs = -1,
    random_state = 42
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_rf_class_0.fit(X_train_selected, y_train)

# Melhor modelo encontrado
best_rf_class_0_model = bayes_search_rf_class_0.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_rf_class_0.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_rf_class_0 = best_rf_class_0_model.predict(X_test_selected)

# Relatório de classificação TREINO
classification_report_rf_class_0 = metrics.classification_report(y_train, best_rf_class_0_model.predict(X_train_selected), digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest [TREINO]: \n')
print(classification_report_rf_class_0)

# Relatório de classificação TESTE
classification_report_rf_class_0 = metrics.classification_report(y_test, y_pred_rf_class_0, digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest [TESTE]: \n')
print(classification_report_rf_class_0)
# Out:
# Melhores hiperparâmetros: OrderedDict([('rf_class_0__criterion', 'entropy'), ('rf_class_0__max_depth', 8), ('rf_class_0__max_features', None), ('rf_class_0__min_samples_leaf', 1), ('rf_class_0__min_samples_split', 2), ('rf_class_0__n_estimators', 200)])
#
#  Classification report para Random Forest [TREINO]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   1.000000  0.186441  0.314286       472
#     Reconhecido   0.938931  1.000000  0.968504      5904
#
#        accuracy                       0.939774      6376
#       macro avg   0.969466  0.593220  0.641395      6376
#    weighted avg   0.943452  0.939774  0.920074      6376
#
#
#  Classification report para Random Forest [TESTE]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.944444  0.144068  0.250000       118
#     Reconhecido   0.935914  0.999322  0.966579      1476
#
#        accuracy                       0.936010      1594
#       macro avg   0.940179  0.571695  0.608290      1594
#    weighted avg   0.936545  0.936010  0.913533      1594

# %%
# Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(best_rf_class_0_model, X_test_selected, y_test, values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido'])

# %% [markdown]
# ### Correlação < 0.5

# %%
# Calcular a matriz de correlação
corr_matrix = X_train.corr()

# Criar um dataframe para armazenar os pares com alta correlação
high_corr_pairs = set()

# Iterar pela matriz de correlação e encontrar pares com correlação acima de 0.5
threshold = 0.5
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) >= threshold:
            # Adicionar os pares de features com correlação maior que o threshold
            high_corr_pairs.add((corr_matrix.columns[i], corr_matrix.columns[j]))

# Exibir os pares com alta correlação
print(f'Pares de features com correlação maior que {threshold}:')
print(high_corr_pairs)

# Remover uma feature de cada par com alta correlação
features_to_remove = {pair[1] for pair in high_corr_pairs}  # Remover a segunda feature em cada par
X_train_uncorrelated = X_train.drop(columns = features_to_remove)
X_test_uncorrelated = X_test.drop(columns = features_to_remove)

# Exibir as features que foram removidas
print(f'Features removidas devido à alta correlação: {features_to_remove}')
print('Número de Features removidas:', len(features_to_remove))
# Out:
# Pares de features com correlação maior que 0.5:
# {('PEPR_Indústria (R$)', 'DM_Inst Saúde Valor'), ('PEPL_Segurança pública (R$)', 'PEPL_Telecomunicações (R$)'), ('PEPL_sist de esgotos sanit(R$)', 'DM_Inst Comuni Valor'), ('DM_Inst Comuni Valor', 'DM_Uni Habita Valor'), ('PEPL_sist de esgotos sanit(R$)', 'DM_Inst Serviços Valor'), ('PEPL_Tran loc/reg/l_curso (R$)', 'PEPL_Telecomunicações (R$)'), ('PDEFSAN', 'DOMICILIO_AREARURAL'), ('PEPL_Telecomunicações (R$)', 'PEPL_Sis cont pragas (R$)'), ('PEPL_Telecomunicações (R$)', 'DM_Inst Comuni Valor'), ('PEPL_Telecomunicações (R$)', 'PEPL_distrib energia (R$)'), ('PEPR_Indústria (R$)', 'DH_DESALOJADOS'), ('PEPL_sist de esgotos sanit(R$)', 'DM_Uni Habita Valor'), ('PEPR_Comércio (R$)', 'DM_Inst Serviços Valor'), ('PDEFSAN', 'PDEFESGOTO'), ('COBRADE_14131', 'Sigla_UF_GO'), ('PEPR_Indústria (R$)', 'DH_MORTOS'), ('COBRADE_13212', 'DM_Inst Saúde Destruidas'), ('PEPL_Telecomunicações (R$)', 'DM_Uni Habita Valor'), ('PEPL_Segurança pública (R$)', 'PEPL_Tran loc/reg/l_curso (R$)'), ('PEPL_Sis cont pragas (R$)', 'DM_Inst Comuni Valor'), ('PEPL_Sis limp e rec lixo (R$)', 'DM_Inst Ensino Valor'), ('PEPL_Sis cont pragas (R$)', 'DM_Inst Serviços Valor'), ('PEPL_Ensino (R$)', 'DM_Inst Saúde Valor'), ('PEPL_Segurança pública (R$)', 'PEPL_Sis cont pragas (R$)'), ('PEPL_Segurança pública (R$)', 'DM_Inst Comuni Valor'), ('PDEFLIXO', 'DOMICILIO_AREARURAL'), ('PDEFSAN', 'PDEFAGUA'), ('PEPL_Sis limp e rec lixo (R$)', 'DM_Inst Ensino Danificadas'), ('DM_Inst Serviços Valor', 'DM_Uni Habita Valor'), ('PEPL_Segurança pública (R$)', 'DM_Inst Serviços Valor'), ('PEPL_Tran loc/reg/l_curso (R$)', 'PEPL_Sis cont pragas (R$)'), ('PEPL_Sis cont pragas (R$)', 'DM_Uni Habita Valor'), ('PEPL_Telecomunicações (R$)', 'PEPL_sist de esgotos sanit(R$)'), ('COBRADE_11340', 'DH_DESABRIGADOS'), ('PEPL_Tran loc/reg/l_curso (R$)', 'DM_Inst Comuni Valor'), ('PEPL_Segurança pública (R$)', 'DM_Uni Habita Valor'), ('COBRADE_11340', 'DM_Uni Habita Valor'), ('PEPL_Tran loc/reg/l_curso (R$)', 'DM_Inst Serviços Valor'), ('PEPL_Sis cont pragas (R$)', 'PEPL_sist de esgotos sanit(R$)'), ('PDEFLIXO', 'PDEFAGUA'), ('PDEFAGUA', 'DOMICILIO_AREARURAL'), ('PEPL_Tran loc/reg/l_curso (R$)', 'DM_Uni Habita Valor'), ('PEPL_Segurança pública (R$)', 'PEPL_sist de esgotos sanit(R$)'), ('DM_Inst Ensino Valor', 'DM_Inst Ensino Danificadas'), ('PEPL_Tran loc/reg/l_curso (R$)', 'PEPL_sist de esgotos sanit(R$)'), ('DM_Inst Saúde Valor', 'DH_DESALOJADOS'), ('DM_Inst Comuni Valor', 'DM_Inst Serviços Valor'), ('PDEFSAN', 'PDEFLIXO')}
# Features removidas devido à alta correlação: {'DM_Inst Saúde Valor', 'PEPL_Telecomunicações (R$)', 'PDEFAGUA', 'DH_DESALOJADOS', 'DM_Inst Ensino Danificadas', 'DM_Inst Saúde Destruidas', 'PEPL_Tran loc/reg/l_curso (R$)', 'DM_Uni Habita Valor', 'PDEFLIXO', 'DM_Inst Serviços Valor', 'DM_Inst Ensino Valor', 'DH_MORTOS', 'PEPL_distrib energia (R$)', 'PEPL_Sis cont pragas (R$)', 'Sigla_UF_GO', 'DH_DESABRIGADOS', 'DM_Inst Comuni Valor', 'PEPL_sist de esgotos sanit(R$)', 'PDEFESGOTO', 'DOMICILIO_AREARURAL'}
# Número de Features removidas: 20

# %%
# Treinamento

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'rf_class_0__criterion': ['gini', 'entropy'],
    'rf_class_0__n_estimators': [150, 175, 200, 225, 250, 300],
    'rf_class_0__max_depth': [2, 4, 6, 8],
    'rf_class_0__min_samples_split': [2, 5, 10, 15, 100],
    'rf_class_0__min_samples_leaf': [1, 2, 5, 10],
    'rf_class_0__max_features': ['sqrt', 'log2', None]
}

# Criar pipeline com RobustScaler e RandomForestClassifier
pipeline_rf_class_0 = Pipeline([
    ('scaler', RobustScaler()),
    ('rf_class_0', RandomForestClassifier(random_state = 42))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_rf_class_0 = BayesSearchCV(
    pipeline_rf_class_0,
    search_spaces = param_grid_bayes,
    n_iter = 30,
    cv = 5,
    scoring = 'f1_weighted',
    n_jobs = -1,
    random_state = 42
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_rf_class_0.fit(X_train_uncorrelated, y_train)

# Melhor modelo encontrado
best_rf_class_0_model = bayes_search_rf_class_0.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_rf_class_0.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_rf_class_0 = best_rf_class_0_model.predict(X_test_uncorrelated)

# Relatório de classificação TREINO
classification_report_rf_class_0 = metrics.classification_report(y_train, best_rf_class_0_model.predict(X_train_uncorrelated), digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest [TREINO]: \n')
print(classification_report_rf_class_0)

# Relatório de classificação TESTE
classification_report_rf_class_0 = metrics.classification_report(y_test, y_pred_rf_class_0, digits = 6, target_names = ['Não reconhecido', 'Reconhecido'])
print('\n Classification report para Random Forest [TESTE]: \n')
print(classification_report_rf_class_0)
# Out:
# Melhores hiperparâmetros: OrderedDict([('rf_class_0__criterion', 'gini'), ('rf_class_0__max_depth', 8), ('rf_class_0__max_features', None), ('rf_class_0__min_samples_leaf', 2), ('rf_class_0__min_samples_split', 2), ('rf_class_0__n_estimators', 300)])
#
#  Classification report para Random Forest [TREINO]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.983871  0.258475  0.409396       472
#     Reconhecido   0.944018  0.999661  0.971043      5904
#
#        accuracy                       0.944793      6376
#       macro avg   0.963944  0.629068  0.690220      6376
#    weighted avg   0.946968  0.944793  0.929466      6376
#
#
#  Classification report para Random Forest [TESTE]:
#
#                  precision    recall  f1-score   support
#
# Não reconhecido   0.588235  0.084746  0.148148       118
#     Reconhecido   0.931516  0.995257  0.962332      1476
#
#        accuracy                       0.927854      1594
#       macro avg   0.759875  0.540002  0.555240      1594
#    weighted avg   0.906103  0.927854  0.902060      1594

# %%
# Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(best_rf_class_0_model, X_test_uncorrelated, y_test, values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido'])
