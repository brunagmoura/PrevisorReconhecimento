# %%
# Importar bibliotecas
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
from sklearn.metrics import make_scorer, recall_score
import numpy as np
from sklearn.model_selection import StratifiedKFold, train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline
import xgboost as xgb
from skopt import BayesSearchCV
from sklearn.preprocessing import RobustScaler
from sklearn import metrics

#Estilizar conteúdo
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},  # Bordas cinza escuro
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        ).format(
            precision=casas_decimais  
        )
    )

# Importar a base de dados

df_eventos_2018_2024_modelo2 = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2018_2024_modelo2.csv",
    sep=';',
    decimal=',',
)

estilo_tabelas(df_eventos_2018_2024_modelo2.head(5))
# Out:
# <style type="text/css">
# #T_2273a thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_2273a td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_2273a tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_2273a table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_2273a td {
#   border: 1px solid #666;
# }
# #T_2273a  th {
#   border: 1px solid #666;
# }
# #T_2273a_row0_col0, #T_2273a_row0_col1, #T_2273a_row0_col2, #T_2273a_row0_col3, #T_2273a_row0_col4, #T_2273a_row0_col5, #T_2273a_row0_col6, #T_2273a_row0_col7, #T_2273a_row0_col8, #T_2273a_row0_col9, #T_2273a_row0_col10, #T_2273a_row0_col11, #T_2273a_row0_col12, #T_2273a_row0_col13, #T_2273a_row0_col14, #T_2273a_row0_col15, #T_2273a_row0_col16, #T_2273a_row0_col17, #T_2273a_row0_col18, #T_2273a_row0_col19, #T_2273a_row0_col20, #T_2273a_row0_col21, #T_2273a_row0_col22, #T_2273a_row0_col23, #T_2273a_row0_col24, #T_2273a_row0_col25, #T_2273a_row0_col26, #T_2273a_row0_col27, #T_2273a_row0_col28, #T_2273a_row0_col29, #T_2273a_row0_col30, #T_2273a_row0_col31, #T_2273a_row0_col32, #T_2273a_row0_col33, #T_2273a_row0_col34, #T_2273a_row0_col35, #T_2273a_row0_col36, #T_2273a_row0_col37, #T_2273a_row0_col38, #T_2273a_row0_col39, #T_2273a_row0_col40, #T_2273a_row0_col41, #T_2273a_row0_col42, #T_2273a_row0_col43, #T_2273a_row0_col44, #T_2273a_row0_col45, #T_2273a_row0_col46, #T_2273a_row0_col47, #T_2273a_row0_col48, #T_2273a_row0_col49, #T_2273a_row0_col50, #T_2273a_row0_col51, #T_2273a_row0_col52, #T_2273a_row0_col53, #T_2273a_row0_col54, #T_2273a_row0_col55, #T_2273a_row0_col56, #T_2273a_row0_col57, #T_2273a_row0_col58, #T_2273a_row0_col59, #T_2273a_row0_col60, #T_2273a_row0_col61, #T_2273a_row0_col62, #T_2273a_row0_col63, #T_2273a_row0_col64, #T_2273a_row0_col65, #T_2273a_row0_col66, #T_2273a_row0_col67, #T_2273a_row0_col68, #T_2273a_row0_col69, #T_2273a_row0_col70, #T_2273a_row0_col71, #T_2273a_row0_col72, #T_2273a_row0_col73, #T_2273a_row0_col74, #T_2273a_row0_col75, #T_2273a_row0_col76, #T_2273a_row0_col77, #T_2273a_row0_col78, #T_2273a_row0_col79, #T_2273a_row0_col80, #T_2273a_row0_col81, #T_2273a_row0_col82, #T_2273a_row0_col83, #T_2273a_row0_col84, #T_2273a_row0_col85, #T_2273a_row0_col86, #T_2273a_row0_col87, #T_2273a_row0_col88, #T_2273a_row0_col89, #T_2273a_row0_col90, #T_2273a_row0_col91, #T_2273a_row0_col92, #T_2273a_row0_col93, #T_2273a_row0_col94, #T_2273a_row0_col95, #T_2273a_row0_col96, #T_2273a_row0_col97, #T_2273a_row0_col98, #T_2273a_row0_col99, #T_2273a_row0_col100, #T_2273a_row0_col101, #T_2273a_row0_col102, #T_2273a_row0_col103, #T_2273a_row0_col104, #T_2273a_row0_col105, #T_2273a_row0_col106, #T_2273a_row0_col107, #T_2273a_row0_col108, #T_2273a_row0_col109, #T_2273a_row0_col110, #T_2273a_row0_col111, #T_2273a_row0_col112, #T_2273a_row0_col113, #T_2273a_row0_col114, #T_2273a_row0_col115, #T_2273a_row0_col116, #T_2273a_row0_col117, #T_2273a_row0_col118, #T_2273a_row0_col119, #T_2273a_row0_col120, #T_2273a_row0_col121, #T_2273a_row1_col0, #T_2273a_row1_col1, #T_2273a_row1_col2, #T_2273a_row1_col3, #T_2273a_row1_col4, #T_2273a_row1_col5, #T_2273a_row1_col6, #T_2273a_row1_col7, #T_2273a_row1_col8, #T_2273a_row1_col9, #T_2273a_row1_col10, #T_2273a_row1_col11, #T_2273a_row1_col12, #T_2273a_row1_col13, #T_2273a_row1_col14, #T_2273a_row1_col15, #T_2273a_row1_col16, #T_2273a_row1_col17, #T_2273a_row1_col18, #T_2273a_row1_col19, #T_2273a_row1_col20, #T_2273a_row1_col21, #T_2273a_row1_col22, #T_2273a_row1_col23, #T_2273a_row1_col24, #T_2273a_row1_col25, #T_2273a_row1_col26, #T_2273a_row1_col27, #T_2273a_row1_col28, #T_2273a_row1_col29, #T_2273a_row1_col30, #T_2273a_row1_col31, #T_2273a_row1_col32, #T_2273a_row1_col33, #T_2273a_row1_col34, #T_2273a_row1_col35, #T_2273a_row1_col36, #T_2273a_row1_col37, #T_2273a_row1_col38, #T_2273a_row1_col39, #T_2273a_row1_col40, #T_2273a_row1_col41, #T_2273a_row1_col42, #T_2273a_row1_col43, #T_2273a_row1_col44, #T_2273a_row1_col45, #T_2273a_row1_col46, #T_2273a_row1_col47, #T_2273a_row1_col48, #T_2273a_row1_col49, #T_2273a_row1_col50, #T_2273a_row1_col51, #T_2273a_row1_col52, #T_2273a_row1_col53, #T_2273a_row1_col54, #T_2273a_row1_col55, #T_2273a_row1_col56, #T_2273a_row1_col57, #T_2273a_row1_col58, #T_2273a_row1_col59, #T_2273a_row1_col60, #T_2273a_row1_col61, #T_2273a_row1_col62, #T_2273a_row1_col63, #T_2273a_row1_col64, #T_2273a_row1_col65, #T_2273a_row1_col66, #T_2273a_row1_col67, #T_2273a ...

# %%
# Inclusão de features derivadas, tratando dados ausentes como 0
df_eventos_2018_2024_modelo2['DH_FERIDOS_ENFERMOS'] = df_eventos_2018_2024_modelo2['DH_FERIDOS'].fillna(0) + df_eventos_2018_2024_modelo2['DH_ENFERMOS'].fillna(0)
df_eventos_2018_2024_modelo2['DH_DESABRIGADOS_DESALOJADOS'] = df_eventos_2018_2024_modelo2['DH_DESABRIGADOS'].fillna(0) + df_eventos_2018_2024_modelo2['DH_DESALOJADOS'].fillna(0)
df_eventos_2018_2024_modelo2['DH_DESAPARECIDOS'] = df_eventos_2018_2024_modelo2['DH_DESAPARECIDOS'].fillna(0)
df_eventos_2018_2024_modelo2['DH_MORTOS'] = df_eventos_2018_2024_modelo2['DH_MORTOS'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Uni_Habita_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Uni Habita Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Uni Habita Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Uni_Habita_Valor'] = df_eventos_2018_2024_modelo2['DM_Uni Habita Valor'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Saude_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Inst Saúde Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Inst Saúde Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Saude_Valor'] = df_eventos_2018_2024_modelo2['DM_Inst Saúde Valor'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Ensino_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Inst Ensino Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Inst Ensino Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Ensino_Valor'] = df_eventos_2018_2024_modelo2['DM_Inst Ensino Valor'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Servicos_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Inst Serviços Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Inst Serviços Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Servicos_Valor'] = df_eventos_2018_2024_modelo2['DM_Inst Serviços Valor'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Comuni_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Inst Comuni Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Inst Comuni Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Comuni_Valor'] = df_eventos_2018_2024_modelo2['DM_Inst Comuni Valor'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Obras_Infra_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Obras de Infra Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Obras de Infra Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Obras_Infra_Valor'] = df_eventos_2018_2024_modelo2['DM_Obras de Infra Valor'].fillna(0)

#Excluir colunas que sobraram após agregação
colunas_a_remover = ['DH_FERIDOS', 'DH_ENFERMOS', 'DH_DESABRIGADOS', 'DH_DESALOJADOS',
                     'DH_DESAPARECIDOS', 'DH_MORTOS', 'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas',
                     'DM_Uni Habita Valor', 'DM_Inst Saúde Danificadas', 'DM_Inst Saúde Destruidas', 
                     'DM_Inst Saúde Valor', 'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas', 
                     'DM_Inst Ensino Valor', 'DM_Inst Serviços Danificadas', 'DM_Inst Serviços Destruidas', 
                     'DM_Inst Serviços Valor', 'DM_Inst Comuni Danificadas', 'DM_Inst Comuni Destruidas', 
                     'DM_Inst Comuni Valor', 'DM_Obras de Infra Danificadas', 'DM_Obras de Infra Destruidas', 
                     'DM_Obras de Infra Valor']

df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.drop(columns=colunas_a_remover)

#Excluir linhas com dados ausentes
df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.dropna()

estilo_tabelas(df_eventos_2018_2024_modelo2.head())
# Out:
# <style type="text/css">
# #T_ffded thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_ffded td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_ffded tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_ffded table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_ffded td {
#   border: 1px solid #666;
# }
# #T_ffded  th {
#   border: 1px solid #666;
# }
# #T_ffded_row0_col0, #T_ffded_row0_col1, #T_ffded_row0_col2, #T_ffded_row0_col3, #T_ffded_row0_col4, #T_ffded_row0_col5, #T_ffded_row0_col6, #T_ffded_row0_col7, #T_ffded_row0_col8, #T_ffded_row0_col9, #T_ffded_row0_col10, #T_ffded_row0_col11, #T_ffded_row0_col12, #T_ffded_row0_col13, #T_ffded_row0_col14, #T_ffded_row0_col15, #T_ffded_row0_col16, #T_ffded_row0_col17, #T_ffded_row0_col18, #T_ffded_row0_col19, #T_ffded_row0_col20, #T_ffded_row0_col21, #T_ffded_row0_col22, #T_ffded_row0_col23, #T_ffded_row0_col24, #T_ffded_row0_col25, #T_ffded_row0_col26, #T_ffded_row0_col27, #T_ffded_row0_col28, #T_ffded_row0_col29, #T_ffded_row0_col30, #T_ffded_row0_col31, #T_ffded_row0_col32, #T_ffded_row0_col33, #T_ffded_row0_col34, #T_ffded_row0_col35, #T_ffded_row0_col36, #T_ffded_row0_col37, #T_ffded_row0_col38, #T_ffded_row0_col39, #T_ffded_row0_col40, #T_ffded_row0_col41, #T_ffded_row0_col42, #T_ffded_row0_col43, #T_ffded_row0_col44, #T_ffded_row0_col45, #T_ffded_row0_col46, #T_ffded_row0_col47, #T_ffded_row0_col48, #T_ffded_row0_col49, #T_ffded_row0_col50, #T_ffded_row0_col51, #T_ffded_row0_col52, #T_ffded_row0_col53, #T_ffded_row0_col54, #T_ffded_row0_col55, #T_ffded_row0_col56, #T_ffded_row0_col57, #T_ffded_row0_col58, #T_ffded_row0_col59, #T_ffded_row0_col60, #T_ffded_row0_col61, #T_ffded_row0_col62, #T_ffded_row0_col63, #T_ffded_row0_col64, #T_ffded_row0_col65, #T_ffded_row0_col66, #T_ffded_row0_col67, #T_ffded_row0_col68, #T_ffded_row0_col69, #T_ffded_row0_col70, #T_ffded_row0_col71, #T_ffded_row0_col72, #T_ffded_row0_col73, #T_ffded_row0_col74, #T_ffded_row0_col75, #T_ffded_row0_col76, #T_ffded_row0_col77, #T_ffded_row0_col78, #T_ffded_row0_col79, #T_ffded_row0_col80, #T_ffded_row0_col81, #T_ffded_row0_col82, #T_ffded_row0_col83, #T_ffded_row0_col84, #T_ffded_row0_col85, #T_ffded_row0_col86, #T_ffded_row0_col87, #T_ffded_row0_col88, #T_ffded_row0_col89, #T_ffded_row0_col90, #T_ffded_row0_col91, #T_ffded_row0_col92, #T_ffded_row0_col93, #T_ffded_row0_col94, #T_ffded_row0_col95, #T_ffded_row0_col96, #T_ffded_row0_col97, #T_ffded_row0_col98, #T_ffded_row0_col99, #T_ffded_row0_col100, #T_ffded_row0_col101, #T_ffded_row0_col102, #T_ffded_row0_col103, #T_ffded_row0_col104, #T_ffded_row0_col105, #T_ffded_row0_col106, #T_ffded_row0_col107, #T_ffded_row0_col108, #T_ffded_row0_col109, #T_ffded_row0_col110, #T_ffded_row0_col111, #T_ffded_row1_col0, #T_ffded_row1_col1, #T_ffded_row1_col2, #T_ffded_row1_col3, #T_ffded_row1_col4, #T_ffded_row1_col5, #T_ffded_row1_col6, #T_ffded_row1_col7, #T_ffded_row1_col8, #T_ffded_row1_col9, #T_ffded_row1_col10, #T_ffded_row1_col11, #T_ffded_row1_col12, #T_ffded_row1_col13, #T_ffded_row1_col14, #T_ffded_row1_col15, #T_ffded_row1_col16, #T_ffded_row1_col17, #T_ffded_row1_col18, #T_ffded_row1_col19, #T_ffded_row1_col20, #T_ffded_row1_col21, #T_ffded_row1_col22, #T_ffded_row1_col23, #T_ffded_row1_col24, #T_ffded_row1_col25, #T_ffded_row1_col26, #T_ffded_row1_col27, #T_ffded_row1_col28, #T_ffded_row1_col29, #T_ffded_row1_col30, #T_ffded_row1_col31, #T_ffded_row1_col32, #T_ffded_row1_col33, #T_ffded_row1_col34, #T_ffded_row1_col35, #T_ffded_row1_col36, #T_ffded_row1_col37, #T_ffded_row1_col38, #T_ffded_row1_col39, #T_ffded_row1_col40, #T_ffded_row1_col41, #T_ffded_row1_col42, #T_ffded_row1_col43, #T_ffded_row1_col44, #T_ffded_row1_col45, #T_ffded_row1_col46, #T_ffded_row1_col47, #T_ffded_row1_col48, #T_ffded_row1_col49, #T_ffded_row1_col50, #T_ffded_row1_col51, #T_ffded_row1_col52, #T_ffded_row1_col53, #T_ffded_row1_col54, #T_ffded_row1_col55, #T_ffded_row1_col56, #T_ffded_row1_col57, #T_ffded_row1_col58, #T_ffded_row1_col59, #T_ffded_row1_col60, #T_ffded_row1_col61, #T_ffded_row1_col62, #T_ffded_row1_col63, #T_ffded_row1_col64, #T_ffded_row1_col65, #T_ffded_row1_col66, #T_ffded_row1_col67, #T_ffded_row1_col68, #T_ffded_row1_col69, #T_ffded_row1_col70, #T_ffded_row1_col71, #T_ffded_row1_col72, #T_ffded_row1_col73, #T_ffded_row1_col74, #T_ffded_row1_col75, #T_ffded_row1_col76, #T_ffded_row1_col77, #T_ffded_row1_col7 ...

# %%
# Balanceamento da variável target

status_counts = df_eventos_2018_2024_modelo2['Status'].value_counts()
print("\nBalanceamento da variável 'Status':")
display(status_counts)
# Out:
# Balanceamento da variável 'Status':
# Status
# 1    7549
# 0     726
# Name: count, dtype: int64

# %%
X_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.drop('Status', axis=1)

y_2018_2024_modelo2 = df_eventos_2018_2024_modelo2['Status']

X_train_2018_2024_modelo2, X_test_2018_2024_modelo2, y_train_2018_2024_modelo2, y_test_2018_2024_modelo2 = train_test_split(X_2018_2024_modelo2, y_2018_2024_modelo2, test_size=0.2, random_state=1, stratify=y_2018_2024_modelo2)

# %%
# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],
    'xgb__min_child_weight': [1, 3, 5, 7],
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__lambda': [0.01, 0.1, 1.0],
    'xgb__alpha': [0, 0.1, 0.5, 1.0]
}

# Definir scale_pos_weight
scale_pos_weight = np.sqrt(7549 / 726)

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb = Pipeline([
    ('scaler', RobustScaler()),  
    ('xgb', xgb.XGBClassifier(
        random_state=1,
        eval_metric='logloss',  
        scale_pos_weight=scale_pos_weight 
    ))
])

# Realizar a busca bayesiana com validação cruzada
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

# Usar recall como métrica de scoring
scorer = make_scorer(recall_score)

bayes_search_xgb = BayesSearchCV(
    pipeline_xgb,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=cv,
    scoring=scorer,
    n_jobs=-1,
    random_state=1
)

# Ajustar o modelo ao conjunto de treino balanceado por pesos scale_pos_weight
bayes_search_xgb.fit(X_train_2018_2024_modelo2, y_train_2018_2024_modelo2)

# Melhor modelo encontrado
best_xgb_model = bayes_search_xgb.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros com scale_pos_weight: {bayes_search_xgb.best_params_}")

# Fazer previsões com o conjunto de teste original
y_pred_xgb_smote = best_xgb_model.predict(X_test_2018_2024_modelo2)

# Relatório de classificação
classification_report_xgb = metrics.classification_report(
    y_test_2018_2024_modelo2, y_pred_xgb_smote, digits=6, target_names=['Reconhecido', 'Não reconhecido']
)

print('Classification report para XGBoost com scale_pos_weight: \n')
print(classification_report_xgb)
# Out:
# Melhores hiperparâmetros com scale_pos_weight: OrderedDict([('xgb__alpha', 0.5), ('xgb__colsample_bytree', 0.6), ('xgb__eta', 0.015), ('xgb__gamma', 0.1), ('xgb__lambda', 0.1), ('xgb__max_depth', 25), ('xgb__min_child_weight', 1), ('xgb__subsample', 0.7)])
# Classification report para XGBoost com scale_pos_weight:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   1.000000  0.200000  0.333333       145
# Não reconhecido   0.928659  1.000000  0.963010      1510
#
#        accuracy                       0.929909      1655
#       macro avg   0.964330  0.600000  0.648172      1655
#    weighted avg   0.934910  0.929909  0.907842      1655

# %%
# Acurácia no conjunto de treino
y_train_pred_smote = best_xgb_model.predict(X_train_2018_2024_modelo2)
acuracia_treino = metrics.accuracy_score(y_train_2018_2024_modelo2, y_train_pred_smote)

# Acurácia no conjunto de teste
acuracia_teste = metrics.accuracy_score(y_test_2018_2024_modelo2, y_pred_xgb_smote)

print(f"Acurácia no conjunto de treino: {acuracia_treino:.6f}")
print(f"Acurácia no conjunto de teste: {acuracia_teste:.6f}")
# Out:
# Acurácia no conjunto de treino: 0.939275
# Acurácia no conjunto de teste: 0.929909

# %%
ConfusionMatrixDisplay.from_estimator(bayes_search_xgb, X_test_2018_2024_modelo2, y_test_2018_2024_modelo2, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])
