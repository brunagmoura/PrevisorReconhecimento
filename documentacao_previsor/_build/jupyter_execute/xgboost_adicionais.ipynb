# %% [markdown]
# ## Testes adicionais
#
#
# Este caderno tem como objetivo tentar melhorar os resultados obtidos no modelo de variáveis desagregadas para 2018 a 2024.

# %% [markdown]
# ### Bibliotecas e base de dados

# %%
# Importar bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc, precision_recall_curve, roc_auc_score
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.metrics import make_scorer, recall_score
from sklearn.feature_selection import SelectFromModel

from xgboost import XGBClassifier

from skopt import BayesSearchCV
from skopt.space import Real, Integer

#Estilizar conteúdo
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},  # Bordas cinza escuro
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        ).format(
            precision=casas_decimais  
        )
    )

# Função para plotar as curvas ROC e PR
def plot_roc_pr_curves(y_test, y_pred_proba, model_name):
    # Curva ROC
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title(f'Curva ROC - {model_name}')
    plt.xlabel('Taxa de Falsos Positivos')
    plt.ylabel('Taxa de Verdadeiros Positivos')
    plt.legend(loc='lower right')
    plt.show()

    # Curva de Precisão-Revocação
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    pr_auc = auc(recall, precision)

    plt.figure()
    plt.plot(recall, precision, label=f'{model_name} (AUC = {pr_auc:.2f})')
    plt.title(f'Curva de Precisão-Revocação - {model_name}')
    plt.xlabel('Revocação')
    plt.ylabel('Precisão')
    plt.legend(loc='lower left')
    plt.show()

# Importar a base de dados

df_eventos_2018_2024_modelo2 = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2018_2024_modelo2.csv",
    sep=';',
    decimal=',',
)

estilo_tabelas(df_eventos_2018_2024_modelo2.head(5))
# Out:
# <style type="text/css">
# #T_753bb thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_753bb td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_753bb tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_753bb table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_753bb td {
#   border: 1px solid #666;
# }
# #T_753bb  th {
#   border: 1px solid #666;
# }
# #T_753bb_row0_col0, #T_753bb_row0_col1, #T_753bb_row0_col2, #T_753bb_row0_col3, #T_753bb_row0_col4, #T_753bb_row0_col5, #T_753bb_row0_col6, #T_753bb_row0_col7, #T_753bb_row0_col8, #T_753bb_row0_col9, #T_753bb_row0_col10, #T_753bb_row0_col11, #T_753bb_row0_col12, #T_753bb_row0_col13, #T_753bb_row0_col14, #T_753bb_row0_col15, #T_753bb_row0_col16, #T_753bb_row0_col17, #T_753bb_row0_col18, #T_753bb_row0_col19, #T_753bb_row0_col20, #T_753bb_row0_col21, #T_753bb_row0_col22, #T_753bb_row0_col23, #T_753bb_row0_col24, #T_753bb_row0_col25, #T_753bb_row0_col26, #T_753bb_row0_col27, #T_753bb_row0_col28, #T_753bb_row0_col29, #T_753bb_row0_col30, #T_753bb_row0_col31, #T_753bb_row0_col32, #T_753bb_row0_col33, #T_753bb_row0_col34, #T_753bb_row0_col35, #T_753bb_row0_col36, #T_753bb_row0_col37, #T_753bb_row0_col38, #T_753bb_row0_col39, #T_753bb_row0_col40, #T_753bb_row0_col41, #T_753bb_row0_col42, #T_753bb_row0_col43, #T_753bb_row0_col44, #T_753bb_row0_col45, #T_753bb_row0_col46, #T_753bb_row0_col47, #T_753bb_row0_col48, #T_753bb_row0_col49, #T_753bb_row0_col50, #T_753bb_row0_col51, #T_753bb_row0_col52, #T_753bb_row0_col53, #T_753bb_row0_col54, #T_753bb_row0_col55, #T_753bb_row0_col56, #T_753bb_row0_col57, #T_753bb_row0_col58, #T_753bb_row0_col59, #T_753bb_row0_col60, #T_753bb_row0_col61, #T_753bb_row0_col62, #T_753bb_row0_col63, #T_753bb_row0_col64, #T_753bb_row0_col65, #T_753bb_row0_col66, #T_753bb_row0_col67, #T_753bb_row0_col68, #T_753bb_row0_col69, #T_753bb_row0_col70, #T_753bb_row0_col71, #T_753bb_row0_col72, #T_753bb_row0_col73, #T_753bb_row0_col74, #T_753bb_row0_col75, #T_753bb_row0_col76, #T_753bb_row0_col77, #T_753bb_row0_col78, #T_753bb_row0_col79, #T_753bb_row0_col80, #T_753bb_row0_col81, #T_753bb_row0_col82, #T_753bb_row0_col83, #T_753bb_row0_col84, #T_753bb_row0_col85, #T_753bb_row0_col86, #T_753bb_row0_col87, #T_753bb_row0_col88, #T_753bb_row0_col89, #T_753bb_row0_col90, #T_753bb_row0_col91, #T_753bb_row0_col92, #T_753bb_row0_col93, #T_753bb_row0_col94, #T_753bb_row0_col95, #T_753bb_row0_col96, #T_753bb_row0_col97, #T_753bb_row0_col98, #T_753bb_row0_col99, #T_753bb_row0_col100, #T_753bb_row0_col101, #T_753bb_row0_col102, #T_753bb_row0_col103, #T_753bb_row0_col104, #T_753bb_row0_col105, #T_753bb_row0_col106, #T_753bb_row0_col107, #T_753bb_row0_col108, #T_753bb_row0_col109, #T_753bb_row0_col110, #T_753bb_row0_col111, #T_753bb_row0_col112, #T_753bb_row0_col113, #T_753bb_row0_col114, #T_753bb_row0_col115, #T_753bb_row0_col116, #T_753bb_row0_col117, #T_753bb_row0_col118, #T_753bb_row0_col119, #T_753bb_row0_col120, #T_753bb_row0_col121, #T_753bb_row1_col0, #T_753bb_row1_col1, #T_753bb_row1_col2, #T_753bb_row1_col3, #T_753bb_row1_col4, #T_753bb_row1_col5, #T_753bb_row1_col6, #T_753bb_row1_col7, #T_753bb_row1_col8, #T_753bb_row1_col9, #T_753bb_row1_col10, #T_753bb_row1_col11, #T_753bb_row1_col12, #T_753bb_row1_col13, #T_753bb_row1_col14, #T_753bb_row1_col15, #T_753bb_row1_col16, #T_753bb_row1_col17, #T_753bb_row1_col18, #T_753bb_row1_col19, #T_753bb_row1_col20, #T_753bb_row1_col21, #T_753bb_row1_col22, #T_753bb_row1_col23, #T_753bb_row1_col24, #T_753bb_row1_col25, #T_753bb_row1_col26, #T_753bb_row1_col27, #T_753bb_row1_col28, #T_753bb_row1_col29, #T_753bb_row1_col30, #T_753bb_row1_col31, #T_753bb_row1_col32, #T_753bb_row1_col33, #T_753bb_row1_col34, #T_753bb_row1_col35, #T_753bb_row1_col36, #T_753bb_row1_col37, #T_753bb_row1_col38, #T_753bb_row1_col39, #T_753bb_row1_col40, #T_753bb_row1_col41, #T_753bb_row1_col42, #T_753bb_row1_col43, #T_753bb_row1_col44, #T_753bb_row1_col45, #T_753bb_row1_col46, #T_753bb_row1_col47, #T_753bb_row1_col48, #T_753bb_row1_col49, #T_753bb_row1_col50, #T_753bb_row1_col51, #T_753bb_row1_col52, #T_753bb_row1_col53, #T_753bb_row1_col54, #T_753bb_row1_col55, #T_753bb_row1_col56, #T_753bb_row1_col57, #T_753bb_row1_col58, #T_753bb_row1_col59, #T_753bb_row1_col60, #T_753bb_row1_col61, #T_753bb_row1_col62, #T_753bb_row1_col63, #T_753bb_row1_col64, #T_753bb_row1_col65, #T_753bb_row1_col66, #T_753bb_row1_col67, #T_753bb ...

# %% [markdown]
# ### Inclusão de features derivadas

# %%
# Inclusão de features derivadas
# As features com "na" que seriam somadas a outras foram tratadas como 0. Por exemplo, caso um evento tenha feridos = 5 e enfermos = na, então o valor de feridos e enfermos = 5.

df_eventos_2018_2024_modelo2['DH_FERIDOS_ENFERMOS'] = df_eventos_2018_2024_modelo2['DH_FERIDOS'].fillna(0) + df_eventos_2018_2024_modelo2['DH_ENFERMOS'].fillna(0)
df_eventos_2018_2024_modelo2['DH_DESABRIGADOS_DESALOJADOS'] = df_eventos_2018_2024_modelo2['DH_DESABRIGADOS'].fillna(0) + df_eventos_2018_2024_modelo2['DH_DESALOJADOS'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Uni_Habita_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Uni Habita Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Uni Habita Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Saude_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Inst Saúde Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Inst Saúde Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Ensino_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Inst Ensino Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Inst Ensino Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Servicos_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Inst Serviços Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Inst Serviços Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Inst_Comuni_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Inst Comuni Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Inst Comuni Destruidas'].fillna(0)
df_eventos_2018_2024_modelo2['DM_Obras_Infra_Danificadas_Destruidas'] = df_eventos_2018_2024_modelo2['DM_Obras de Infra Danificadas'].fillna(0) + df_eventos_2018_2024_modelo2['DM_Obras de Infra Destruidas'].fillna(0)

#Excluir colunas que repetidas após agregação

colunas_a_remover = ['DH_FERIDOS', 'DH_ENFERMOS', 'DH_DESABRIGADOS', 'DH_DESALOJADOS',
                     'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas',
                     'DM_Inst Saúde Danificadas', 'DM_Inst Saúde Destruidas', 
                     'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas', 
                     'DM_Inst Serviços Danificadas', 'DM_Inst Serviços Destruidas', 
                     'DM_Inst Comuni Danificadas', 'DM_Inst Comuni Destruidas', 
                     'DM_Obras de Infra Danificadas', 'DM_Obras de Infra Destruidas', ]

df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.drop(columns=colunas_a_remover)

#Excluir linhas com dados ausentes
df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.dropna()

estilo_tabelas(df_eventos_2018_2024_modelo2.head())
# Out:
# <style type="text/css">
# #T_9f0b3 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_9f0b3 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_9f0b3 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_9f0b3 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_9f0b3 td {
#   border: 1px solid #666;
# }
# #T_9f0b3  th {
#   border: 1px solid #666;
# }
# #T_9f0b3_row0_col0, #T_9f0b3_row0_col1, #T_9f0b3_row0_col2, #T_9f0b3_row0_col3, #T_9f0b3_row0_col4, #T_9f0b3_row0_col5, #T_9f0b3_row0_col6, #T_9f0b3_row0_col7, #T_9f0b3_row0_col8, #T_9f0b3_row0_col9, #T_9f0b3_row0_col10, #T_9f0b3_row0_col11, #T_9f0b3_row0_col12, #T_9f0b3_row0_col13, #T_9f0b3_row0_col14, #T_9f0b3_row0_col15, #T_9f0b3_row0_col16, #T_9f0b3_row0_col17, #T_9f0b3_row0_col18, #T_9f0b3_row0_col19, #T_9f0b3_row0_col20, #T_9f0b3_row0_col21, #T_9f0b3_row0_col22, #T_9f0b3_row0_col23, #T_9f0b3_row0_col24, #T_9f0b3_row0_col25, #T_9f0b3_row0_col26, #T_9f0b3_row0_col27, #T_9f0b3_row0_col28, #T_9f0b3_row0_col29, #T_9f0b3_row0_col30, #T_9f0b3_row0_col31, #T_9f0b3_row0_col32, #T_9f0b3_row0_col33, #T_9f0b3_row0_col34, #T_9f0b3_row0_col35, #T_9f0b3_row0_col36, #T_9f0b3_row0_col37, #T_9f0b3_row0_col38, #T_9f0b3_row0_col39, #T_9f0b3_row0_col40, #T_9f0b3_row0_col41, #T_9f0b3_row0_col42, #T_9f0b3_row0_col43, #T_9f0b3_row0_col44, #T_9f0b3_row0_col45, #T_9f0b3_row0_col46, #T_9f0b3_row0_col47, #T_9f0b3_row0_col48, #T_9f0b3_row0_col49, #T_9f0b3_row0_col50, #T_9f0b3_row0_col51, #T_9f0b3_row0_col52, #T_9f0b3_row0_col53, #T_9f0b3_row0_col54, #T_9f0b3_row0_col55, #T_9f0b3_row0_col56, #T_9f0b3_row0_col57, #T_9f0b3_row0_col58, #T_9f0b3_row0_col59, #T_9f0b3_row0_col60, #T_9f0b3_row0_col61, #T_9f0b3_row0_col62, #T_9f0b3_row0_col63, #T_9f0b3_row0_col64, #T_9f0b3_row0_col65, #T_9f0b3_row0_col66, #T_9f0b3_row0_col67, #T_9f0b3_row0_col68, #T_9f0b3_row0_col69, #T_9f0b3_row0_col70, #T_9f0b3_row0_col71, #T_9f0b3_row0_col72, #T_9f0b3_row0_col73, #T_9f0b3_row0_col74, #T_9f0b3_row0_col75, #T_9f0b3_row0_col76, #T_9f0b3_row0_col77, #T_9f0b3_row0_col78, #T_9f0b3_row0_col79, #T_9f0b3_row0_col80, #T_9f0b3_row0_col81, #T_9f0b3_row0_col82, #T_9f0b3_row0_col83, #T_9f0b3_row0_col84, #T_9f0b3_row0_col85, #T_9f0b3_row0_col86, #T_9f0b3_row0_col87, #T_9f0b3_row0_col88, #T_9f0b3_row0_col89, #T_9f0b3_row0_col90, #T_9f0b3_row0_col91, #T_9f0b3_row0_col92, #T_9f0b3_row0_col93, #T_9f0b3_row0_col94, #T_9f0b3_row0_col95, #T_9f0b3_row0_col96, #T_9f0b3_row0_col97, #T_9f0b3_row0_col98, #T_9f0b3_row0_col99, #T_9f0b3_row0_col100, #T_9f0b3_row0_col101, #T_9f0b3_row0_col102, #T_9f0b3_row0_col103, #T_9f0b3_row0_col104, #T_9f0b3_row0_col105, #T_9f0b3_row0_col106, #T_9f0b3_row0_col107, #T_9f0b3_row0_col108, #T_9f0b3_row0_col109, #T_9f0b3_row0_col110, #T_9f0b3_row0_col111, #T_9f0b3_row0_col112, #T_9f0b3_row0_col113, #T_9f0b3_row1_col0, #T_9f0b3_row1_col1, #T_9f0b3_row1_col2, #T_9f0b3_row1_col3, #T_9f0b3_row1_col4, #T_9f0b3_row1_col5, #T_9f0b3_row1_col6, #T_9f0b3_row1_col7, #T_9f0b3_row1_col8, #T_9f0b3_row1_col9, #T_9f0b3_row1_col10, #T_9f0b3_row1_col11, #T_9f0b3_row1_col12, #T_9f0b3_row1_col13, #T_9f0b3_row1_col14, #T_9f0b3_row1_col15, #T_9f0b3_row1_col16, #T_9f0b3_row1_col17, #T_9f0b3_row1_col18, #T_9f0b3_row1_col19, #T_9f0b3_row1_col20, #T_9f0b3_row1_col21, #T_9f0b3_row1_col22, #T_9f0b3_row1_col23, #T_9f0b3_row1_col24, #T_9f0b3_row1_col25, #T_9f0b3_row1_col26, #T_9f0b3_row1_col27, #T_9f0b3_row1_col28, #T_9f0b3_row1_col29, #T_9f0b3_row1_col30, #T_9f0b3_row1_col31, #T_9f0b3_row1_col32, #T_9f0b3_row1_col33, #T_9f0b3_row1_col34, #T_9f0b3_row1_col35, #T_9f0b3_row1_col36, #T_9f0b3_row1_col37, #T_9f0b3_row1_col38, #T_9f0b3_row1_col39, #T_9f0b3_row1_col40, #T_9f0b3_row1_col41, #T_9f0b3_row1_col42, #T_9f0b3_row1_col43, #T_9f0b3_row1_col44, #T_9f0b3_row1_col45, #T_9f0b3_row1_col46, #T_9f0b3_row1_col47, #T_9f0b3_row1_col48, #T_9f0b3_row1_col49, #T_9f0b3_row1_col50, #T_9f0b3_row1_col51, #T_9f0b3_row1_col52, #T_9f0b3_row1_col53, #T_9f0b3_row1_col54, #T_9f0b3_row1_col55, #T_9f0b3_row1_col56, #T_9f0b3_row1_col57, #T_9f0b3_row1_col58, #T_9f0b3_row1_col59, #T_9f0b3_row1_col60, #T_9f0b3_row1_col61, #T_9f0b3_row1_col62, #T_9f0b3_row1_col63, #T_9f0b3_row1_col64, #T_9f0b3_row1_col65, #T_9f0b3_row1_col66, #T_9f0b3_row1_col67, #T_9f0b3_row1_col68, #T_9f0b3_row1_col69, #T_9f0b3_row1_col70, #T_9f0b3_row1_col71, #T_9f0b3_row1_col72, #T_9f0b3_row1_col73, #T_9f0b3_row1_col74, #T_9f0b3_row1_col75, #T_9f0b3_row1_co ...

# %%
# Balanceamento da variável target

status_counts = df_eventos_2018_2024_modelo2['Status'].value_counts()
print("\nBalanceamento da variável 'Status':")
display(status_counts)
# Out:
# Balanceamento da variável 'Status':
# Status
# 1    7549
# 0     726
# Name: count, dtype: int64

# %% [markdown]
# ### Modelos

# %% [markdown]
# #### Treino e Teste

# %%
X = df_eventos_2018_2024_modelo2.drop('Status', axis=1)

y = df_eventos_2018_2024_modelo2['Status']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=1
)

# Lista para armazenar os resultados
results_summary = []

# %% [markdown]
# ### Modelo base

# %%
# Modelo base do XGBoost
xgb_base = XGBClassifier(
    random_state=1,
    eval_metric='logloss'
)

# Treinamento do modelo
xgb_base.fit(X_train, y_train)

# Previsões no conjunto de teste
y_pred_base = xgb_base.predict(X_test)
y_pred_proba_base = xgb_base.predict_proba(X_test)[:, 1]

# Previsões no conjunto de treino
y_train_pred_base = xgb_base.predict(X_train)

# Cálculo do recall no conjunto de treino e teste
recall_train_base = recall_score(y_train, y_train_pred_base)
recall_test_base = recall_score(y_test, y_pred_base)

# Relatório de classificação
classification_report_base = classification_report(
    y_test, y_pred_base, digits=6, target_names=['Não reconhecido', 'Reconhecido']
)
print('Classification Report - XGBoost Base:\n', classification_report_base)

# Plotagem da Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(
    xgb_base, X_test, y_test,
    values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido']
)
plt.title('Matriz de Confusão - XGBoost Base')
plt.show()

# Cálculo das métricas
metrics_base = {
    'model': 'XGBoost Base',
    'accuracy_train': xgb_base.score(X_train, y_train),
    'accuracy_test': xgb_base.score(X_test, y_test),
    'recall_train': recall_train_base,
    'recall_test': recall_test_base,
    'precision': metrics.precision_score(y_test, y_pred_base),
    'f1': metrics.f1_score(y_test, y_pred_base),
    'auc_roc': roc_auc_score(y_test, y_pred_proba_base),
    'auc_pr': auc(*precision_recall_curve(y_test, y_pred_proba_base)[1::-1]),
}

# Plotagem das curvas para o XGBoost Base
plot_roc_pr_curves(y_test, y_pred_proba_base, 'XGBoost Base')
# Out:
# Classification Report - XGBoost Base:
#                   precision    recall  f1-score   support
#
# Não reconhecido   0.816667  0.337931  0.478049       145
#     Reconhecido   0.939812  0.992715  0.965539      1510
#
#        accuracy                       0.935347      1655
#       macro avg   0.878239  0.665323  0.721794      1655
#    weighted avg   0.929023  0.935347  0.922829      1655

# %% [markdown]
# #### Ajuste de Hiperparâmetros de Thakur (2020) com BayesSearchCV, scale_pos_weight = classe minoritária / classe majoritária e score = recall_score

# %%
# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],
    'xgb__min_child_weight': [1, 3, 5, 7],
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__lambda': [0.01, 0.1, 1.0],
    'xgb__alpha': [0, 0.1, 0.5, 1.0]
}

# Usar recall como métrica de scoring
scorer = make_scorer(recall_score)

# Definir scale_pos_weight
scale_pos_weight = np.sqrt(y_train.value_counts()[0] / y_train.value_counts()[1])

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb = Pipeline([
    ('scaler', RobustScaler()),  
    ('xgb', XGBClassifier(
        random_state=1,
        eval_metric='logloss',  
        scale_pos_weight=scale_pos_weight 
    ))
])

# Realizar a busca bayesiana com validação cruzada
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

bayes_search_xgb = BayesSearchCV(
    pipeline_xgb,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=cv,
    scoring=scorer,
    n_jobs=-1,
    random_state=1
)

# Treinar o modelo
bayes_search_xgb.fit(X_train, y_train)

# Melhor modelo encontrado
best_xgb_model = bayes_search_xgb.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros com scale_pos_weight e hiperparâmetros de Thakur (2020): {bayes_search_xgb.best_params_}")

# Previsões no conjunto de teste
y_pred_tuned = best_xgb_model.predict(X_test)
y_pred_proba_tuned = best_xgb_model.predict_proba(X_test)[:, 1]

# Previsões no conjunto de treino
y_train_pred_tuned = best_xgb_model.predict(X_train)

# Cálculo do recall no conjunto de treino e teste
recall_train_tuned = recall_score(y_train, y_train_pred_tuned)
recall_test_tuned = recall_score(y_test, y_pred_tuned)

# Relatório de classificação
classification_report_tuned = classification_report(
    y_test, y_pred_tuned, digits=6, target_names=['Não reconhecido', 'Reconhecido']
)
print('Classification Report - XGBoost Tunado:\n', classification_report_tuned)

# Plotagem da Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(
    best_xgb_model, X_test, y_test,
    values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido']
)
plt.title('Matriz de Confusão - XGBoost com hiperparâmetros de Thakur (2020)')
plt.show()

# Cálculo das métricas
metrics_tuned = {
    'model': 'XGBoost Tunado',
    'accuracy_train': best_xgb_model.score(X_train, y_train),
    'accuracy_test': best_xgb_model.score(X_test, y_test),
    'recall_train': recall_train_tuned,
    'recall_test': recall_test_tuned,
    'precision': metrics.precision_score(y_test, y_pred_tuned),
    'f1': metrics.f1_score(y_test, y_pred_tuned),
    'auc_roc': roc_auc_score(y_test, y_pred_proba_tuned),
    'auc_pr': auc(*precision_recall_curve(y_test, y_pred_proba_tuned)[1::-1]),
}

# Plotagem das curvas
plot_roc_pr_curves(y_test, y_pred_proba_tuned, 'XGBoost com hiperparâmetros de Thakur (2020)')
# Out:
# Melhores hiperparâmetros com scale_pos_weight e hiperparâmetros de Thakur (2020): OrderedDict({'xgb__alpha': 0.1, 'xgb__colsample_bytree': 0.6, 'xgb__eta': 0.01, 'xgb__gamma': 0.9, 'xgb__lambda': 0.1, 'xgb__max_depth': 3, 'xgb__min_child_weight': 5, 'xgb__subsample': 0.7})
# Classification Report - XGBoost Tunado:
#                   precision    recall  f1-score   support
#
# Não reconhecido   1.000000  0.200000  0.333333       145
#     Reconhecido   0.928659  1.000000  0.963010      1510
#
#        accuracy                       0.929909      1655
#       macro avg   0.964330  0.600000  0.648172      1655
#    weighted avg   0.934910  0.929909  0.907842      1655

# %% [markdown]
# #### Seleção de features
#
# Ajuste de Hiperparâmetros de Thakur (2020) com BayesSearchCV, scale_pos_weight = classe minoritária / classe majoritária e score = recall_score + seleção de features por importância maior que a média

# %%
# Definir scale_pos_weight
scale_pos_weight = np.sqrt(y_train.value_counts()[0] / y_train.value_counts()[1])

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb = Pipeline([
    ('scaler', RobustScaler()),  
    ('xgb', XGBClassifier(
        random_state=1,
        eval_metric='logloss',  
        scale_pos_weight=scale_pos_weight
    ))
])

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],
    'xgb__min_child_weight': [1, 3, 5, 7],
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__lambda': [0.01, 0.1, 1.0],
    'xgb__alpha': [0, 0.1, 0.5, 1.0]
}

# Usar recall como métrica de scoring
scorer = make_scorer(recall_score)

# Realizar a busca bayesiana com validação cruzada
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

bayes_search_xgb = BayesSearchCV(
    pipeline_xgb,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=cv,
    scoring=scorer,
    n_jobs=-1,
    random_state=1
)

# Treinar o modelo
bayes_search_xgb.fit(X_train, y_train)

# Melhor modelo encontrado
best_xgb_model = bayes_search_xgb.best_estimator_

# Acessar o estimador XGBClassifier dentro do pipeline
xgb_estimator = best_xgb_model.named_steps['xgb']

# Obter importâncias das features
feature_importances = pd.Series(
    xgb_estimator.feature_importances_, 
    index=X_train.columns
)
feature_importances = feature_importances.sort_values(ascending=False)

# Plotar as 20 features mais importantes
plt.figure(figsize=(10, 8))
sns.barplot(x=feature_importances[:20], y=feature_importances.index[:20])
plt.title('Top 20 Features Importantes')
plt.xlabel('Importância')
plt.ylabel('Features')
plt.show()

# Selecionar as features com importância maior que a média
selector = SelectFromModel(xgb_estimator, threshold='mean', prefit=True)
X_train_selected = selector.transform(X_train)
X_test_selected = selector.transform(X_test)

# Atualizar o pipeline para usar apenas as features selecionadas
pipeline_xgb_selected = Pipeline([
    ('scaler', RobustScaler()),
    ('xgb', XGBClassifier(
        random_state=1,
        eval_metric='logloss',
        scale_pos_weight=scale_pos_weight
    ))
])

# Realizar a busca bayesiana novamente com os dados selecionados
bayes_search_xgb_selected = BayesSearchCV(
    pipeline_xgb_selected,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=cv,
    scoring=scorer,
    n_jobs=-1,
    random_state=1
)

# Treinar o modelo com as features selecionadas
bayes_search_xgb_selected.fit(X_train_selected, y_train)

# Melhor modelo encontrado
best_xgb_model_selected = bayes_search_xgb_selected.best_estimator_

# Previsões no conjunto de teste
y_pred_selected = best_xgb_model_selected.predict(X_test_selected)
y_pred_proba_selected = best_xgb_model_selected.predict_proba(X_test_selected)[:, 1]

# Previsões no conjunto de treino
y_train_pred_selected = best_xgb_model_selected.predict(X_train_selected)

# Cálculo do recall no conjunto de treino e teste
recall_train_selected = recall_score(y_train, y_train_pred_selected)
recall_test_selected = recall_score(y_test, y_pred_selected)

# Relatório de classificação
classification_report_selected = classification_report(
    y_test, y_pred_selected, digits=6, target_names=['Não reconhecido', 'Reconhecido']
)
print('Classification Report - XGBoost com Features Selecionadas:\n', classification_report_selected)

# Plotagem da Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(
    best_xgb_model_selected, X_test_selected, y_test,
    values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido']
)
plt.title('Matriz de Confusão - XGBoost com Features Selecionadas')
plt.show()

# Cálculo das métricas
metrics_selected = {
    'model': 'XGBoost com Features Selecionadas',
    'accuracy_train': best_xgb_model_selected.score(X_train_selected, y_train),
    'accuracy_test': best_xgb_model_selected.score(X_test_selected, y_test),
    'recall_train': recall_train_selected,
    'recall_test': recall_test_selected,
    'precision': metrics.precision_score(y_test, y_pred_selected),
    'f1': metrics.f1_score(y_test, y_pred_selected),
    'auc_roc': roc_auc_score(y_test, y_pred_proba_selected),
    'auc_pr': auc(*precision_recall_curve(y_test, y_pred_proba_selected)[1::-1]),
}

# Plotagem das curvas
plot_roc_pr_curves(y_test, y_pred_proba_selected, 'XGBoost com Features Selecionadas')
# Out:
# C:\Users\Bruna\PycharmProjects\PrevisorReconhecimento\.venv\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# C:\Users\Bruna\PycharmProjects\PrevisorReconhecimento\.venv\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Classification Report - XGBoost com Features Selecionadas:
#                   precision    recall  f1-score   support
#
# Não reconhecido   0.863636  0.262069  0.402116       145
#     Reconhecido   0.933582  0.996026  0.963794      1510
#
#        accuracy                       0.931722      1655
#       macro avg   0.898609  0.629048  0.682955      1655
#    weighted avg   0.927453  0.931722  0.914583      1655

# %% [markdown]
# #### Feature Engineering
#
# Ajuste de Hiperparâmetros de Thakur (2020) com BayesSearchCV, scale_pos_weight = classe minoritária / classe majoritária e score = recall_score + agregação das variáveis de prejuízo.

# %%
# Criação de novas features
X_train_fe = X_train.copy()
X_test_fe = X_test.copy()

# Features agregadas
X_train_fe['PEPL_Total'] = X_train_fe.filter(like='PEPL_').sum(axis=1)
X_test_fe['PEPL_Total'] = X_test_fe.filter(like='PEPL_').sum(axis=1)

X_train_fe['PEPR_Total'] = X_train_fe.filter(like='PEPR_').sum(axis=1)
X_test_fe['PEPR_Total'] = X_test_fe.filter(like='PEPR_').sum(axis=1)

# Definir scale_pos_weight
scale_pos_weight = np.sqrt(y_train.value_counts()[0] / y_train.value_counts()[1])

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb_fe = Pipeline([
    ('scaler', RobustScaler()),
    ('xgb', XGBClassifier(
        random_state=1,
        scale_pos_weight=scale_pos_weight
    ))
])

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],
    'xgb__min_child_weight': [1, 3, 5, 7],
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__lambda': [0.01, 0.1, 1.0],
    'xgb__alpha': [0, 0.1, 0.5, 1.0]
}

# Usar recall como métrica de scoring
scorer = make_scorer(recall_score)

# Realizar a busca bayesiana com validação cruzada
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

bayes_search_xgb_fe = BayesSearchCV(
    pipeline_xgb_fe,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=cv,
    scoring=scorer,
    n_jobs=-1,
    random_state=1
)

# Treinar o modelo com feature engineering
bayes_search_xgb_fe.fit(X_train_fe, y_train)

# Melhor modelo encontrado
best_xgb_model_fe = bayes_search_xgb_fe.best_estimator_

# Previsões no conjunto de teste
y_pred_fe = best_xgb_model_fe.predict(X_test_fe)
y_pred_proba_fe = best_xgb_model_fe.predict_proba(X_test_fe)[:, 1]

# Previsões no conjunto de treino
y_train_pred_fe = best_xgb_model_fe.predict(X_train_fe)

# Cálculo do recall no conjunto de treino e teste
recall_train_fe = recall_score(y_train, y_train_pred_fe)
recall_test_fe = recall_score(y_test, y_pred_fe)

# Relatório de classificação
classification_report_fe = classification_report(
    y_test, y_pred_fe, digits=6, target_names=['Não reconhecido', 'Reconhecido']
)
print('Classification Report - XGBoost com Feature Engineering:\n', classification_report_fe)

# Plotagem da Matriz de Confusão
ConfusionMatrixDisplay.from_estimator(
    best_xgb_model_fe, X_test_fe, y_test,
    values_format='d', cmap='Blues', display_labels=['Não reconhecido', 'Reconhecido']
)
plt.title('Matriz de Confusão - XGBoost com Feature Engineering')
plt.show()

# Cálculo das métricas
metrics_fe = {
    'model': 'XGBoost com Feature Engineering',
    'accuracy_train': best_xgb_model_fe.score(X_train_fe, y_train),
    'accuracy_test': best_xgb_model_fe.score(X_test_fe, y_test),
    'recall_train': recall_train_fe,
    'recall_test': recall_test_fe,
    'precision': metrics.precision_score(y_test, y_pred_fe),
    'f1': metrics.f1_score(y_test, y_pred_fe),
    'auc_roc': roc_auc_score(y_test, y_pred_proba_fe),
    'auc_pr': auc(*precision_recall_curve(y_test, y_pred_proba_fe)[1::-1]),
}

# Plotagem das curvas
plot_roc_pr_curves(y_test, y_pred_proba_fe, 'XGBoost com Feature Engineering')
# Out:
# Classification Report - XGBoost com Feature Engineering:
#                   precision    recall  f1-score   support
#
# Não reconhecido   0.904762  0.262069  0.406417       145
#     Reconhecido   0.933664  0.997351  0.964457      1510
#
#        accuracy                       0.932931      1655
#       macro avg   0.919213  0.629710  0.685437      1655
#    weighted avg   0.931132  0.932931  0.915566      1655

# %% [markdown]
# ### Resumo das métricas

# %%
results_summary.append(metrics_base)
results_summary.append(metrics_tuned)
results_summary.append(metrics_selected)
results_summary.append(metrics_fe)

# Criação de um DataFrame com as métricas
resultados_xgboost_adicionais = pd.DataFrame(results_summary)
resultados_xgboost_adicionais = resultados_xgboost_adicionais[['model', 'accuracy_train', 'accuracy_test', 'recall_train', 'recall_test', 'precision', 'f1', 'auc_roc', 'auc_pr']]

# Exibir a tabela de resultados
estilo_tabelas(resultados_xgboost_adicionais)
# Out:
# <style type="text/css">
# #T_52b1e thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_52b1e td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_52b1e tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_52b1e table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_52b1e td {
#   border: 1px solid #666;
# }
# #T_52b1e  th {
#   border: 1px solid #666;
# }
# #T_52b1e_row0_col0, #T_52b1e_row0_col1, #T_52b1e_row0_col2, #T_52b1e_row0_col3, #T_52b1e_row0_col4, #T_52b1e_row0_col5, #T_52b1e_row0_col6, #T_52b1e_row0_col7, #T_52b1e_row0_col8, #T_52b1e_row1_col0, #T_52b1e_row1_col1, #T_52b1e_row1_col2, #T_52b1e_row1_col3, #T_52b1e_row1_col4, #T_52b1e_row1_col5, #T_52b1e_row1_col6, #T_52b1e_row1_col7, #T_52b1e_row1_col8, #T_52b1e_row2_col0, #T_52b1e_row2_col1, #T_52b1e_row2_col2, #T_52b1e_row2_col3, #T_52b1e_row2_col4, #T_52b1e_row2_col5, #T_52b1e_row2_col6, #T_52b1e_row2_col7, #T_52b1e_row2_col8, #T_52b1e_row3_col0, #T_52b1e_row3_col1, #T_52b1e_row3_col2, #T_52b1e_row3_col3, #T_52b1e_row3_col4, #T_52b1e_row3_col5, #T_52b1e_row3_col6, #T_52b1e_row3_col7, #T_52b1e_row3_col8 {
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_52b1e" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52b1e_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_52b1e_level0_col1" class="col_heading level0 col1" >accuracy_train</th>
#       <th id="T_52b1e_level0_col2" class="col_heading level0 col2" >accuracy_test</th>
#       <th id="T_52b1e_level0_col3" class="col_heading level0 col3" >recall_train</th>
#       <th id="T_52b1e_level0_col4" class="col_heading level0 col4" >recall_test</th>
#       <th id="T_52b1e_level0_col5" class="col_heading level0 col5" >precision</th>
#       <th id="T_52b1e_level0_col6" class="col_heading level0 col6" >f1</th>
#       <th id="T_52b1e_level0_col7" class="col_heading level0 col7" >auc_roc</th>
#       <th id="T_52b1e_level0_col8" class="col_heading level0 col8" >auc_pr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52b1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52b1e_row0_col0" class="data row0 col0" >XGBoost Base</td>
#       <td id="T_52b1e_row0_col1" class="data row0 col1" >0.996</td>
#       <td id="T_52b1e_row0_col2" class="data row0 col2" >0.935</td>
#       <td id="T_52b1e_row0_col3" class="data row0 col3" >1.000</td>
#       <td id="T_52b1e_row0_col4" class="data row0 col4" >0.993</td>
#       <td id="T_52b1e_row0_col5" class="data row0 col5" >0.940</td>
#       <td id="T_52b1e_row0_col6" class="data row0 col6" >0.966</td>
#       <td id="T_52b1e_row0_col7" class="data row0 col7" >0.824</td>
#       <td id="T_52b1e_row0_col8" class="data row0 col8" >0.975</td>
#     </tr>
#     <tr>
#       <th id="T_52b1e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52b1e_row1_col0" class="data row1 col0" >XGBoost Tunado</td>
#       <td id="T_52b1e_row1_col1" class="data row1 col1" >0.931</td>
#       <td id="T_52b1e_row1_col2" class="data row1 col2" >0.930</td>
#       <td id="T_52b1e_row1_col3" class="data row1 col3" >1.000</td>
#       <td id="T_52b1e_row1_col4" class="data row1 col4" >1.000</td>
#       <td id="T_52b1e_row1_col5" class="data row1 col5" >0.929</td>
#       <td id="T_52b1e_row1_col6" class="data row1 col6" >0.963</td>
#       <td id="T_52b1e_row1_col7" class="data row1 col7" >0.825</td>
#       <td id="T_52b1e_row1_col8" class="data row1 col8" >0.977</td>
#     </tr>
#     <tr>
#       <th id="T_52b1e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_52b1e_row2_col0" class="data row2 col0" >XGBoost com Features Selecionadas</td>
#       <td id="T_52b1e_row2_col1" class="data row2 col1" >0.944</td>
#       <td id="T_52b1e_row2_col2" class="data row2 col2" >0.932</td>
#       <td id="T_52b1e_row2_col3" class="data row2 col3" >0.998</td>
#       <td id="T_52b1e_row2_col4" class="data row2 col4" >0.996</td>
#       <td id="T_52b1e_row2_col5" class="data row2 col5" >0.934</td>
#       <td id="T_52b1e_row2_col6" class="data row2 col6" >0.964</td>
#       <td id="T_52b1e_row2_col7" class="data row2 col7" >0.843</td>
#       <td id="T_52b1e_row2_col8" class="data row2 col8" >0.980</td>
#     </tr>
#     <tr>
#       <th id="T_52b1e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_52b1e_row3_col0" class="data row3 col0" >XGBoost com Feature Engineering</td>
#       <td id="T_52b1e_row3_col1" class="data row3 col1" >0.945</td>
#       <td id="T_52b1e_row3_col2" class="data row3 col2" >0.933</td>
#       <td id="T_52b1e_row3_col3" class="data row3 col3" >0.999</td>
#       <td id="T_52b1e_row3_col4" class="data row3 col4" >0.997</td>
#       <td id="T_52b1e_row3_col5" class="data row3 col5" >0.934</td>
#       <td id="T_52b1e_row3_col6" class="data row3 col6" >0.964</td>
#       <td id="T_52b1e_row3_col7" class="data row3 col7" >0.846</td>
#       <td id="T_52b1e_row3_col8" class="data row3 col8" >0.978</td>
#     </tr>
#   </tbody>
# </table>
