# %% [markdown]
# ## Variáveis agregadas (2010 a 2017)
#
#
# Neste teste será considerada a base de dados completa, sem considerar o pré-processamento dos dados indicado no capítulo "Pré Processamento".

# %% [markdown]
# ### Bibliotecas e base de dados

# %%
# Importar bibliotecas
import pandas as pd
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn import metrics
from skopt import BayesSearchCV
from sklearn import metrics
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt

#Estilizar conteúdo
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},  # Bordas cinza escuro
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        ).format(
            precision=casas_decimais  
        )
    )

# Importar a base de dados

df_eventos_2010_2017_modelo1 = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2010_2017_modelo1.csv",
    sep=';',
    decimal=',',
)

estilo_tabelas(df_eventos_2010_2017_modelo1.head(5))
# Out:
# <style type="text/css">
# #T_db224 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_db224 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_db224 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_db224 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_db224 td {
#   border: 1px solid #666;
# }
# #T_db224  th {
#   border: 1px solid #666;
# }
# #T_db224_row0_col0, #T_db224_row0_col1, #T_db224_row0_col2, #T_db224_row0_col3, #T_db224_row0_col4, #T_db224_row0_col5, #T_db224_row0_col6, #T_db224_row0_col7, #T_db224_row0_col8, #T_db224_row0_col9, #T_db224_row0_col10, #T_db224_row0_col11, #T_db224_row0_col12, #T_db224_row0_col13, #T_db224_row0_col14, #T_db224_row0_col15, #T_db224_row0_col16, #T_db224_row0_col17, #T_db224_row0_col18, #T_db224_row0_col19, #T_db224_row0_col20, #T_db224_row0_col21, #T_db224_row0_col22, #T_db224_row0_col23, #T_db224_row0_col24, #T_db224_row0_col25, #T_db224_row0_col26, #T_db224_row0_col27, #T_db224_row0_col28, #T_db224_row0_col29, #T_db224_row0_col30, #T_db224_row0_col31, #T_db224_row0_col32, #T_db224_row0_col33, #T_db224_row0_col34, #T_db224_row0_col35, #T_db224_row0_col36, #T_db224_row0_col37, #T_db224_row0_col38, #T_db224_row0_col39, #T_db224_row0_col40, #T_db224_row0_col41, #T_db224_row0_col42, #T_db224_row0_col43, #T_db224_row0_col44, #T_db224_row0_col45, #T_db224_row0_col46, #T_db224_row0_col47, #T_db224_row0_col48, #T_db224_row0_col49, #T_db224_row0_col50, #T_db224_row0_col51, #T_db224_row0_col52, #T_db224_row0_col53, #T_db224_row0_col54, #T_db224_row0_col55, #T_db224_row1_col0, #T_db224_row1_col1, #T_db224_row1_col2, #T_db224_row1_col3, #T_db224_row1_col4, #T_db224_row1_col5, #T_db224_row1_col6, #T_db224_row1_col7, #T_db224_row1_col8, #T_db224_row1_col9, #T_db224_row1_col10, #T_db224_row1_col11, #T_db224_row1_col12, #T_db224_row1_col13, #T_db224_row1_col14, #T_db224_row1_col15, #T_db224_row1_col16, #T_db224_row1_col17, #T_db224_row1_col18, #T_db224_row1_col19, #T_db224_row1_col20, #T_db224_row1_col21, #T_db224_row1_col22, #T_db224_row1_col23, #T_db224_row1_col24, #T_db224_row1_col25, #T_db224_row1_col26, #T_db224_row1_col27, #T_db224_row1_col28, #T_db224_row1_col29, #T_db224_row1_col30, #T_db224_row1_col31, #T_db224_row1_col32, #T_db224_row1_col33, #T_db224_row1_col34, #T_db224_row1_col35, #T_db224_row1_col36, #T_db224_row1_col37, #T_db224_row1_col38, #T_db224_row1_col39, #T_db224_row1_col40, #T_db224_row1_col41, #T_db224_row1_col42, #T_db224_row1_col43, #T_db224_row1_col44, #T_db224_row1_col45, #T_db224_row1_col46, #T_db224_row1_col47, #T_db224_row1_col48, #T_db224_row1_col49, #T_db224_row1_col50, #T_db224_row1_col51, #T_db224_row1_col52, #T_db224_row1_col53, #T_db224_row1_col54, #T_db224_row1_col55, #T_db224_row2_col0, #T_db224_row2_col1, #T_db224_row2_col2, #T_db224_row2_col3, #T_db224_row2_col4, #T_db224_row2_col5, #T_db224_row2_col6, #T_db224_row2_col7, #T_db224_row2_col8, #T_db224_row2_col9, #T_db224_row2_col10, #T_db224_row2_col11, #T_db224_row2_col12, #T_db224_row2_col13, #T_db224_row2_col14, #T_db224_row2_col15, #T_db224_row2_col16, #T_db224_row2_col17, #T_db224_row2_col18, #T_db224_row2_col19, #T_db224_row2_col20, #T_db224_row2_col21, #T_db224_row2_col22, #T_db224_row2_col23, #T_db224_row2_col24, #T_db224_row2_col25, #T_db224_row2_col26, #T_db224_row2_col27, #T_db224_row2_col28, #T_db224_row2_col29, #T_db224_row2_col30, #T_db224_row2_col31, #T_db224_row2_col32, #T_db224_row2_col33, #T_db224_row2_col34, #T_db224_row2_col35, #T_db224_row2_col36, #T_db224_row2_col37, #T_db224_row2_col38, #T_db224_row2_col39, #T_db224_row2_col40, #T_db224_row2_col41, #T_db224_row2_col42, #T_db224_row2_col43, #T_db224_row2_col44, #T_db224_row2_col45, #T_db224_row2_col46, #T_db224_row2_col47, #T_db224_row2_col48, #T_db224_row2_col49, #T_db224_row2_col50, #T_db224_row2_col51, #T_db224_row2_col52, #T_db224_row2_col53, #T_db224_row2_col54, #T_db224_row2_col55, #T_db224_row3_col0, #T_db224_row3_col1, #T_db224_row3_col2, #T_db224_row3_col3, #T_db224_row3_col4, #T_db224_row3_col5, #T_db224_row3_col6, #T_db224_row3_col7, #T_db224_row3_col8, #T_db224_row3_col9, #T_db224_row3_col10, #T_db224_row3_col11, #T_db224_row3_col12, #T_db224_row3_col13, #T_db224_row3_col14, #T_db224_row3_col15, #T_db224_row3_col16, #T_db224_row3_col17, #T_db224_row3_col18, #T_db224_row3_col19, #T_db224_row3_col20, #T_db224_row3_col21, #T_db224_row3_col22, #T_db224_row3_col23, #T_db224 ...
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_db224" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db224_level0_col0" class="col_heading level0 col0" >Status</th>
#       <th id="T_db224_level0_col1" class="col_heading level0 col1" >DH_total_danos_humanos</th>
#       <th id="T_db224_level0_col2" class="col_heading level0 col2" >DM_total_danos_materiais</th>
#       <th id="T_db224_level0_col3" class="col_heading level0 col3" >PEPL_total_publico</th>
#       <th id="T_db224_level0_col4" class="col_heading level0 col4" >PEPR_total_privado</th>
#       <th id="T_db224_level0_col5" class="col_heading level0 col5" >regiao_Centro-oeste</th>
#       <th id="T_db224_level0_col6" class="col_heading level0 col6" >regiao_Nordeste</th>
#       <th id="T_db224_level0_col7" class="col_heading level0 col7" >regiao_Norte</th>
#       <th id="T_db224_level0_col8" class="col_heading level0 col8" >regiao_Sudeste</th>
#       <th id="T_db224_level0_col9" class="col_heading level0 col9" >regiao_Sul</th>
#       <th id="T_db224_level0_col10" class="col_heading level0 col10" >COBRADE_11110</th>
#       <th id="T_db224_level0_col11" class="col_heading level0 col11" >COBRADE_11120</th>
#       <th id="T_db224_level0_col12" class="col_heading level0 col12" >COBRADE_11311</th>
#       <th id="T_db224_level0_col13" class="col_heading level0 col13" >COBRADE_11312</th>
#       <th id="T_db224_level0_col14" class="col_heading level0 col14" >COBRADE_11313</th>
#       <th id="T_db224_level0_col15" class="col_headi

# %% [markdown]
# ### Ajustes da base de dados

# %%
# Remover linhas com dados ausentes

df_eventos_2018_2024_modelo1 = df_eventos_2010_2017_modelo1.dropna()

estilo_tabelas(df_eventos_2010_2017_modelo1.head(5))
# Out:
# <style type="text/css">
# #T_6c1ba thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_6c1ba td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_6c1ba tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_6c1ba table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_6c1ba td {
#   border: 1px solid #666;
# }
# #T_6c1ba  th {
#   border: 1px solid #666;
# }
# #T_6c1ba_row0_col0, #T_6c1ba_row0_col1, #T_6c1ba_row0_col2, #T_6c1ba_row0_col3, #T_6c1ba_row0_col4, #T_6c1ba_row0_col5, #T_6c1ba_row0_col6, #T_6c1ba_row0_col7, #T_6c1ba_row0_col8, #T_6c1ba_row0_col9, #T_6c1ba_row0_col10, #T_6c1ba_row0_col11, #T_6c1ba_row0_col12, #T_6c1ba_row0_col13, #T_6c1ba_row0_col14, #T_6c1ba_row0_col15, #T_6c1ba_row0_col16, #T_6c1ba_row0_col17, #T_6c1ba_row0_col18, #T_6c1ba_row0_col19, #T_6c1ba_row0_col20, #T_6c1ba_row0_col21, #T_6c1ba_row0_col22, #T_6c1ba_row0_col23, #T_6c1ba_row0_col24, #T_6c1ba_row0_col25, #T_6c1ba_row0_col26, #T_6c1ba_row0_col27, #T_6c1ba_row0_col28, #T_6c1ba_row0_col29, #T_6c1ba_row0_col30, #T_6c1ba_row0_col31, #T_6c1ba_row0_col32, #T_6c1ba_row0_col33, #T_6c1ba_row0_col34, #T_6c1ba_row0_col35, #T_6c1ba_row0_col36, #T_6c1ba_row0_col37, #T_6c1ba_row0_col38, #T_6c1ba_row0_col39, #T_6c1ba_row0_col40, #T_6c1ba_row0_col41, #T_6c1ba_row0_col42, #T_6c1ba_row0_col43, #T_6c1ba_row0_col44, #T_6c1ba_row0_col45, #T_6c1ba_row0_col46, #T_6c1ba_row0_col47, #T_6c1ba_row0_col48, #T_6c1ba_row0_col49, #T_6c1ba_row0_col50, #T_6c1ba_row0_col51, #T_6c1ba_row0_col52, #T_6c1ba_row0_col53, #T_6c1ba_row0_col54, #T_6c1ba_row0_col55, #T_6c1ba_row1_col0, #T_6c1ba_row1_col1, #T_6c1ba_row1_col2, #T_6c1ba_row1_col3, #T_6c1ba_row1_col4, #T_6c1ba_row1_col5, #T_6c1ba_row1_col6, #T_6c1ba_row1_col7, #T_6c1ba_row1_col8, #T_6c1ba_row1_col9, #T_6c1ba_row1_col10, #T_6c1ba_row1_col11, #T_6c1ba_row1_col12, #T_6c1ba_row1_col13, #T_6c1ba_row1_col14, #T_6c1ba_row1_col15, #T_6c1ba_row1_col16, #T_6c1ba_row1_col17, #T_6c1ba_row1_col18, #T_6c1ba_row1_col19, #T_6c1ba_row1_col20, #T_6c1ba_row1_col21, #T_6c1ba_row1_col22, #T_6c1ba_row1_col23, #T_6c1ba_row1_col24, #T_6c1ba_row1_col25, #T_6c1ba_row1_col26, #T_6c1ba_row1_col27, #T_6c1ba_row1_col28, #T_6c1ba_row1_col29, #T_6c1ba_row1_col30, #T_6c1ba_row1_col31, #T_6c1ba_row1_col32, #T_6c1ba_row1_col33, #T_6c1ba_row1_col34, #T_6c1ba_row1_col35, #T_6c1ba_row1_col36, #T_6c1ba_row1_col37, #T_6c1ba_row1_col38, #T_6c1ba_row1_col39, #T_6c1ba_row1_col40, #T_6c1ba_row1_col41, #T_6c1ba_row1_col42, #T_6c1ba_row1_col43, #T_6c1ba_row1_col44, #T_6c1ba_row1_col45, #T_6c1ba_row1_col46, #T_6c1ba_row1_col47, #T_6c1ba_row1_col48, #T_6c1ba_row1_col49, #T_6c1ba_row1_col50, #T_6c1ba_row1_col51, #T_6c1ba_row1_col52, #T_6c1ba_row1_col53, #T_6c1ba_row1_col54, #T_6c1ba_row1_col55, #T_6c1ba_row2_col0, #T_6c1ba_row2_col1, #T_6c1ba_row2_col2, #T_6c1ba_row2_col3, #T_6c1ba_row2_col4, #T_6c1ba_row2_col5, #T_6c1ba_row2_col6, #T_6c1ba_row2_col7, #T_6c1ba_row2_col8, #T_6c1ba_row2_col9, #T_6c1ba_row2_col10, #T_6c1ba_row2_col11, #T_6c1ba_row2_col12, #T_6c1ba_row2_col13, #T_6c1ba_row2_col14, #T_6c1ba_row2_col15, #T_6c1ba_row2_col16, #T_6c1ba_row2_col17, #T_6c1ba_row2_col18, #T_6c1ba_row2_col19, #T_6c1ba_row2_col20, #T_6c1ba_row2_col21, #T_6c1ba_row2_col22, #T_6c1ba_row2_col23, #T_6c1ba_row2_col24, #T_6c1ba_row2_col25, #T_6c1ba_row2_col26, #T_6c1ba_row2_col27, #T_6c1ba_row2_col28, #T_6c1ba_row2_col29, #T_6c1ba_row2_col30, #T_6c1ba_row2_col31, #T_6c1ba_row2_col32, #T_6c1ba_row2_col33, #T_6c1ba_row2_col34, #T_6c1ba_row2_col35, #T_6c1ba_row2_col36, #T_6c1ba_row2_col37, #T_6c1ba_row2_col38, #T_6c1ba_row2_col39, #T_6c1ba_row2_col40, #T_6c1ba_row2_col41, #T_6c1ba_row2_col42, #T_6c1ba_row2_col43, #T_6c1ba_row2_col44, #T_6c1ba_row2_col45, #T_6c1ba_row2_col46, #T_6c1ba_row2_col47, #T_6c1ba_row2_col48, #T_6c1ba_row2_col49, #T_6c1ba_row2_col50, #T_6c1ba_row2_col51, #T_6c1ba_row2_col52, #T_6c1ba_row2_col53, #T_6c1ba_row2_col54, #T_6c1ba_row2_col55, #T_6c1ba_row3_col0, #T_6c1ba_row3_col1, #T_6c1ba_row3_col2, #T_6c1ba_row3_col3, #T_6c1ba_row3_col4, #T_6c1ba_row3_col5, #T_6c1ba_row3_col6, #T_6c1ba_row3_col7, #T_6c1ba_row3_col8, #T_6c1ba_row3_col9, #T_6c1ba_row3_col10, #T_6c1ba_row3_col11, #T_6c1ba_row3_col12, #T_6c1ba_row3_col13, #T_6c1ba_row3_col14, #T_6c1ba_row3_col15, #T_6c1ba_row3_col16, #T_6c1ba_row3_col17, #T_6c1ba_row3_col18, #T_6c1ba_row3_col19, #T_6c1ba_row3_col20, #T_6c1ba_row3_col21, #T_6c1ba_row3_col22, #T_6c1ba_row3_col23, #T_6c1ba ...
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_6c1ba" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c1ba_level0_col0" class="col_heading level0 col0" >Status</th>
#       <th id="T_6c1ba_level0_col1" class="col_heading level0 col1" >DH_total_danos_humanos</th>
#       <th id="T_6c1ba_level0_col2" class="col_heading level0 col2" >DM_total_danos_materiais</th>
#       <th id="T_6c1ba_level0_col3" class="col_heading level0 col3" >PEPL_total_publico</th>
#       <th id="T_6c1ba_level0_col4" class="col_heading level0 col4" >PEPR_total_privado</th>
#       <th id="T_6c1ba_level0_col5" class="col_heading level0 col5" >regiao_Centro-oeste</th>
#       <th id="T_6c1ba_level0_col6" class="col_heading level0 col6" >regiao_Nordeste</th>
#       <th id="T_6c1ba_level0_col7" class="col_heading level0 col7" >regiao_Norte</th>
#       <th id="T_6c1ba_level0_col8" class="col_heading level0 col8" >regiao_Sudeste</th>
#       <th id="T_6c1ba_level0_col9" class="col_heading level0 col9" >regiao_Sul</th>
#       <th id="T_6c1ba_level0_col10" class="col_heading level0 col10" >COBRADE_11110</th>
#       <th id="T_6c1ba_level0_col11" class="col_heading level0 col11" >COBRADE_11120</th>
#       <th id="T_6c1ba_level0_col12" class="col_heading level0 col12" >COBRADE_11311</th>
#       <th id="T_6c1ba_level0_col13" class="col_heading level0 col13" >COBRADE_11312</th>
#       <th id="T_6c1ba_level0_col14" class="col_heading level0 col14" >COBRADE_11313</th>
#       <th id="T_6c1ba_level0_col15" class="col_headi

# %%
# Balanceamento da variável target

status_counts = df_eventos_2018_2024_modelo1['Status'].value_counts()
print("\nBalanceamento da variável 'Status':")
display(status_counts)
# Out:
# Balanceamento da variável 'Status':
# Status
# 0    11814
# 1     1233
# Name: count, dtype: int64

# %% [markdown]
# ### Modelo sem balanceamento

# %% [markdown]
# #### Treino e teste

# %%
X_2010_2017_modelo1 = df_eventos_2010_2017_modelo1.drop('Status', axis=1)

y_2010_2017_modelo1 = df_eventos_2010_2017_modelo1['Status']

X_train_2010_2017_modelo1, X_test_2010_2017_modelo1, y_train_2010_2017_modelo1, y_test_2010_2017_modelo1 = train_test_split(X_2010_2017_modelo1, y_2010_2017_modelo1, test_size=0.2, random_state=1, stratify=y_2010_2017_modelo1)

# %% [markdown]
# #### Treinamento sem balanceamento
#
# Inicialmente, o modelo foi treinado sem balanceamento e utilizando-se a busca de hiperparâmetros bayesiana com o objetivo de testar os hiperparâmetros. O teste foi feito a partir dos hiperparâmetros sugeridos por Thakur (2020).

# %%
# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],  # Taxa de aprendizado
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],  # Redução mínima da perda
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],  # Profundidade da árvore
    'xgb__min_child_weight': [1, 3, 5, 7],  # Peso mínimo para divisão do nó
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],  # Subamostragem para treinamento
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],  # Subamostragem de colunas
    'xgb__lambda': [0.01, 0.1, 1.0],  # Regularização L2
    'xgb__alpha': [0, 0.1, 0.5, 1.0]  # Regularização L1
}

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb = Pipeline([
    ('scaler', RobustScaler()),  # Alterado para RobustScaler
    ('xgb', xgb.XGBClassifier(random_state=1, eval_metric='logloss'))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_xgb = BayesSearchCV(
    pipeline_xgb,
    search_spaces=param_grid_bayes,
    n_iter=30, 
    cv=3,
    scoring='f1_weighted',
    n_jobs=-1,
    random_state=1
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_xgb.fit(X_train_2010_2017_modelo1, y_train_2010_2017_modelo1)

# Melhor modelo encontrado
best_xgb_model = bayes_search_xgb.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_xgb.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_xgb = best_xgb_model.predict(X_test_2010_2017_modelo1)

# Relatório de classificação
classification_report_xgb = metrics.classification_report(y_test_2010_2017_modelo1, y_pred_xgb, digits=6, target_names=['Reconhecido', 'Não reconhecido'])
print('Classification report para XGBoost: \n')
print(classification_report_xgb)
# Out:
# Melhores hiperparâmetros: OrderedDict([('xgb__alpha', 1.0), ('xgb__colsample_bytree', 0.8), ('xgb__eta', 0.1), ('xgb__gamma', 0.5), ('xgb__lambda', 0.1), ('xgb__max_depth', 12), ('xgb__min_child_weight', 3), ('xgb__subsample', 0.8)])
# Classification report para XGBoost:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.920016  0.988151  0.952867      2363
# Não reconhecido   0.611111  0.178138  0.275862       247
#
#        accuracy                       0.911494      2610
#       macro avg   0.765563  0.583144  0.614364      2610
#    weighted avg   0.890782  0.911494  0.888798      2610

# %%
ConfusionMatrixDisplay.from_estimator(best_xgb_model, X_test_2010_2017_modelo1, y_test_2010_2017_modelo1, values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %% [markdown]
# ### Modelo com balanceamento SMOTE
#
# Treinamento do modelo com balanceamento SMOTE e utilizando-se a busca de hiperparâmetros bayesiana com o objetivo de testar os hiperparâmetros. O teste foi feito a partir dos hiperparâmetros sugeridos por Thakur (2020).

# %% [markdown]
# #### Treino e teste

# %%
X_smote = df_eventos_2010_2017_modelo1.drop('Status', axis=1)

y_smote = df_eventos_2010_2017_modelo1['Status']

X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, y_smote, test_size=0.2, random_state=1, stratify=y_smote)

# %% [markdown]
# #### Treinamento com balanceamento SMOTE

# %%
# Aplicar SMOTE apenas no conjunto de treino
smote = SMOTE(random_state=1)
X_train_smote, y_train_smote = smote.fit_resample(X_train_smote, y_train_smote)

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],
    'xgb__min_child_weight': [1, 3, 5, 7],
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__lambda': [0.01, 0.1, 1.0],
    'xgb__alpha': [0, 0.1, 0.5, 1.0]
}

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb_smote = Pipeline([
    ('scaler', RobustScaler()),  # Usando RobustScaler
    ('xgb', xgb.XGBClassifier(random_state=1, eval_metric='logloss'))
])

# Realizar a busca bayesiana com validação cruzada no conjunto balanceado pelo SMOTE
bayes_search_xgb_smote = BayesSearchCV(
    pipeline_xgb_smote,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=3,
    scoring='f1_weighted',
    n_jobs=-1,
    random_state=1
)

# Ajustar o modelo ao conjunto de treino balanceado
bayes_search_xgb_smote.fit(X_train_smote, y_train_smote)

# Melhor modelo encontrado
best_xgb_model_smote = bayes_search_xgb_smote.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros com balanceamento smote: {bayes_search_xgb_smote.best_params_}")

# Fazer previsões com o conjunto de teste original
y_pred_xgb_smote = best_xgb_model_smote.predict(X_test_smote)

# Relatório de classificação
classification_report_xgb_smote = metrics.classification_report(
    y_test_smote, y_pred_xgb_smote, digits=6, target_names=['Reconhecido', 'Não reconhecido']
)

print('Classification report para XGBoost com SMOTE: \n')
print(classification_report_xgb_smote)
# Out:
# Melhores hiperparâmetros com balanceamento smote: OrderedDict([('xgb__alpha', 0.1), ('xgb__colsample_bytree', 0.8), ('xgb__eta', 0.1), ('xgb__gamma', 0.3), ('xgb__lambda', 0.1), ('xgb__max_depth', 25), ('xgb__min_child_weight', 1), ('xgb__subsample', 0.9)])
# Classification report para XGBoost com SMOTE:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.926346  0.968684  0.947042      2363
# Não reconhecido   0.467626  0.263158  0.336788       247
#
#        accuracy                       0.901916      2610
#       macro avg   0.696986  0.615921  0.641915      2610
#    weighted avg   0.882934  0.901916  0.889290      2610

# %%
ConfusionMatrixDisplay.from_estimator(bayes_search_xgb_smote, X_test_smote, y_test_smote, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %% [markdown]
# ### Avaliação das Variáveis de Importância
#
# Avaliação das variáveis de importância de acordo com o modelo com Smote, que apresentou o maior f1-score.

# %% [markdown]
# #### Feature importance

# %%
# Ajustar o melhor modelo encontrado (depois da busca bayesiana)
best_xgb_model_smote.named_steps['xgb'].fit(X_train_smote, y_train_smote)

# Obter o booster (árvores) do modelo treinado
booster = best_xgb_model_smote.named_steps['xgb'].get_booster()

# Obter a importância das features com base no ganho
importance_dict = booster.get_score(importance_type='gain')

# Transformar em DataFrame para organizar como tabela
importance_df = pd.DataFrame({
    'Feature': list(importance_dict.keys()),
    'Importance': list(importance_dict.values())
})

# Ordenar pela importância em ordem decrescente
importance_df = importance_df.sort_values(by='Importance', ascending=False)

estilo_tabelas(importance_df)
# Out:
# <style type="text/css">
# #T_a4494 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_a4494 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_a4494 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_a4494 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_a4494 td {
#   border: 1px solid #666;
# }
# #T_a4494  th {
#   border: 1px solid #666;
# }
# #T_a4494_row0_col0, #T_a4494_row0_col1, #T_a4494_row1_col0, #T_a4494_row1_col1, #T_a4494_row2_col0, #T_a4494_row2_col1, #T_a4494_row3_col0, #T_a4494_row3_col1, #T_a4494_row4_col0, #T_a4494_row4_col1, #T_a4494_row5_col0, #T_a4494_row5_col1, #T_a4494_row6_col0, #T_a4494_row6_col1, #T_a4494_row7_col0, #T_a4494_row7_col1, #T_a4494_row8_col0, #T_a4494_row8_col1, #T_a4494_row9_col0, #T_a4494_row9_col1, #T_a4494_row10_col0, #T_a4494_row10_col1, #T_a4494_row11_col0, #T_a4494_row11_col1, #T_a4494_row12_col0, #T_a4494_row12_col1, #T_a4494_row13_col0, #T_a4494_row13_col1, #T_a4494_row14_col0, #T_a4494_row14_col1, #T_a4494_row15_col0, #T_a4494_row15_col1, #T_a4494_row16_col0, #T_a4494_row16_col1, #T_a4494_row17_col0, #T_a4494_row17_col1, #T_a4494_row18_col0, #T_a4494_row18_col1, #T_a4494_row19_col0, #T_a4494_row19_col1, #T_a4494_row20_col0, #T_a4494_row20_col1, #T_a4494_row21_col0, #T_a4494_row21_col1, #T_a4494_row22_col0, #T_a4494_row22_col1, #T_a4494_row23_col0, #T_a4494_row23_col1, #T_a4494_row24_col0, #T_a4494_row24_col1, #T_a4494_row25_col0, #T_a4494_row25_col1, #T_a4494_row26_col0, #T_a4494_row26_col1, #T_a4494_row27_col0, #T_a4494_row27_col1, #T_a4494_row28_col0, #T_a4494_row28_col1, #T_a4494_row29_col0, #T_a4494_row29_col1, #T_a4494_row30_col0, #T_a4494_row30_col1, #T_a4494_row31_col0, #T_a4494_row31_col1, #T_a4494_row32_col0, #T_a4494_row32_col1, #T_a4494_row33_col0, #T_a4494_row33_col1 {
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_a4494" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4494_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_a4494_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4494_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_a4494_row0_col0" class="data row0 col0" >regiao_Nordeste</td>
#       <td id="T_a4494_row0_col1" class="data row0 col1" >98.105</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row1" class="row_heading level0 row1" >31</th>
#       <td id="T_a4494_row1_col0" class="data row1 col0" >COBRADE_15110</td>
#       <td id="T_a4494_row1_col1" class="data row1 col1" >59.171</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_a4494_row2_col0" class="data row2 col0" >regiao_Sul</td>
#       <td id="T_a4494_row2_col1" class="data row2 col1" >48.380</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row3" class="row_heading level0 row3" >28</th>
#       <td id="T_a4494_row3_col0" class="data row3 col0" >COBRADE_14120</td>
#       <td id="T_a4494_row3_col1" class="data row3 col1" >27.640</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row4" class="row_heading level0 row4" >27</th>
#       <td id="T_a4494_row4_col0" class="data row4 col0" >COBRADE_14110</td>
#       <td id="T_a4494_row4_col1" class="data row4 col1" >22.958</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_a4494_row5_col0" class="data row5 col0" >COBRADE_12200</td>
#       <td id="T_a4494_row5_col1" class="data row5 col1" >20.970</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_a4494_row6_col0" class="data row6 col0" >COBRADE_12100</td>
#       <td id="T_a4494_row6_col1" class="data row6 col1" >19.307</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a4494_row7_col0" class="data row7 col0" >regiao_Sudeste</td>
#       <td id="T_a4494_row7_col1" class="data row7 col1" >19.160</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row8" class="row_heading level0 row8" >20</th>
#       <td id="T_a4494_row8_col0" class="data row8 col0" >COBRADE_13211</td>
#       <td id="T_a4494_row8_col1" class="data row8 col1" >17.101</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row9" class="row_heading level0 row9" >23</th>
#       <td id="T_a4494_row9_col0" class="data row9 col0" >COBRADE_13214</td>
#       <td id="T_a4494_row9_col1" class="data row9 col1" >15.035</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_a4494_row10_col0" class="data row10 col0" >COBRADE_11432</td>
#       <td id="T_a4494_row10_col1" class="data row10 col1" >14.882</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row11" class="row_heading level0 row11" >6</th>
#       <td id="T_a4494_row11_col0" class="data row11 col0" >regiao_Norte</td>
#       <td id="T_a4494_row11_col1" class="data row11 col1" >12.536</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row12" class="row_heading level0 row12" >24</th>
#       <td id="T_a4494_row12_col0" class="data row12 col0" >COBRADE_13215</td>
#       <td id="T_a4494_row12_col1" class="data row12 col1" >7.640</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row13" class="row_heading level0 row13" >22</th>
#       <td id="T_a4494_row13_col0" class="data row13 col0" >COBRADE_13213</td>
#       <td id="T_a4494_row13_col1" class="data row13 col1" >7.196</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row14" class="row_heading level0 row14" >25</th>
#       <td id="T_a4494_row14_col0" class="data row14 col0" >COBRADE_13310</td>
#       <td id="T_a4494_row14_col1" class="data row14 col1" >6.109</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row15" class="row_heading level0 row15" >4</th>
#       <td id="T_a4494_row15_col0" class="data row15 col0" >regiao_Centro-oeste</td>
#       <td id="T_a4494_row15_col1" class="data row15 col1" >5.701</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row16" class="row_heading level0 row16" >10</th>
#       <td id="T_a4494_row16_col0" class="data row16 col0" >COBRADE_11331</td>
#       <td id="T_a4494_row16_col1" class="data row16 col1" >5.661</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_a4494_row17_col0" class="data row17 col0" >COBRADE_13112</td>
#       <td id="T_a4494_row17_col1" class="data row17 col1" >5.031</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row18" class="row_heading level0 row18" >21</th>
#       <td id="T_a4494_row18_col0" class="data row18 col0" >COBRADE_13212</td>
#       <td id="T_a4494_row18_col1" class="data row18 col1" >4.527</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row19" class="row_heading level0 row19" >17</th>
#       <td id="T_a4494_row19_col0" class="data row19 col0" >COBRADE_12300</td>
#       <td id="T_a4494_row19_col1" class="data row19 col1" >4.366</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row20" class="row_heading level0 row20" >9</th>
#       <td id="T_a4494_row20_col0" class="data row20 col0" >COBRADE_11321</td>
#       <td id="T_a4494_row20_col1" class="data row20 col1" >4.122</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row21" class="row_heading level0 row21" >26</th>
#       <td id="T_a4494_row21_col0" class="data row21 col0" >COBRADE_13322</td>
#       <td id="T_a4494_row21_col1" class="data row21 col1" >4.066</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_level0_row22" class="row_heading level0 row22" >29</th>
#       <td id="T_a4494_row22_col0" class="data row22 col0" >COBRADE_14131</td>
#       <td id="T_a4494_row22_col1" class="data row22 col1" >3.722</td>
#     </tr>
#     <tr>
#       <th id="T_a4494_leve

# %% [markdown]
# #### Permutation importance

# %%
# Calcular a permutação de importância no conjunto de teste
result = permutation_importance(best_xgb_model_smote, X_test_smote, y_test_smote, n_repeats=5, random_state=1, n_jobs=-1)

# Ordenar os resultados pela importância média
sorted_idx = result.importances_mean.argsort()

# Gráfico boxplot para mostrar a importância das variáveis
fig, ax = plt.subplots()
ax.boxplot(result.importances[sorted_idx].T, vert=False, tick_labels=X_test_smote.columns[sorted_idx])
ax.set_title("Permutation Importances (test set)")
fig.set_size_inches(15, 20) 
fig.tight_layout()
plt.show()
