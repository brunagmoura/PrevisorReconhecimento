# %% [markdown]
# ## Variáveis agregadas (2018 a 2024)

# %% [markdown]
# ### Bibliotecas e base de dados

# %%
# Importar bibliotecas
import pandas as pd
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn import metrics
from skopt import BayesSearchCV
from sklearn import metrics
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt

#Estilizar conteúdo
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},  # Bordas cinza escuro
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        ).format(
            precision=casas_decimais  
        )
    )

# Importar a base de dados

df_eventos_2018_2024_modelo2 = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2018_2024_modelo2.csv",
    sep=';',
    decimal=',',
)

estilo_tabelas(df_eventos_2018_2024_modelo2.head(5))
# Out:
# <style type="text/css">
# #T_b1a68 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_b1a68 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_b1a68 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_b1a68 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_b1a68 td {
#   border: 1px solid #666;
# }
# #T_b1a68  th {
#   border: 1px solid #666;
# }
# #T_b1a68_row0_col0, #T_b1a68_row0_col1, #T_b1a68_row0_col2, #T_b1a68_row0_col3, #T_b1a68_row0_col4, #T_b1a68_row0_col5, #T_b1a68_row0_col6, #T_b1a68_row0_col7, #T_b1a68_row0_col8, #T_b1a68_row0_col9, #T_b1a68_row0_col10, #T_b1a68_row0_col11, #T_b1a68_row0_col12, #T_b1a68_row0_col13, #T_b1a68_row0_col14, #T_b1a68_row0_col15, #T_b1a68_row0_col16, #T_b1a68_row0_col17, #T_b1a68_row0_col18, #T_b1a68_row0_col19, #T_b1a68_row0_col20, #T_b1a68_row0_col21, #T_b1a68_row0_col22, #T_b1a68_row0_col23, #T_b1a68_row0_col24, #T_b1a68_row0_col25, #T_b1a68_row0_col26, #T_b1a68_row0_col27, #T_b1a68_row0_col28, #T_b1a68_row0_col29, #T_b1a68_row0_col30, #T_b1a68_row0_col31, #T_b1a68_row0_col32, #T_b1a68_row0_col33, #T_b1a68_row0_col34, #T_b1a68_row0_col35, #T_b1a68_row0_col36, #T_b1a68_row0_col37, #T_b1a68_row0_col38, #T_b1a68_row0_col39, #T_b1a68_row0_col40, #T_b1a68_row0_col41, #T_b1a68_row0_col42, #T_b1a68_row0_col43, #T_b1a68_row0_col44, #T_b1a68_row0_col45, #T_b1a68_row0_col46, #T_b1a68_row0_col47, #T_b1a68_row0_col48, #T_b1a68_row0_col49, #T_b1a68_row0_col50, #T_b1a68_row0_col51, #T_b1a68_row0_col52, #T_b1a68_row0_col53, #T_b1a68_row0_col54, #T_b1a68_row0_col55, #T_b1a68_row0_col56, #T_b1a68_row0_col57, #T_b1a68_row0_col58, #T_b1a68_row0_col59, #T_b1a68_row0_col60, #T_b1a68_row0_col61, #T_b1a68_row0_col62, #T_b1a68_row0_col63, #T_b1a68_row0_col64, #T_b1a68_row0_col65, #T_b1a68_row0_col66, #T_b1a68_row0_col67, #T_b1a68_row0_col68, #T_b1a68_row0_col69, #T_b1a68_row0_col70, #T_b1a68_row0_col71, #T_b1a68_row0_col72, #T_b1a68_row0_col73, #T_b1a68_row0_col74, #T_b1a68_row0_col75, #T_b1a68_row0_col76, #T_b1a68_row0_col77, #T_b1a68_row0_col78, #T_b1a68_row0_col79, #T_b1a68_row0_col80, #T_b1a68_row0_col81, #T_b1a68_row0_col82, #T_b1a68_row0_col83, #T_b1a68_row0_col84, #T_b1a68_row0_col85, #T_b1a68_row0_col86, #T_b1a68_row0_col87, #T_b1a68_row0_col88, #T_b1a68_row0_col89, #T_b1a68_row0_col90, #T_b1a68_row0_col91, #T_b1a68_row0_col92, #T_b1a68_row0_col93, #T_b1a68_row0_col94, #T_b1a68_row0_col95, #T_b1a68_row0_col96, #T_b1a68_row0_col97, #T_b1a68_row0_col98, #T_b1a68_row0_col99, #T_b1a68_row0_col100, #T_b1a68_row0_col101, #T_b1a68_row0_col102, #T_b1a68_row0_col103, #T_b1a68_row0_col104, #T_b1a68_row0_col105, #T_b1a68_row0_col106, #T_b1a68_row0_col107, #T_b1a68_row0_col108, #T_b1a68_row0_col109, #T_b1a68_row0_col110, #T_b1a68_row0_col111, #T_b1a68_row0_col112, #T_b1a68_row0_col113, #T_b1a68_row0_col114, #T_b1a68_row0_col115, #T_b1a68_row0_col116, #T_b1a68_row0_col117, #T_b1a68_row0_col118, #T_b1a68_row0_col119, #T_b1a68_row0_col120, #T_b1a68_row0_col121, #T_b1a68_row1_col0, #T_b1a68_row1_col1, #T_b1a68_row1_col2, #T_b1a68_row1_col3, #T_b1a68_row1_col4, #T_b1a68_row1_col5, #T_b1a68_row1_col6, #T_b1a68_row1_col7, #T_b1a68_row1_col8, #T_b1a68_row1_col9, #T_b1a68_row1_col10, #T_b1a68_row1_col11, #T_b1a68_row1_col12, #T_b1a68_row1_col13, #T_b1a68_row1_col14, #T_b1a68_row1_col15, #T_b1a68_row1_col16, #T_b1a68_row1_col17, #T_b1a68_row1_col18, #T_b1a68_row1_col19, #T_b1a68_row1_col20, #T_b1a68_row1_col21, #T_b1a68_row1_col22, #T_b1a68_row1_col23, #T_b1a68_row1_col24, #T_b1a68_row1_col25, #T_b1a68_row1_col26, #T_b1a68_row1_col27, #T_b1a68_row1_col28, #T_b1a68_row1_col29, #T_b1a68_row1_col30, #T_b1a68_row1_col31, #T_b1a68_row1_col32, #T_b1a68_row1_col33, #T_b1a68_row1_col34, #T_b1a68_row1_col35, #T_b1a68_row1_col36, #T_b1a68_row1_col37, #T_b1a68_row1_col38, #T_b1a68_row1_col39, #T_b1a68_row1_col40, #T_b1a68_row1_col41, #T_b1a68_row1_col42, #T_b1a68_row1_col43, #T_b1a68_row1_col44, #T_b1a68_row1_col45, #T_b1a68_row1_col46, #T_b1a68_row1_col47, #T_b1a68_row1_col48, #T_b1a68_row1_col49, #T_b1a68_row1_col50, #T_b1a68_row1_col51, #T_b1a68_row1_col52, #T_b1a68_row1_col53, #T_b1a68_row1_col54, #T_b1a68_row1_col55, #T_b1a68_row1_col56, #T_b1a68_row1_col57, #T_b1a68_row1_col58, #T_b1a68_row1_col59, #T_b1a68_row1_col60, #T_b1a68_row1_col61, #T_b1a68_row1_col62, #T_b1a68_row1_col63, #T_b1a68_row1_col64, #T_b1a68_row1_col65, #T_b1a68_row1_col66, #T_b1a68_row1_col67, #T_b1a68 ...

# %% [markdown]
# ### Ajustes da base de dados

# %%
# Remover linhas com dados ausentes

df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.dropna()

estilo_tabelas(df_eventos_2018_2024_modelo2.head(5))

# Remover linhas com todos os dados informados = 0.

colunas_informados = [
    'DH_MORTOS', 'DH_FERIDOS', 'DH_ENFERMOS', 'DH_DESABRIGADOS', 'DH_DESALOJADOS', 
    'DH_DESAPARECIDOS', 'DH_OUTROS AFETADOS', 
    'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas', 'DM_Uni Habita Valor', 
    'DM_Inst Saúde Danificadas', 'DM_Inst Saúde Destruidas', 'DM_Inst Saúde Valor', 
    'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas', 'DM_Inst Ensino Valor', 
    'DM_Inst Serviços Danificadas', 'DM_Inst Serviços Destruidas', 'DM_Inst Serviços Valor', 
    'DM_Inst Comuni Danificadas', 'DM_Inst Comuni Destruidas', 'DM_Inst Comuni Valor', 
    'DM_Obras de Infra Danificadas', 'DM_Obras de Infra Destruidas', 'DM_Obras de Infra Valor', 
    'PEPL_Assis_méd e emergên(R$)', 'PEPL_Abast de água pot(R$)', 
    'PEPL_sist de esgotos sanit(R$)', 'PEPL_Sis limp e rec lixo (R$)', 'PEPL_Sis cont pragas (R$)', 
    'PEPL_distrib energia (R$)', 'PEPL_Telecomunicações (R$)', 'PEPL_Tran loc/reg/l_curso (R$)', 
    'PEPL_Distrib combustíveis(R$)', 'PEPL_Segurança pública (R$)', 'PEPL_Ensino (R$)',
    'PEPR_Agricultura (R$)', 'PEPR_Pecuária (R$)', 'PEPR_Indústria (R$)', 'PEPR_Comércio (R$)', 
    'PEPR_Serviços (R$)'
]

df_eventos_2018_2024_modelo2 = df_eventos_2018_2024_modelo2[
    ~(df_eventos_2018_2024_modelo2[colunas_informados] == 0).all(axis=1)
]

# %%
# Balanceamento da variável target

status_counts = df_eventos_2018_2024_modelo2['Status'].value_counts()
print("\nBalanceamento da variável 'Status':")
display(status_counts)
# Out:
# Balanceamento da variável 'Status':
# Status
# 0    7380
# 1     590
# Name: count, dtype: int64

# %% [markdown]
# ### Modelo sem balanceamento

# %% [markdown]
# #### Treino e teste

# %%
X_2018_2024_modelo2 = df_eventos_2018_2024_modelo2.drop('Status', axis=1)

y_2018_2024_modelo2 = df_eventos_2018_2024_modelo2['Status']

X_train_2018_2024_modelo2, X_test_2018_2024_modelo2, y_train_2018_2024_modelo2, y_test_2018_2024_modelo2 = train_test_split(X_2018_2024_modelo2, y_2018_2024_modelo2, test_size=0.2, random_state=1, stratify=y_2018_2024_modelo2)

# %% [markdown]
# #### Treinamento sem balanceamento
#
# Inicialmente, o modelo foi treinado sem balanceamento e utilizando-se a busca de hiperparâmetros bayesiana com o objetivo de testar os hiperparâmetros. O teste foi feito a partir dos hiperparâmetros sugeridos por Thakur (2020).

# %%
# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],  # Taxa de aprendizado
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],  # Redução mínima da perda
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],  # Profundidade da árvore
    'xgb__min_child_weight': [1, 3, 5, 7],  # Peso mínimo para divisão do nó
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],  # Subamostragem para treinamento
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],  # Subamostragem de colunas
    'xgb__lambda': [0.01, 0.1, 1.0],  # Regularização L2
    'xgb__alpha': [0, 0.1, 0.5, 1.0]  # Regularização L1
}

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb = Pipeline([
    ('scaler', RobustScaler()),  # Alterado para RobustScaler
    ('xgb', xgb.XGBClassifier(random_state=1, eval_metric='logloss'))
])

# Realizar a busca bayesiana com validação cruzada
bayes_search_xgb = BayesSearchCV(
    pipeline_xgb,
    search_spaces=param_grid_bayes,
    n_iter=30, 
    cv=3,
    scoring='f1_weighted',
    n_jobs=-1,
    random_state=1
)

# Ajustar a busca bayesiana ao conjunto de treino
bayes_search_xgb.fit(X_train_2018_2024_modelo2, y_train_2018_2024_modelo2)

# Melhor modelo encontrado
best_xgb_model = bayes_search_xgb.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {bayes_search_xgb.best_params_}")

# Fazer previsões com o conjunto de teste
y_pred_xgb = best_xgb_model.predict(X_test_2018_2024_modelo2)

# Relatório de classificação
classification_report_xgb = metrics.classification_report(y_test_2018_2024_modelo2, y_pred_xgb, digits=6, target_names=['Reconhecido', 'Não reconhecido'])
print('Classification report para XGBoost: \n')
print(classification_report_xgb)
# Out:
# Melhores hiperparâmetros: OrderedDict([('xgb__alpha', 0), ('xgb__colsample_bytree', 0.9), ('xgb__eta', 0.05), ('xgb__gamma', 1.0), ('xgb__lambda', 1.0), ('xgb__max_depth', 9), ('xgb__min_child_weight', 3), ('xgb__subsample', 1.0)])
# Classification report para XGBoost:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.939258  0.995257  0.966447      1476
# Não reconhecido   0.766667  0.194915  0.310811       118
#
#        accuracy                       0.936010      1594
#       macro avg   0.852962  0.595086  0.638629      1594
#    weighted avg   0.926482  0.936010  0.917912      1594

# %%
ConfusionMatrixDisplay.from_estimator(best_xgb_model, X_test_2018_2024_modelo2, y_test_2018_2024_modelo2, values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %% [markdown]
# ### Modelo com balanceamento SMOTE
#
# Treinamento do modelo com balanceamento SMOTE e utilizando-se a busca de hiperparâmetros bayesiana com o objetivo de testar os hiperparâmetros. O teste foi feito a partir dos hiperparâmetros sugeridos por Thakur (2020).

# %% [markdown]
# #### Treino e teste

# %%
X_smote = df_eventos_2018_2024_modelo2.drop('Status', axis=1)

y_smote = df_eventos_2018_2024_modelo2['Status']

X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, y_smote, test_size=0.2, random_state=1, stratify=y_smote)

# %% [markdown]
# #### Treinamento com balanceamento SMOTE

# %%
# Aplicar SMOTE apenas no conjunto de treino
smote = SMOTE(random_state=1)
X_train_smote, y_train_smote = smote.fit_resample(X_train_smote, y_train_smote)

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],
    'xgb__min_child_weight': [1, 3, 5, 7],
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__lambda': [0.01, 0.1, 1.0],
    'xgb__alpha': [0, 0.1, 0.5, 1.0]
}

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb_smote = Pipeline([
    ('scaler', RobustScaler()),  # Usando RobustScaler
    ('xgb', xgb.XGBClassifier(random_state=1, eval_metric='logloss'))
])

# Realizar a busca bayesiana com validação cruzada no conjunto balanceado pelo SMOTE
bayes_search_xgb_smote = BayesSearchCV(
    pipeline_xgb_smote,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=3,
    scoring='f1_weighted',
    n_jobs=-1,
    random_state=1
)

# Ajustar o modelo ao conjunto de treino balanceado
bayes_search_xgb_smote.fit(X_train_smote, y_train_smote)

# Melhor modelo encontrado
best_xgb_model_smote = bayes_search_xgb_smote.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros com balanceamento smote: {bayes_search_xgb_smote.best_params_}")

# Fazer previsões com o conjunto de teste original
y_pred_xgb_smote = best_xgb_model_smote.predict(X_test_smote)

# Relatório de classificação
classification_report_xgb_smote = metrics.classification_report(
    y_test_smote, y_pred_xgb_smote, digits=6, target_names=['Reconhecido', 'Não reconhecido']
)

print('Classification report para XGBoost com SMOTE: \n')
print(classification_report_xgb_smote)
# Out:
# Melhores hiperparâmetros com balanceamento smote: OrderedDict([('xgb__alpha', 0), ('xgb__colsample_bytree', 0.7), ('xgb__eta', 0.1), ('xgb__gamma', 0.05), ('xgb__lambda', 0.01), ('xgb__max_depth', 25), ('xgb__min_child_weight', 1), ('xgb__subsample', 1.0)])
# Classification report para XGBoost com SMOTE:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.946104  0.987127  0.966180      1476
# Não reconhecido   0.648148  0.296610  0.406977       118
#
#        accuracy                       0.936010      1594
#       macro avg   0.797126  0.641869  0.686579      1594
#    weighted avg   0.924047  0.936010  0.924784      1594

# %%
ConfusionMatrixDisplay.from_estimator(bayes_search_xgb_smote, X_test_smote, y_test_smote, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %% [markdown]
# ### Avaliação das Variáveis de Importância
#
# Avaliação das variáveis de importância de acordo com o modelo com Smote, que apresentou o maior f1-score.

# %% [markdown]
# #### Feature importance

# %%
# Ajustar o melhor modelo encontrado (depois da busca bayesiana)
best_xgb_model_smote.named_steps['xgb'].fit(X_train_smote, y_train_smote)

# Obter o booster (árvores) do modelo treinado
booster = best_xgb_model_smote.named_steps['xgb'].get_booster()

# Obter a importância das features com base no ganho
importance_dict = booster.get_score(importance_type='gain')

# Transformar em DataFrame para organizar como tabela
importance_df = pd.DataFrame({
    'Feature': list(importance_dict.keys()),
    'Importance': list(importance_dict.values())
})

# Ordenar pela importância em ordem decrescente
importance_df = importance_df.sort_values(by='Importance', ascending=False)

estilo_tabelas(importance_df)
# Out:
# <style type="text/css">
# #T_d88b5 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_d88b5 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_d88b5 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_d88b5 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_d88b5 td {
#   border: 1px solid #666;
# }
# #T_d88b5  th {
#   border: 1px solid #666;
# }
# #T_d88b5_row0_col0, #T_d88b5_row0_col1, #T_d88b5_row1_col0, #T_d88b5_row1_col1, #T_d88b5_row2_col0, #T_d88b5_row2_col1, #T_d88b5_row3_col0, #T_d88b5_row3_col1, #T_d88b5_row4_col0, #T_d88b5_row4_col1, #T_d88b5_row5_col0, #T_d88b5_row5_col1, #T_d88b5_row6_col0, #T_d88b5_row6_col1, #T_d88b5_row7_col0, #T_d88b5_row7_col1, #T_d88b5_row8_col0, #T_d88b5_row8_col1, #T_d88b5_row9_col0, #T_d88b5_row9_col1, #T_d88b5_row10_col0, #T_d88b5_row10_col1, #T_d88b5_row11_col0, #T_d88b5_row11_col1, #T_d88b5_row12_col0, #T_d88b5_row12_col1, #T_d88b5_row13_col0, #T_d88b5_row13_col1, #T_d88b5_row14_col0, #T_d88b5_row14_col1, #T_d88b5_row15_col0, #T_d88b5_row15_col1, #T_d88b5_row16_col0, #T_d88b5_row16_col1, #T_d88b5_row17_col0, #T_d88b5_row17_col1, #T_d88b5_row18_col0, #T_d88b5_row18_col1, #T_d88b5_row19_col0, #T_d88b5_row19_col1, #T_d88b5_row20_col0, #T_d88b5_row20_col1, #T_d88b5_row21_col0, #T_d88b5_row21_col1, #T_d88b5_row22_col0, #T_d88b5_row22_col1, #T_d88b5_row23_col0, #T_d88b5_row23_col1, #T_d88b5_row24_col0, #T_d88b5_row24_col1, #T_d88b5_row25_col0, #T_d88b5_row25_col1, #T_d88b5_row26_col0, #T_d88b5_row26_col1, #T_d88b5_row27_col0, #T_d88b5_row27_col1, #T_d88b5_row28_col0, #T_d88b5_row28_col1, #T_d88b5_row29_col0, #T_d88b5_row29_col1, #T_d88b5_row30_col0, #T_d88b5_row30_col1, #T_d88b5_row31_col0, #T_d88b5_row31_col1, #T_d88b5_row32_col0, #T_d88b5_row32_col1, #T_d88b5_row33_col0, #T_d88b5_row33_col1, #T_d88b5_row34_col0, #T_d88b5_row34_col1, #T_d88b5_row35_col0, #T_d88b5_row35_col1, #T_d88b5_row36_col0, #T_d88b5_row36_col1, #T_d88b5_row37_col0, #T_d88b5_row37_col1, #T_d88b5_row38_col0, #T_d88b5_row38_col1, #T_d88b5_row39_col0, #T_d88b5_row39_col1, #T_d88b5_row40_col0, #T_d88b5_row40_col1, #T_d88b5_row41_col0, #T_d88b5_row41_col1, #T_d88b5_row42_col0, #T_d88b5_row42_col1, #T_d88b5_row43_col0, #T_d88b5_row43_col1, #T_d88b5_row44_col0, #T_d88b5_row44_col1, #T_d88b5_row45_col0, #T_d88b5_row45_col1, #T_d88b5_row46_col0, #T_d88b5_row46_col1, #T_d88b5_row47_col0, #T_d88b5_row47_col1, #T_d88b5_row48_col0, #T_d88b5_row48_col1, #T_d88b5_row49_col0, #T_d88b5_row49_col1, #T_d88b5_row50_col0, #T_d88b5_row50_col1, #T_d88b5_row51_col0, #T_d88b5_row51_col1, #T_d88b5_row52_col0, #T_d88b5_row52_col1, #T_d88b5_row53_col0, #T_d88b5_row53_col1, #T_d88b5_row54_col0, #T_d88b5_row54_col1, #T_d88b5_row55_col0, #T_d88b5_row55_col1, #T_d88b5_row56_col0, #T_d88b5_row56_col1, #T_d88b5_row57_col0, #T_d88b5_row57_col1, #T_d88b5_row58_col0, #T_d88b5_row58_col1, #T_d88b5_row59_col0, #T_d88b5_row59_col1, #T_d88b5_row60_col0, #T_d88b5_row60_col1, #T_d88b5_row61_col0, #T_d88b5_row61_col1, #T_d88b5_row62_col0, #T_d88b5_row62_col1, #T_d88b5_row63_col0, #T_d88b5_row63_col1, #T_d88b5_row64_col0, #T_d88b5_row64_col1, #T_d88b5_row65_col0, #T_d88b5_row65_col1, #T_d88b5_row66_col0, #T_d88b5_row66_col1, #T_d88b5_row67_col0, #T_d88b5_row67_col1, #T_d88b5_row68_col0, #T_d88b5_row68_col1, #T_d88b5_row69_col0, #T_d88b5_row69_col1, #T_d88b5_row70_col0, #T_d88b5_row70_col1, #T_d88b5_row71_col0, #T_d88b5_row71_col1, #T_d88b5_row72_col0, #T_d88b5_row72_col1, #T_d88b5_row73_col0, #T_d88b5_row73_col1, #T_d88b5_row74_col0, #T_d88b5_row74_col1, #T_d88b5_row75_col0, #T_d88b5_row75_col1, #T_d88b5_row76_col0, #T_d88b5_row76_col1, #T_d88b5_row77_col0, #T_d88b5_row77_col1, #T_d88b5_row78_col0, #T_d88b5_row78_col1, #T_d88b5_row79_col0, #T_d88b5_row79_col1, #T_d88b5_row80_col0, #T_d88b5_row80_col1, #T_d88b5_row81_col0, #T_d88b5_row81_col1, #T_d88b5_row82_col0, #T_d88b5_row82_col1, #T_d88b5_row83_col0, #T_d88b5_row83_col1, #T_d88b5_row84_col0, #T_d88b5_row84_col1, #T_d88b5_row85_col0, #T_d88b5_row85_col1, #T_d88b5_row86_col0, #T_d88b5_row86_col1, #T_d88b5_row87_col0, #T_d88b5_row87_col1, #T_d88b5_row88_col0, #T_d88b5_row88_col1, #T_d88b5_row89_col0, #T_d88b5_row89_col1, #T_d88b5_row90_col0, #T_d88b5_row90_col1 {
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_d88b5" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d88b5_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_d88b5_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d88b5_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_d88b5_row0_col0" class="data row0 col0" >DM_Inst Saúde Destruidas</td>
#       <td id="T_d88b5_row0_col1" class="data row0 col1" >47.487</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row1" class="row_heading level0 row1" >85</th>
#       <td id="T_d88b5_row1_col0" class="data row1 col0" >COBRADE_14132</td>
#       <td id="T_d88b5_row1_col1" class="data row1 col1" >29.143</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row2" class="row_heading level0 row2" >67</th>
#       <td id="T_d88b5_row2_col0" class="data row2 col0" >Sigla_UF_SC</td>
#       <td id="T_d88b5_row2_col1" class="data row2 col1" >25.507</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row3" class="row_heading level0 row3" >80</th>
#       <td id="T_d88b5_row3_col0" class="data row3 col0" >COBRADE_13214</td>
#       <td id="T_d88b5_row3_col1" class="data row3 col1" >25.358</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row4" class="row_heading level0 row4" >83</th>
#       <td id="T_d88b5_row4_col0" class="data row4 col0" >COBRADE_14120</td>
#       <td id="T_d88b5_row4_col1" class="data row4 col1" >24.620</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row5" class="row_heading level0 row5" >50</th>
#       <td id="T_d88b5_row5_col0" class="data row5 col0" >Sigla_UF_BA</td>
#       <td id="T_d88b5_row5_col1" class="data row5 col1" >20.069</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row6" class="row_heading level0 row6" >81</th>
#       <td id="T_d88b5_row6_col0" class="data row6 col0" >COBRADE_13215</td>
#       <td id="T_d88b5_row6_col1" class="data row6 col1" >19.331</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row7" class="row_heading level0 row7" >47</th>
#       <td id="T_d88b5_row7_col0" class="data row7 col0" >Sigla_UF_AL</td>
#       <td id="T_d88b5_row7_col1" class="data row7 col1" >18.014</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row8" class="row_heading level0 row8" >82</th>
#       <td id="T_d88b5_row8_col0" class="data row8 col0" >COBRADE_14110</td>
#       <td id="T_d88b5_row8_col1" class="data row8 col1" >17.378</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_d88b5_row9_col0" class="data row9 col0" >DM_Inst Ensino Danificadas</td>
#       <td id="T_d88b5_row9_col1" class="data row9 col1" >17.373</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row10" class="row_heading level0 row10" >88</th>
#       <td id="T_d88b5_row10_col0" class="data row10 col0" >COBRADE_22210</td>
#       <td id="T_d88b5_row10_col1" class="data row10 col1" >15.188</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row11" class="row_heading level0 row11" >57</th>
#       <td id="T_d88b5_row11_col0" class="data row11 col0" >Sigla_UF_MT</td>
#       <td id="T_d88b5_row11_col1" class="data row11 col1" >12.908</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row12" class="row_heading level0 row12" >64</th>
#       <td id="T_d88b5_row12_col0" class="data row12 col0" >Sigla_UF_RN</td>
#       <td id="T_d88b5_row12_col1" class="data row12 col1" >12.703</td>
#     </tr>
#     <tr>
#       <th id="T_d88b5_level0_row13" class="row_heading level0 row1

# %% [markdown]
# #### Permutation importance

# %%
# Calcular a permutação de importância no conjunto de teste
result = permutation_importance(best_xgb_model_smote, X_test_smote, y_test_smote, n_repeats=5, random_state=1, n_jobs=-1)

# Ordenar os resultados pela importância média
sorted_idx = result.importances_mean.argsort()

# Gráfico boxplot para mostrar a importância das variáveis
fig, ax = plt.subplots()
ax.boxplot(result.importances[sorted_idx].T, vert=False, tick_labels=X_test_smote.columns[sorted_idx])
ax.set_title("Permutation Importances (test set)")
fig.set_size_inches(15, 20) 
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Modelos com seleção de variáveis

# %% [markdown]
# #### Importância média > 0

# %%
# Filtrar as variáveis com importância média > 0
positive_idx = result.importances_mean > 0

# Selecionar apenas as colunas das features com importância positiva
selected_features = X_test_smote.columns[positive_idx]

# Criar novos datasets apenas com essas features
X_train_selected = X_train_smote[selected_features]
X_test_selected = X_test_smote[selected_features]

# Exibir as features selecionadas
print("Features selecionadas:", selected_features.tolist())
# Out:
# Features selecionadas: ['DH_DESALOJADOS', 'DM_Uni Habita Destruidas', 'DM_Uni Habita Valor', 'DM_Inst Saúde Destruidas', 'DM_Inst Saúde Valor', 'DM_Inst Ensino Destruidas', 'DM_Inst Comuni Danificadas', 'DM_Obras de Infra Destruidas', 'PEPR_Comércio (R$)', 'PEPR_Serviços (R$)', 'DOMICILIO_AREARURAL', 'QTDE_FAMILIAS_ATUALIZADAS', 'Sigla_UF_AL', 'Sigla_UF_PA', 'Sigla_UF_PB', 'Sigla_UF_PI', 'Sigla_UF_SC', 'COBRADE_13214', 'COBRADE_14120', 'COBRADE_14131']

# %%
# Aplicar SMOTE apenas no conjunto de treino com as variáveis selecionadas.
smote = SMOTE(random_state=1)
X_train_selected, y_train_smote = smote.fit_resample(X_train_selected, y_train_smote)

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],
    'xgb__min_child_weight': [1, 3, 5, 7],
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__lambda': [0.01, 0.1, 1.0],
    'xgb__alpha': [0, 0.1, 0.5, 1.0]
}

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb_smote = Pipeline([
    ('scaler', RobustScaler()),  # Usando RobustScaler
    ('xgb', xgb.XGBClassifier(random_state=1, eval_metric='logloss'))
])

# Realizar a busca bayesiana com validação cruzada no conjunto balanceado pelo SMOTE
bayes_search_xgb_smote = BayesSearchCV(
    pipeline_xgb_smote,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=3,
    scoring='f1_weighted',
    n_jobs=-1,
    random_state=1
)

# Ajustar o modelo ao conjunto de treino balanceado
bayes_search_xgb_smote.fit(X_train_selected, y_train_smote)

# Melhor modelo encontrado
best_xgb_model_smote = bayes_search_xgb_smote.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros com balanceamento smote: {bayes_search_xgb_smote.best_params_}")

# Fazer previsões com o conjunto de teste original
y_pred_xgb_smote = best_xgb_model_smote.predict(X_test_selected)

# Relatório de classificação
classification_report_xgb_smote = metrics.classification_report(
    y_test_smote, y_pred_xgb_smote, digits=6, target_names=['Reconhecido', 'Não reconhecido']
)

print('Classification report para XGBoost com SMOTE e considerando apenas variáveis com importância média positiva: \n')
print(classification_report_xgb_smote)
# Out:
# Melhores hiperparâmetros com balanceamento smote: OrderedDict([('xgb__alpha', 0), ('xgb__colsample_bytree', 0.6), ('xgb__eta', 0.1), ('xgb__gamma', 0.5), ('xgb__lambda', 0.1), ('xgb__max_depth', 17), ('xgb__min_child_weight', 1), ('xgb__subsample', 1.0)])
# Classification report para XGBoost com SMOTE e considerando apenas variáveis com importância média positiva:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.944628  0.970867  0.957568      1476
# Não reconhecido   0.441558  0.288136  0.348718       118
#
#        accuracy                       0.920326      1594
#       macro avg   0.693093  0.629501  0.653143      1594
#    weighted avg   0.907387  0.920326  0.912496      1594

# %%
ConfusionMatrixDisplay.from_estimator(bayes_search_xgb_smote, X_test_selected, y_test_smote, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %% [markdown]
# #### Importância média > -0.01

# %%
# Ajustando o threshold para manter variáveis com importância > -0.01
positive_idx_adjusted = result.importances_mean > -0.01

# Selecionar apenas as colunas das features com importância ajustada
selected_features_adjusted = X_test_smote.columns[positive_idx_adjusted]

# Criar novos datasets apenas com essas features
X_train_selected_adjusted = X_train_smote[selected_features_adjusted]
X_test_selected_adjusted = X_test_smote[selected_features_adjusted]

# Aplicar SMOTE apenas no conjunto de treino com as variáveis selecionadas.
smote = SMOTE(random_state=1)
X_train_selected_adjusted, y_train_smote = smote.fit_resample(X_train_selected_adjusted, y_train_smote)

# Definir hiperparâmetros para a busca bayesiana
param_grid_bayes = {
    'xgb__eta': [0.01, 0.015, 0.025, 0.05, 0.1],
    'xgb__gamma': [0.05, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0],
    'xgb__max_depth': [3, 5, 7, 9, 12, 15, 17, 25],
    'xgb__min_child_weight': [1, 3, 5, 7],
    'xgb__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgb__lambda': [0.01, 0.1, 1.0],
    'xgb__alpha': [0, 0.1, 0.5, 1.0]
}

# Criar pipeline com RobustScaler e XGBoost Classifier
pipeline_xgb_smote = Pipeline([
    ('scaler', RobustScaler()),  # Usando RobustScaler
    ('xgb', xgb.XGBClassifier(random_state=1, eval_metric='logloss'))
])

# Realizar a busca bayesiana com validação cruzada no conjunto balanceado pelo SMOTE
bayes_search_xgb_smote = BayesSearchCV(
    pipeline_xgb_smote,
    search_spaces=param_grid_bayes,
    n_iter=30,
    cv=3,
    scoring='f1_weighted',
    n_jobs=-1,
    random_state=1
)

# Ajustar o modelo ao conjunto de treino balanceado
bayes_search_xgb_smote.fit(X_train_selected_adjusted, y_train_smote)

# Melhor modelo encontrado
best_xgb_model_smote = bayes_search_xgb_smote.best_estimator_

# Exibir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros com balanceamento smote: {bayes_search_xgb_smote.best_params_}")

# Fazer previsões com o conjunto de teste original
y_pred_xgb_smote = best_xgb_model_smote.predict(X_test_selected_adjusted)

# Relatório de classificação
classification_report_xgb_smote = metrics.classification_report(
    y_test_smote, y_pred_xgb_smote, digits=6, target_names=['Reconhecido', 'Não reconhecido']
)

print('Classification report para XGBoost com SMOTE e considerando apenas variáveis com importância média > -0.01: \n')
print(classification_report_xgb_smote)
# Out:
# Melhores hiperparâmetros com balanceamento smote: OrderedDict([('xgb__alpha', 0), ('xgb__colsample_bytree', 0.7), ('xgb__eta', 0.1), ('xgb__gamma', 0.05), ('xgb__lambda', 0.01), ('xgb__max_depth', 25), ('xgb__min_child_weight', 1), ('xgb__subsample', 1.0)])
# Classification report para XGBoost com SMOTE e considerando apenas variáveis com importância média > -0.01:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.946104  0.987127  0.966180      1476
# Não reconhecido   0.648148  0.296610  0.406977       118
#
#        accuracy                       0.936010      1594
#       macro avg   0.797126  0.641869  0.686579      1594
#    weighted avg   0.924047  0.936010  0.924784      1594

# %%
ConfusionMatrixDisplay.from_estimator(bayes_search_xgb_smote, X_test_selected_adjusted, y_test_smote, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %% [markdown]
# #### Correlação < 0.5

# %%
# Calcular a matriz de correlação
corr_matrix = X_train_smote.corr()

# Criar um dataframe para armazenar os pares com alta correlação
high_corr_pairs = set()

# Iterar pela matriz de correlação e encontrar pares com correlação acima de 0.5
threshold = 0.5
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > threshold:
            # Adicionar os pares de features com correlação maior que o threshold
            high_corr_pairs.add((corr_matrix.columns[i], corr_matrix.columns[j]))

# Exibir os pares com alta correlação
print(f"Pares de features com correlação maior que {threshold}:")
print(high_corr_pairs)

# Remover uma feature de cada par com alta correlação
features_to_remove = {pair[1] for pair in high_corr_pairs}  # Remover a segunda feature em cada par
X_train_uncorrelated = X_train_smote.drop(columns=features_to_remove)
X_test_uncorrelated = X_test_smote.drop(columns=features_to_remove)

# Exibir as features que foram removidas
print(f"Features removidas devido à alta correlação: {features_to_remove}")
# Out:
# Pares de features com correlação maior que 0.5:
# {('DM_Uni Habita Valor', 'DH_DESABRIGADOS'), ('PDEFSAN', 'DOMICILIO_AREARURAL'), ('PEPR_Comércio (R$)', 'DM_Inst Serviços Valor'), ('PEPR_Comércio (R$)', 'PEPL_sist de esgotos sanit(R$)'), ('DM_Inst Ensino Valor', 'DM_Inst Ensino Danificadas'), ('Sigla_UF_PB', 'PEPL_Abast de água pot(R$)'), ('DH_DESALOJADOS', 'DH_MORTOS'), ('PEPL_sist de esgotos sanit(R$)', 'DM_Inst Serviços Valor'), ('PEPR_Indústria (R$)', 'DH_DESALOJADOS'), ('PEPR_Indústria (R$)', 'DH_MORTOS'), ('PDEFLIXO', 'PDEFAGUA'), ('PDEFAGUA', 'DOMICILIO_AREARURAL'), ('PEPL_Sis limp e rec lixo (R$)', 'DM_Inst Ensino Danificadas'), ('PDEFLIXO', 'DOMICILIO_AREARURAL'), ('PDEFSAN', 'PDEFLIXO'), ('PEPL_Telecomunicações (R$)', 'PEPL_distrib energia (R$)'), ('DM_Inst Saúde Valor', 'DH_DESALOJADOS'), ('DM_Inst Saúde Valor', 'DH_MORTOS'), ('PEPL_Ensino (R$)', 'DM_Inst Saúde Valor'), ('PEPR_Indústria (R$)', 'DM_Inst Saúde Valor'), ('PDEFSAN', 'PDEFESGOTO'), ('PEPL_Sis limp e rec lixo (R$)', 'DM_Inst Ensino Valor'), ('PDEFSAN', 'PDEFAGUA')}
# Features removidas devido à alta correlação: {'PDEFLIXO', 'PEPL_sist de esgotos sanit(R$)', 'DM_Inst Ensino Valor', 'DH_DESALOJADOS', 'DH_MORTOS', 'PEPL_distrib energia (R$)', 'PEPL_Abast de água pot(R$)', 'PDEFAGUA', 'DM_Inst Ensino Danificadas', 'DM_Inst Saúde Valor', 'PDEFESGOTO', 'DH_DESABRIGADOS', 'DOMICILIO_AREARURAL', 'DM_Inst Serviços Valor'}

# %%
# Aplicar o mesmo processo de SMOTE e ajuste do modelo com os dados sem alta correlação
smote = SMOTE(random_state=1)
X_train_uncorrelated_smote, y_train_smote_uncorrelated = smote.fit_resample(X_train_uncorrelated, y_train_smote)

# Ajustar o modelo com os dados sem alta correlação
best_xgb_model_uncorrelated = bayes_search_xgb_smote.fit(X_train_uncorrelated_smote, y_train_smote_uncorrelated)

# Fazer previsões
y_pred_uncorrelated = best_xgb_model_uncorrelated.predict(X_test_uncorrelated)

# Avaliar o desempenho
classification_report_uncorrelated = metrics.classification_report(
    y_test_smote, y_pred_uncorrelated, digits=6, target_names=['Reconhecido', 'Não reconhecido']
)

print('Relatório de classificação após remoção de alta correlação: \n')
print(classification_report_uncorrelated)
# Out:
# Relatório de classificação após remoção de alta correlação:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.944661  0.983062  0.963479      1476
# Não reconhecido   0.568966  0.279661  0.375000       118
#
#        accuracy                       0.930991      1594
#       macro avg   0.756813  0.631362  0.669240      1594
#    weighted avg   0.916850  0.930991  0.919916      1594

# %%
ConfusionMatrixDisplay.from_estimator(bayes_search_xgb_smote, X_test_uncorrelated, y_test_smote, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])
