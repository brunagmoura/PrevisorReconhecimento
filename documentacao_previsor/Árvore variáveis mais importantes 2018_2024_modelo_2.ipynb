# %% [markdown]
# ---
# ## Árvore de decisão - dados 2018 a 2024 - modelo 2
# ---

# %% [markdown]
# ## Análise exploratória dos dados

# %%
# Importar bibliotecas pandas, plot_confusion_matrix, train_test_split, matplotlib
import pandas as pd
# from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# !pip install treeinterpreter scikit-learn
from treeinterpreter import treeinterpreter as ti
# Out:
# Collecting treeinterpreter
#   Downloading treeinterpreter-0.2.3-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Downloading treeinterpreter-0.2.3-py2.py3-none-any.whl (6.0 kB)
# Installing collected packages: treeinterpreter
# Successfully installed treeinterpreter-0.2.3

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.float_format', '{:,.2f}'.format)
pd.set_option('display.float_format', '{:,.2f}'.format)
sns.set_theme(style="white", palette="deep", context="talk",font_scale=0.8)
plt.rcParams['figure.figsize'] = (12, 6)

# %%
object_columns = ['Protocolo_S2iD', 'Nome_Municipio', 'Sigla_UF', 'regiao',
                  'Setores Censitários', 'Status', 'DH_Descricao', 'DM_Descricao',
                  'DA_Descricao', 'DA_Polui/cont da água', 'DA_Polui/cont do ar',
                  'DA_Polui/cont do solo', 'DA_Dimi/exauri hídrico',
                  "DA_Incêndi parques/APA's/APP's", 'PEPL_Descricao', 'PEPR_Descricao',
                  'Categoria', 'Grupo', 'Subgrupo', 'Tipo', 'Subtipo']

dtype = {col: 'object' for col in object_columns}

# %%
df_eventos_2018_2 = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2018_2024_modelo2.csv",
    sep=';',
    decimal=',')

# %%
# df_eventos_2018_2.head(5)
# print(df_eventos_2018_2.info())

# %%
df_eventos_2018_2.dtypes.reset_index().rename(columns={0: '.dtype', 'index': 'Variável'})
# Out:
#                            Variável   .dtype
# 0                            Status    int64
# 1                         DH_MORTOS    int64
# 2                        DH_FERIDOS    int64
# 3                       DH_ENFERMOS    int64
# 4                   DH_DESABRIGADOS    int64
# 5                    DH_DESALOJADOS    int64
# 6                  DH_DESAPARECIDOS    int64
# 7                DH_OUTROS AFETADOS    int64
# 8         DM_Uni Habita Danificadas    int64
# 9          DM_Uni Habita Destruidas    int64
# 10              DM_Uni Habita Valor  float64
# 11        DM_Inst Saúde Danificadas  float64
# 12         DM_Inst Saúde Destruidas    int64
# 13              DM_Inst Saúde Valor  float64
# 14       DM_Inst Ensino Danificadas  float64
# 15        DM_Inst Ensino Destruidas    int64
# 16             DM_Inst Ensino Valor  float64
# 17     DM_Inst Serviços Danificadas    int64
# 18      DM_Inst Serviços Destruidas    int64
# 19           DM_Inst Serviços Valor  float64
# 20       DM_Inst Comuni Danificadas    int64
# 21        DM_Inst Comuni Destruidas    int64
# 22             DM_Inst Comuni Valor  float64
# 23    DM_Obras de Infra Danificadas  float64
# 24     DM_Obras de Infra Destruidas  float64
# 25          DM_Obras de Infra Valor  float64
# 26     PEPL_Assis_méd e emergên(R$)  float64
# 27       PEPL_Abast de água pot(R$)  float64
# 28   PEPL_sist de esgotos sanit(R$)  float64
# 29    PEPL_Sis limp e rec lixo (R$)  float64
# 30        PEPL_Sis cont pragas (R$)  float64
# 31        PEPL_distrib energia (R$)  float64
# 32       PEPL_Telecomunicações (R$)  float64
# 33   PEPL_Tran loc/reg/l_curso (R$)  float64
# 34    PEPL_Distrib combustíveis(R$)  float64
# 35      PEPL_Segurança pública (R$)  float64
# 36                 PEPL_Ensino (R$)  float64
# 37            PEPR_Agricultura (R$)  float64
# 38               PEPR_Pecuária (R$)  float64
# 39              PEPR_Indústria (R$)  float64
# 40               PEPR_Comércio (R$)  float64
# 41               PEPR_Serviços (R$)  float64
# 42                     DensidadePop  float64
# 43              DOMICILIO_AREARURAL  float64
# 44                         PDEFAGUA  float64
# 45                       PDEFESGOTO  float64
# 46                         PDEFLIXO  float64
# 47                          PDEFSAN  float64
# 48        QTDE_FAMILIAS_ATUALIZADAS  float64
# 49                      Sigla_UF_AC  float64
# 50                      Sigla_UF_AL  float64
# 51                      Sigla_UF_AM  float64
# 52                      Sigla_UF_AP  float64
# 53                      Sigla_UF_BA  float64
# 54                      Sigla_UF_CE  float64
# 55                      Sigla_UF_DF  float64
# 56                      Sigla_UF_ES  float64
# 57                      Sigla_UF_GO  float64
# 58                      Sigla_UF_MA  float64
# 59                      Sigla_UF_MG  float64
# 60                      Sigla_UF_MS  float64
# 61                      Sigla_UF_MT  float64
# 62                      Sigla_UF_PA  float64
# 63                      Sigla_UF_PB  float64
# 64                      Sigla_UF_PE  float64
# 65                      Sigla_UF_PI  float64
# 66                      Sigla_UF_PR  float64
# 67                      Sigla_UF_RJ  float64
# 68                      Sigla_UF_RN  float64
# 69                      Sigla_UF_RO  float64
# 70                      Sigla_UF_RR  float64
# 71                      Sigla_UF_RS  float64
# 72                      Sigla_UF_SC  float64
# 73                      Sigla_UF_SE  float64
# 74                      Sigla_UF_SP  float64
# 75                      Sigla_UF_TO  float64
# 76                      Sigla_UF_pa  float64
# 77                    COBRADE_11110  float64
# 78                    COBRADE_11120  float64
# 79                    COBRADE_11311  float64
# 80                    COBRADE_11312  float64
# 81                    COBRADE_11313  float64
# 82                    COBRADE_11321  float64
# 83                    COBRADE_11331  float64
# 84                    COBRADE_11332  float64
# 85                    COBRADE_11340  float64
# 86                    COBRADE_11410  float64
# 87                    COBRADE_11420  float64
# 88                    COBRADE_11431  float64
# 89                    COBRADE_11432  float64
# 90                    COBRADE_11433  float64
# 91                    COBRADE_12100  float64
# 92                    COBRADE_12200  float64
# 93                    COBRADE_12300  float64
# 94                    COBRADE_13111  float64
# 95                    COBRADE_13112  float64
# 96                    COBRADE_13120  float64
# 97                    COBRADE_13211  float64
# 98                    COBRADE_13212  float64
# 99                    COBRADE_13213  float64
# 100                   COBRADE_13214  float64
# 101                   COBRADE_13215  float64
# 102                   COBRADE_13310  float64
# 103                   COBRADE_13321  float64
# 104                   COBRADE_13322  float64
# 105                   COBRADE_14110  float64
# 106                   COBRADE_14120  float64
# 107                   COBRADE_14131  float64
# 108                   COBRADE_14132  float64
# 109                   COBRADE_14140  float64
# 110                   COBRADE_15110  float64
# 111                   COBRADE_15120  float64
# 112                   COBRADE_15130  float64
# 113                   COBRADE_15210  float64
# 114                   COBRADE_15230  float64
# 115                   COBRADE_22210  float64
# 116                   COBRADE_22220  float64
# 117                   COBRADE_23120  float64
# 118                   COBRADE_24100  float64
# 119                   COBRADE_24200  float64
# 120                   COBRADE_25100  float64
# 121                   COBRADE_25500  float64

# %%
# # Mostra número de valores nulos no dataset
# df_eventos_2018_2.isna().sum()

# %%
# Verifica balanceamento das classses (value_counts())
print(df_eventos_2018_2['Status'].value_counts())
# Out:
# Status
# 0    12057
# 1     1154
# Name: count, dtype: int64

# %%
# Atribuir valores para X e y, sendoque y será correspondete à variável 'Status'
X, y = df_eventos_2018_2.drop('Status', axis=1), df_eventos_2018_2['Status']
#print(y)

# %%
# # Cria X com as features codificadas com ".get_dummies" do Pandas.
# X_dummies = pd.get_dummies(df_eventos_2018_1.iloc[:,:-1])
# X_dummies.head()

# %%
# Criar árvore de decisão e plotar a árvore (plot_tree)
from sklearn.tree import DecisionTreeClassifier, plot_tree

cl = DecisionTreeClassifier(max_depth=4).fit(X, y)

plt.figure(figsize=(30,10))
plot_tree(cl, filled=True, fontsize=12, feature_names=X.columns)
plt.show()

# %%
# Dividir dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Árvore de decisão
clf = DecisionTreeClassifier(max_depth=4).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9157416750756812

# %%
from sklearn.metrics import f1_score
y_pred = clf.predict(X_test)
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"F1-score: {f1}")
# Out:
# F1-score: 0.8871982939065389

# %%
#Mostrar a árvore de decisão
plt.figure(figsize=(30,10))
plot_tree(clf, filled=True, fontsize=12, feature_names=X.columns)
plt.show()

# %%
# Regressão Logística
from sklearn.linear_model import LogisticRegression
X_train_no_nan = X_train.dropna()
X_test_no_nan = X_test.dropna()
y_train_no_nan = y_train[X_train_no_nan.index]
y_test_no_nan = y_test[X_test_no_nan.index]

reg_log = LogisticRegression(solver='lbfgs').fit(X_train_no_nan, y_train_no_nan)
reg_log.score(X_test_no_nan, np.ravel(y_test_no_nan))
# Out:
# 0.9003572846367606

# %%
y_pred_log = reg_log.predict(X_test_no_nan)
f1_log = f1_score(y_test_no_nan, y_pred_log, average='weighted')
print(f"F1-score: {f1_log}")
# Out:
# F1-score: 0.8705872070262718

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
import numpy as np
rf_class = RandomForestClassifier(n_estimators=120, max_depth=6, random_state=100).fit(X_train, np.ravel(y_train))
rf_class.score(X_test, y_test)
# Out:
# 0.9112008072653885

# %%
y_pred_r = rf_class.predict(X_test)
f1_r = f1_score(y_test, y_pred_r, average='weighted')
print(f"F1-score: {f1_r}")
# Out:
# F1-score: 0.8721433295160306

# %% [markdown]
# ###Como encontrar a árvore com o melhor score em uma Random Forest nos dados de teste ?

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Treinar uma Random Forest
rf = RandomForestClassifier(n_estimators=120, max_depth=6, random_state=100)  # Exemplo com 10 árvores
rf.fit(X_train, np.ravel(y_train))

# Avaliar o desempenho de cada árvore individual
best_score = 0
best_tree_index = 0

for i, tree in enumerate(rf.estimators_):
    # Previsão da árvore individual
    y_pred_tree = tree.predict(X_test)

    # Calcular o accuracy score da árvore nos dados de teste
    score = accuracy_score(y_test, np.ravel(y_pred_tree))

    # Encontrar a árvore com o melhor score
    if score > best_score:
        best_score = score
        best_tree_index = i

print(f'A árvore com o melhor desempenho é a árvore {best_tree_index} com um score de {best_score:.4f}\n')

# Acessando a árvore com o melhor desempenho
best_tree = rf.estimators_[best_tree_index]

# Opcional: Visualizar a árvore
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 15))
plot_tree(clf, filled=True, fontsize=10, feature_names=X.columns)
plt.show()
# Out:
# A árvore com o melhor desempenho é a árvore 42 com um score de 0.9135

# %%
## Usar o treeinterpreter para explicar uma previsão
instance = X_test.iloc[[0]].values #X_test[0].reshape(1, -1)  # Vamos explicar a primeira instância do conjunto de teste
prediction, bias, contributions = ti.predict(clf, instance)

# %%
# Passo 6: Visualizar o resultado
## Passo 6: Visualizar o resultado
# Criar um DataFrame para mostrar a contribuição de cada característica
# Ensure that the feature names and contributions have the same length
# by slicing the feature names to match the length of contributions
num_features = contributions[0].shape[0]

feature_contributions = pd.DataFrame({
    'Feature': X.columns[:num_features],  # Slicing feature names to match contributions length
    'Contribution': contributions[0][:, 1]  # Seleciona a coluna correspondente à classe positiva (1)
})
feature_contributions['Absolute Contribution'] = feature_contributions['Contribution'].abs()

# %%
# Ordenar as contribuições pela importância absoluta
feature_contributions = feature_contributions.sort_values(by='Absolute Contribution', ascending=False)

# Mostrar a previsão, o valor de bias e as contribuições
print(f"Previsão do modelo: {prediction[0][1]:.4f}")
print(f"Valor de bias (média): {bias[0][1]:.4f}")
print("\nContribuições das características:")
print(feature_contributions)
# Out:
# Previsão do modelo: 0.1061
# Valor de bias (média): 0.0852
#
# Contribuições das características:
#                             Feature  Contribution  Absolute Contribution
# 36            PEPR_Agricultura (R$)          0.06                   0.06
# 6                DH_OUTROS AFETADOS         -0.03                   0.03
# 85                    COBRADE_11410         -0.00                   0.00
# 89                    COBRADE_11433         -0.00                   0.00
# 0                         DH_MORTOS          0.00                   0.00
# 77                    COBRADE_11120          0.00                   0.00
# 88                    COBRADE_11432          0.00                   0.00
# 87                    COBRADE_11431          0.00                   0.00
# 86                    COBRADE_11420          0.00                   0.00
# 84                    COBRADE_11340          0.00                   0.00
# 83                    COBRADE_11332          0.00                   0.00
# 82                    COBRADE_11331          0.00                   0.00
# 81                    COBRADE_11321          0.00                   0.00
# 80                    COBRADE_11313          0.00                   0.00
# 79                    COBRADE_11312          0.00                   0.00
# 78                    COBRADE_11311          0.00                   0.00
# 76                    COBRADE_11110          0.00                   0.00
# 91                    COBRADE_12200          0.00                   0.00
# 75                      Sigla_UF_pa          0.00                   0.00
# 74                      Sigla_UF_TO          0.00                   0.00
# 73                      Sigla_UF_SP          0.00                   0.00
# 72                      Sigla_UF_SE          0.00                   0.00
# 71                      Sigla_UF_SC          0.00                   0.00
# 70                      Sigla_UF_RS          0.00                   0.00
# 69                      Sigla_UF_RR          0.00                   0.00
# 68                      Sigla_UF_RO          0.00                   0.00
# 67                      Sigla_UF_RN          0.00                   0.00
# 66                      Sigla_UF_RJ          0.00                   0.00
# 65                      Sigla_UF_PR          0.00                   0.00
# 64                      Sigla_UF_PI          0.00                   0.00
# 90                    COBRADE_12100          0.00                   0.00
# 92                    COBRADE_12300          0.00                   0.00
# 62                      Sigla_UF_PB          0.00                   0.00
# 107                   COBRADE_14132          0.00                   0.00
# 119                   COBRADE_25100          0.00                   0.00
# 118                   COBRADE_24200          0.00                   0.00
# 117                   COBRADE_24100          0.00                   0.00
# 116                   COBRADE_23120          0.00                   0.00
# 115                   COBRADE_22220          0.00                   0.00
# 114                   COBRADE_22210          0.00                   0.00
# 113                   COBRADE_15230          0.00                   0.00
# 112                   COBRADE_15210          0.00                   0.00
# 111                   COBRADE_15130          0.00                   0.00
# 110                   COBRADE_15120          0.00                   0.00
# 109                   COBRADE_15110          0.00                   0.00
# 108                   COBRADE_14140          0.00                   0.00
# 106                   COBRADE_14131          0.00                   0.00
# 93                    COBRADE_13111          0.00                   0.00
# 105                   COBRADE_14120          0.00                   0.00
# 104                   COBRADE_14110          0.00                   0.00
# 103                   COBRADE_13322          0.00                   0.00
# 102                   COBRADE_13321          0.00                   0.00
# 101                   COBRADE_13310          0.00                   0.00
# 100                   COBRADE_13215          0.00                   0.00
# 99                    COBRADE_13214          0.00                   0.00
# 98                    COBRADE_13213          0.00                   0.00
# 97                    COBRADE_13212          0.00                   0.00
# 96                    COBRADE_13211          0.00                   0.00
# 95                    COBRADE_13120          0.00                   0.00
# 94                    COBRADE_13112          0.00                   0.00
# 63                      Sigla_UF_PE          0.00                   0.00
# 60                      Sigla_UF_MT          0.00                   0.00
# 61                      Sigla_UF_PA          0.00                   0.00
# 16     DM_Inst Serviços Danificadas          0.00                   0.00
# 28    PEPL_Sis limp e rec lixo (R$)          0.00                   0.00
# 27   PEPL_sist de esgotos sanit(R$)          0.00                   0.00
# 26       PEPL_Abast de água pot(R$)          0.00                   0.00
# 25     PEPL_Assis_méd e emergên(R$)          0.00                   0.00
# 24          DM_Obras de Infra Valor          0.00                   0.00
# 23     DM_Obras de Infra Destruidas          0.00                   0.00
# 22    DM_Obras de Infra Danificadas          0.00                   0.00
# 21             DM_Inst Comuni Valor          0.00                   0.00
# 20        DM_Inst Comuni Destruidas          0.00                   0.00
# 19       DM_Inst Comuni Danificadas          0.00                   0.00
# 18           DM_Inst Serviços Valor          0.00                   0.00
# 17      DM_Inst Serviços Destruidas          0.00                   0.00
# 15             DM_Inst Ensino Valor          0.00                   0.00
# 30        PEPL_distrib energia (R$)          0.00                   0.00
# 14        DM_Inst Ensino Destruidas          0.00                   0.00
# 13       DM_Inst Ensino Danificadas          0.00                   0.00
# 12              DM_Inst Saúde Valor          0.00                   0.00
# 11         DM_Inst Saúde Destruidas          0.00                   0.00
# 10        DM_Inst Saúde Danificadas          0.00                   0.00
# 9               DM_Uni Habita Valor          0.00                   0.00
# 8          DM_Uni Habita Destruidas          0.00                   0.00
# 7         DM_Uni Habita Danificadas          0.00                   0.00
# 5                  DH_DESAPARECIDOS          0.00                   0.00
# 4                    DH_DESALOJADOS          0.00                   0.00
# 3                   DH_DESABRIGADOS          0.00                   0.00
# 2                       DH_ENFERMOS          0.00                   0.00
# 29        PEPL_Sis cont pragas (R$)          0.00                   0.00
# 31       PEPL_Telecomunicações (R$)          0.00                   0.00
# 1                        DH_FERIDOS          0.00                   0.00
# 47        QTDE_FAMILIAS_ATUALIZADAS          0.00                   0.00
# 59                      Sigla_UF_MS          0.00                   0.00
# 58                      Sigla_UF_MG          0.00                   0.00
# 57                      Sigla_UF_MA          0.00                   0.00
# 56                      Sigla_UF_GO          0.00                   0.00
# 55                      Sigla_UF_ES          0.00                   0.00
# 54                      Sigla_UF_DF          0.00                   0.00
# 53                      Sigla_UF_CE          0.00                   0.00
# 52                      Sigla_UF_BA          0.00                   0.00
# 51                      Sigla_UF_AP          0.00                   0.00
# 50                      Sigla_UF_AM          0.00                   0.00
# 49                      Sigla_UF_AL          0.00                   0.00
# 48                      Sigla_UF_AC          0.00                   0.00
# 46                          PDEFSAN          0.00                   0.00
# 32   PEPL_Tran loc/reg/l_curso (R$)          0.00                   0.00
# 45                         PDEFLIXO          0.00                   0.00
# 44                       PDEFESGOTO          0.00                   0.00
# 43                         PDEFAGUA          0.00                   0.00
# 42              DOMICILIO_AREARURAL          0.00                   0.00
# 41                     DensidadePop          0.00                   0.00
# 40               PEPR_Serviços (R$)          0.00                   0.00
# 39               PEPR_Comércio (R$)          0.00                   0.00
# 38              PEPR_Indústria (R$)          0.00                   0.00
# 37               PEPR_Pecuária (R$)          0.00                   0.00
# 35                 PEPL_Ensino (R$)          0.00                   0.00
# 34      PEPL_Segurança pública (R$)          0.00                   0.00
# 33    PEPL_Distrib combustíveis(R$)          0.00                   0.00
# 120                   COBRADE_25500          0.00                   0.00

# %%
# Visualizar o resultado com um gráfico


plt.figure(figsize=(10, 6))
plt.barh(feature_contributions['Feature'][0:10], feature_contributions['Contribution'][0:10], color='b')
plt.xlabel('Contribuição')
plt.title('Contribuição de cada característica para a previsão')
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contribuição no topo
plt.show()
